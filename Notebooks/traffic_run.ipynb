# %%
import random

import pandas as pd
from ptrail.core.Datasets import Datasets
from ptrail.features.kinematic_features import KinematicFeatures
from ptrail.preprocessing.statistics import Statistics
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import f1_score, accuracy_score

from src.augmentation.augment import Augmentation
from src.selection.select import Selection
from src.utils.general_utils import Utilities

# %%
BASE = 'base'
TRAINING = 'training'
TEST_X = 'test_x'
TEST_Y = 'test_y'
RANDOM_SELECTED = 'random_selected'
PROPORTIONAL_SELECTED = 'proportional_selected'
FEWEST_SELECTED = 'fewest_selected'
REPRESENTATIVE_SELECTED = 'representative_selected'
BALANCED_ON = 'balanced_on'
BALANCED_IN = 'balanced_in'

# %%
def augment_trajectories(dataset, ids_to_augment, circle, class_col):
    dataset = Augmentation.augment_trajectories_with_randomly_generated_points(dataset,
                                                                               ids_to_augment=ids_to_augment,
                                                                               circle=circle)

    for i in range(1, 3):
        dataset = Augmentation.augment_trajectories_with_randomly_generated_points(dataset,
                                                                                   ids_to_augment=ids_to_augment,
                                                                                   circle=circle)

    pivoted = Statistics.pivot_stats_df(
        dataframe=Statistics.generate_kinematic_stats(dataset, class_col), target_col_name=class_col).dropna()

    return pivoted.drop(columns=[class_col]), pivoted[class_col]

# %%
traffic_data = Datasets.load_traffic_data()
ready_dataset = KinematicFeatures.create_distance_column(traffic_data).reset_index()
# Out:
# ------------------------ Dataset Facts ------------------------------
#
# Number of unique Trajectories in the data: 125
# Number of points in the data: 44905
# Dataset time range: 0 days 00:00:59.900000
# Datatype of the DataFrame: <class 'ptrail.core.TrajectoryDF.PTRAILDataFrame'>
# Dataset Bounding Box: (34.7107417, 135.4640652, 34.7156517, 135.4702002)
#
# ---------------------------------------------------------------------

# %%
def get_test_train_data(seed_val, class_col, k=0.8):
    """
        Given the seed value and a proportion, split the
        data into training and testing set and return it.

        Parameters
        ----------
        seed_val: int
            The seed value to use to control the randomness
            while selecting the train-test split.
        k: float
            The percent of data to be used as training data.

        Returns
        -------
            tuple:
                training, testing_x and testing_y
    """
    # Get all the Trajectory Ids and set the random state.
    traj_ids = list(ready_dataset['traj_id'].unique())
    random.seed(seed_val)

    # Select the ids to be used as training set and the calculate subsequent testing ids.
    train_size = int(len(traj_ids) * k)
    train_traj_ids = random.sample(traj_ids, train_size)
    test_traj_ids = [id_ for id_ in traj_ids if id_ not in train_traj_ids]

    # Split the data into training and testing sets.
    training = ready_dataset.loc[ready_dataset.traj_id.isin(train_traj_ids)]
    testing = ready_dataset.loc[ready_dataset.traj_id.isin(test_traj_ids)]

    pivoted_test = Statistics.pivot_stats_df(Statistics.generate_kinematic_stats(testing, class_col, False), class_col).dropna()

    return training.dropna(), pivoted_test.drop(columns=[class_col]), pivoted_test[class_col]

# %%
def get_iterable_map(seed_val: int, class_col):
    """
        Given the seed value, generate the dataset based on it,
        and return a dictionary that contains the following values:
            | 1. Training dataset
            | 2. Testing X data.
            | 3. Testing Y data.
            | 4. Randomly selected trajectories to augment.
            | 5. Proportionally selected trajectories to augment.
            | 6. Fewest selected trajectories to augment.
            | 7. Representative selected trajectories to augment.
            | 8. Balanced using ON strategy Dataset.
            | 9. Balanced using IN strategy Dataset.

        Parameters
        ----------
            seed_val: int
                The seed value to use to control the randomness
                while selecting the train-test split.

        Returns
        -------
            dict:
                Dictionary with the aforementioned values.
    """
    training, test_x, test_y = get_test_train_data(seed_val, class_col)

    # -------------------------- The trajectory selection strategies --------------------------------- #
    # Random selection.
    random_selected_ids = Selection.select_randomly(training, seed=seed_val, k=0.2)

    # Proportional selection.
    proportional_selected = Selection.select_trajectories_proportionally(training, classification_col=class_col, seed=seed_val, k=0.2)

    # Fewest selection.
    fewest_selected = Selection.select_with_fewest_points(training, k=0.2)

    # Representative Selection
    rep_selected = Selection.select_representative_trajectories(training, class_col, closeness_cutoff=0.7, tolerance=10)

    # Balance the dataset.
    balanced_on = Augmentation.balance_dataset_with_augmentation(training, class_col, 'on')
    balanced_in = Augmentation.balance_dataset_with_augmentation(training, class_col, 'in')

    # ------------------------ Create the iterable map to be returned ---------------------------------- #
    return {
        TRAINING: training,
        TEST_X: test_x,
        TEST_Y: test_y,
        RANDOM_SELECTED: random_selected_ids,
        PROPORTIONAL_SELECTED: proportional_selected,
        FEWEST_SELECTED: fewest_selected,
        REPRESENTATIVE_SELECTED: rep_selected,
        BALANCED_ON: balanced_on,
        BALANCED_IN: balanced_in,
    }

# %%
def select_correct_test_train_split(iter_map, strat, circle_strat, class_col):
    x_train, y_train = None, None
    if strategy != BASE:
        if not "balanced" in strat:
            x_train, y_train = augment_trajectories(dataset=iter_map[TRAINING], ids_to_augment=iter_map[strat],
                                                    circle=circle_strat, class_col=class_col)
        if "balanced" in strat and circle_strat == "on":
            training = Statistics.pivot_stats_df(
                Statistics.generate_kinematic_stats(iter_map[BALANCED_ON], class_col), class_col).dropna()
            x_train, y_train = training.drop(columns=[class_col]), training[class_col]
        if "balanced" in strategy and circle_strat == "in":
            training = Statistics.pivot_stats_df(
                Statistics.generate_kinematic_stats(iter_map[BALANCED_IN], class_col), class_col).dropna()
            x_train, y_train = training.drop(columns=[class_col]), training[class_col]
    else:
        training = Statistics.pivot_stats_df(Statistics.generate_kinematic_stats(iter_map[TRAINING], class_col), class_col).dropna()
        x_train = training.drop(columns=[class_col])
        y_train = training[class_col]

    return x_train, y_train

# %%
# Get the 20 seed values that we are going to use.
seed_generator = Utilities.generate_pi_seed(20)
seed_vals = [next(seed_generator) for i in range(20)]
final_results = ["seed, strategy, model, accuracy, f1_score"]

# All our selection strategies.
select_strategies = [BASE, RANDOM_SELECTED, PROPORTIONAL_SELECTED, FEWEST_SELECTED, REPRESENTATIVE_SELECTED, BALANCED_ON, BALANCED_IN]
models = [GradientBoostingClassifier(), DecisionTreeClassifier(), SVC()]

for seed in seed_vals:
    # Get the iterable map for the seed.
    iter_map = get_iterable_map(seed, 'vehicle_type')
    for strategy in select_strategies:
        for model in models:
            for circle_strategy in ['on', 'in']:
                train_x, train_y = select_correct_test_train_split(iter_map, strategy, circle_strategy, 'vehicle_type')
                if (train_x is not None) and (train_y is not None):
                    # Fit the model and predict.
                    model.random_state = seed
                    model.fit(X=train_x, y=train_y)
                    pred_vals = model.predict(X=iter_map[TEST_X])

                    # Calculate the accuracy and f1 score.
                    acc = accuracy_score(y_true=iter_map[TEST_Y], y_pred=pred_vals)
                    score = f1_score(y_true=iter_map[TEST_Y], y_pred=pred_vals, average='weighted')
                    print(f"{seed}, {strategy}_{circle_strategy}, {model.__class__.__name__}, {acc}, {score}")
                    final_results.append(f"{seed}, {strategy}_{circle_strategy}, {model.__class__.__name__}, {acc}, {score}")
# Out:
# 1415, base_on, GradientBoostingClassifier, 0.875, 0.8944444444444444
# 1415, base_in, GradientBoostingClassifier, 0.875, 0.8944444444444444
# 1415, base_on, DecisionTreeClassifier, 0.875, 0.8944444444444444
# 1415, base_in, DecisionTreeClassifier, 0.875, 0.8944444444444444
# 1415, base_on, SVC, 0.9583333333333334, 0.9379432624113475
# 1415, base_in, SVC, 0.9583333333333334, 0.9379432624113475
# 1415, random_selected_on, GradientBoostingClassifier, 0.8333333333333334, 0.8712121212121211
# 1415, random_selected_in, GradientBoostingClassifier, 0.7916666666666666, 0.8468992248062017
# 1415, random_selected_on, DecisionTreeClassifier, 0.7083333333333334, 0.7955840455840456
# 1415, random_selected_in, DecisionTreeClassifier, 0.7916666666666666, 0.8468992248062017
# 1415, random_selected_on, SVC, 0.9583333333333334, 0.9379432624113475
# 1415, random_selected_in, SVC, 0.9583333333333334, 0.9379432624113475
# 1415, proportional_selected_on, GradientBoostingClassifier, 0.7916666666666666, 0.8468992248062017
# 1415, proportional_selected_in, GradientBoostingClassifier, 0.75, 0.8214285714285713
# 1415, proportional_selected_on, DecisionTreeClassifier, 0.5, 0.638888888888889
# 1415, proportional_selected_in, DecisionTreeClassifier, 0.7083333333333334, 0.7947154471544716
# 1415, proportional_selected_on, SVC, 0.9583333333333334, 0.9379432624113475
# 1415, proportional_selected_in, SVC, 0.9583333333333334, 0.9379432624113475
# 1415, fewest_selected_on, GradientBoostingClassifier, 0.875, 0.8944444444444444
# 1415, fewest_selected_in, GradientBoostingClassifier, 0.9583333333333334, 0.9379432624113475
# 1415, fewest_selected_on, DecisionTreeClassifier, 0.7083333333333334, 0.7947154471544716
# 1415, fewest_selected_in, DecisionTreeClassifier, 0.75, 0.8214285714285713
# 1415, fewest_selected_on, SVC, 0.9583333333333334, 0.9379432624113475
# 1415, fewest_selected_in, SVC, 0.9583333333333334, 0.9379432624113475
# 1415, representative_selected_on, GradientBoostingClassifier, 0.7916666666666666, 0.8468992248062017
# 1415, representative_selected_in, GradientBoostingClassifier, 0.7916666666666666, 0.8468992248062017
# 1415, representative_selected_on, DecisionTreeClassifier, 0.7916666666666666, 0.8468992248062017
# 1415, representative_selected_in, DecisionTreeClassifier, 0.75, 0.8214285714285713
# 1415, representative_selected_on, SVC, 0.9583333333333334, 0.9379432624113475
# 1415, representative_selected_in, SVC, 0.9583333333333334, 0.9379432624113475
# 1415, balanced_on_on, GradientBoostingClassifier, 0.9166666666666666, 0.9166666666666666
# 1415, balanced_on_in, GradientBoostingClassifier, 0.9583333333333334, 0.9379432624113475
# 1415, balanced_on_on, DecisionTreeClassifier, 0.9166666666666666, 0.9166666666666666
# 1415, balanced_on_in, DecisionTreeClassifier, 0.7916666666666666, 0.8533681765389084
# 1415, balanced_on_on, SVC, 0.9166666666666666, 0.9166666666666666
# 1415, balanced_on_in, SVC, 0.9583333333333334, 0.9379432624113475
# 1415, balanced_in_on, GradientBoostingClassifier, 0.9166666666666666, 0.9166666666666666
# 1415, balanced_in_in, GradientBoostingClassifier, 0.9583333333333334, 0.9379432624113475
# 1415, balanced_in_on, DecisionTreeClassifier, 0.9166666666666666, 0.9166666666666666
# 1415, balanced_in_in, DecisionTreeClassifier, 0.7916666666666666, 0.8533681765389084
# 1415, balanced_in_on, SVC, 0.9166666666666666, 0.9166666666666666
# 1415, balanced_in_in, SVC, 0.9583333333333334, 0.9379432624113475
# 9265, base_on, GradientBoostingClassifier, 0.92, 0.92
# 9265, base_in, GradientBoostingClassifier, 0.92, 0.92
# 9265, base_on, DecisionTreeClassifier, 0.92, 0.92
# 9265, base_in, DecisionTreeClassifier, 0.92, 0.92
# 9265, base_on, SVC, 0.96, 0.9404081632653061
# 9265, base_in, SVC, 0.96, 0.9404081632653061
# 9265, random_selected_on, GradientBoostingClassifier, 0.92, 0.92
# 9265, random_selected_in, GradientBoostingClassifier, 0.92, 0.92
# 9265, random_selected_on, DecisionTreeClassifier, 0.88, 0.898723404255319
# 9265, random_selected_in, DecisionTreeClassifier, 0.88, 0.898723404255319
# 9265, random_selected_on, SVC, 0.96, 0.9404081632653061
# 9265, random_selected_in, SVC, 0.96, 0.9404081632653061
# 9265, proportional_selected_on, GradientBoostingClassifier, 0.92, 0.92
# 9265, proportional_selected_in, GradientBoostingClassifier, 0.88, 0.898723404255319
# 9265, proportional_selected_on, DecisionTreeClassifier, 0.84, 0.8765217391304347
# 9265, proportional_selected_in, DecisionTreeClassifier, 0.84, 0.8765217391304347
# 9265, proportional_selected_on, SVC, 0.96, 0.9404081632653061
# 9265, proportional_selected_in, SVC, 0.96, 0.9404081632653061
# 9265, fewest_selected_on, GradientBoostingClassifier, 0.88, 0.898723404255319
# 9265, fewest_selected_in, GradientBoostingClassifier, 0.92, 0.92
# 9265, fewest_selected_on, DecisionTreeClassifier, 0.88, 0.898723404255319
# 9265, fewest_selected_in, DecisionTreeClassifier, 0.84, 0.8765217391304347
# 9265, fewest_selected_on, SVC, 0.96, 0.9404081632653061
# 9265, fewest_selected_in, SVC, 0.96, 0.9404081632653061
# 9265, representative_selected_on, GradientBoostingClassifier, 0.92, 0.92
# 9265, representative_selected_in, GradientBoostingClassifier, 0.92, 0.92
# 9265, representative_selected_on, DecisionTreeClassifier, 0.88, 0.898723404255319
# 9265, representative_selected_in, DecisionTreeClassifier, 0.84, 0.8765217391304347
# 9265, representative_selected_on, SVC, 0.96, 0.9404081632653061
# 9265, representative_selected_in, SVC, 0.96, 0.9404081632653061
# 9265, balanced_on_on, GradientBoostingClassifier, 0.96, 0.9404081632653061
# 9265, balanced_on_in, GradientBoostingClassifier, 1.0, 1.0
# 9265, balanced_on_on, DecisionTreeClassifier, 0.84, 0.8765217391304347
# 9265, balanced_on_in, DecisionTreeClassifier, 0.88, 0.898723404255319
# 9265, balanced_on_on, SVC, 0.96, 0.9404081632653061
# 9265, balanced_on_in, SVC, 0.96, 0.9404081632653061
# 9265, balanced_in_on, GradientBoostingClassifier, 0.96, 0.9404081632653061
# 9265, balanced_in_in, GradientBoostingClassifier, 1.0, 1.0
# 9265, balanced_in_on, DecisionTreeClassifier, 0.84, 0.8765217391304347
# 9265, balanced_in_in, DecisionTreeClassifier, 0.88, 0.898723404255319
# 9265, balanced_in_on, SVC, 0.96, 0.9404081632653061
# 9265, balanced_in_in, SVC, 0.96, 0.9404081632653061
# 3589, base_on, GradientBoostingClassifier, 0.92, 0.92
# 3589, base_in, GradientBoostingClassifier, 0.92, 0.92
# 3589, base_on, DecisionTreeClassifier, 0.84, 0.8765217391304347
# 3589, base_in, DecisionTreeClassifier, 0.84, 0.8765217391304347
# 3589, base_on, SVC, 0.96, 0.9404081632653061
# 3589, base_in, SVC, 0.96, 0.9404081632653061
# 3589, random_selected_on, GradientBoostingClassifier, 0.96, 0.9404081632653061
# 3589, random_selected_in, GradientBoostingClassifier, 0.96, 0.9404081632653061
# 3589, random_selected_on, DecisionTreeClassifier, 0.92, 0.92
# 3589, random_selected_in, DecisionTreeClassifier, 0.84, 0.8765217391304347
# 3589, random_selected_on, SVC, 0.96, 0.9404081632653061
# 3589, random_selected_in, SVC, 0.96, 0.9404081632653061
# 3589, proportional_selected_on, GradientBoostingClassifier, 0.96, 0.9404081632653061
# 3589, proportional_selected_in, GradientBoostingClassifier, 0.96, 0.9404081632653061
# 3589, proportional_selected_on, DecisionTreeClassifier, 0.92, 0.92
# 3589, proportional_selected_in, DecisionTreeClassifier, 0.88, 0.898723404255319
# 3589, proportional_selected_on, SVC, 0.96, 0.9404081632653061
# 3589, proportional_selected_in, SVC, 0.96, 0.9404081632653061
# 3589, fewest_selected_on, GradientBoostingClassifier, 0.96, 0.9404081632653061
# 3589, fewest_selected_in, GradientBoostingClassifier, 0.96, 0.9404081632653061
# 3589, fewest_selected_on, DecisionTreeClassifier, 0.8, 0.8533333333333334
# 3589, fewest_selected_in, DecisionTreeClassifier, 0.8, 0.8533333333333334
# 3589, fewest_selected_on, SVC, 0.96, 0.9404081632653061
# 3589, fewest_selected_in, SVC, 0.96, 0.9404081632653061
# 3589, representative_selected_on, GradientBoostingClassifier, 0.92, 0.92
# 3589, representative_selected_in, GradientBoostingClassifier, 0.96, 0.9404081632653061
# 3589, representative_selected_on, DecisionTreeClassifier, 0.96, 0.9404081632653061
# 3589, representative_selected_in, DecisionTreeClassifier, 0.92, 0.92
# 3589, representative_selected_on, SVC, 0.96, 0.9404081632653061
# 3589, representative_selected_in, SVC, 0.96, 0.9404081632653061
# 3589, balanced_on_on, GradientBoostingClassifier, 0.96, 0.9404081632653061
# 3589, balanced_on_in, GradientBoostingClassifier, 0.92, 0.92
# 3589, balanced_on_on, DecisionTreeClassifier, 0.88, 0.898723404255319
# 3589, balanced_on_in, DecisionTreeClassifier, 0.84, 0.8765217391304347
# 3589, balanced_on_on, SVC, 0.88, 0.898723404255319
# 3589, balanced_on_in, SVC, 0.96, 0.9404081632653061
# 3589, balanced_in_on, GradientBoostingClassifier, 0.96, 0.9404081632653061
# 3589, balanced_in_in, GradientBoostingClassifier, 0.92, 0.92
# 3589, balanced_in_on, DecisionTreeClassifier, 0.88, 0.898723404255319
# 3589, balanced_in_in, DecisionTreeClassifier, 0.84, 0.8765217391304347
# 3589, balanced_in_on, SVC, 0.88, 0.898723404255319
# 3589, balanced_in_in, SVC, 0.96, 0.9404081632653061
# 7932, base_on, GradientBoostingClassifier, 0.76, 0.7254545454545455
# 7932, base_in, GradientBoostingClassifier, 0.76, 0.7254545454545455
# 7932, base_on, DecisionTreeClassifier, 0.8, 0.8086720867208672
# 7932, base_in, DecisionTreeClassifier, 0.8, 0.8086720867208672
# 7932, base_on, SVC, 0.84, 0.7669565217391304
# 7932, base_in, SVC, 0.84, 0.7669565217391304
# 7932, random_selected_on, GradientBoostingClassifier, 0.76, 0.7254545454545455
# 7932, random_selected_in, GradientBoostingClassifier, 0.84, 0.8169696969696968
# 7932, random_selected_on, DecisionTreeClassifier, 0.72, 0.7032558139534884
# 7932, random_selected_in, DecisionTreeClassifier, 0.8, 0.7466666666666667
# 7932, random_selected_on, SVC, 0.84, 0.7669565217391304
# 7932, random_selected_in, SVC, 0.84, 0.7669565217391304
# 7932, proportional_selected_on, GradientBoostingClassifier, 0.76, 0.7254545454545455
# 7932, proportional_selected_in, GradientBoostingClassifier, 0.84, 0.8169696969696968
# 7932, proportional_selected_on, DecisionTreeClassifier, 0.72, 0.7474125874125873
# 7932, proportional_selected_in, DecisionTreeClassifier, 0.72, 0.7032558139534884
# 7932, proportional_selected_on, SVC, 0.84, 0.7669565217391304
# 7932, proportional_selected_in, SVC, 0.84, 0.7669565217391304
# 7932, fewest_selected_on, GradientBoostingClassifier, 0.8, 0.7466666666666667
# 7932, fewest_selected_in, GradientBoostingClassifier, 0.84, 0.7669565217391304
# 7932, fewest_selected_on, DecisionTreeClassifier, 0.8, 0.7880398671096346
# 7932, fewest_selected_in, DecisionTreeClassifier, 0.8, 0.7880398671096346
# 7932, fewest_selected_on, SVC, 0.84, 0.7669565217391304
# 7932, fewest_selected_in, SVC, 0.84, 0.7669565217391304
# 7932, representative_selected_on, GradientBoostingClassifier, 0.8, 0.7466666666666667
# 7932, representative_selected_in, GradientBoostingClassifier, 0.76, 0.7254545454545455
# 7932, representative_selected_on, DecisionTreeClassifier, 0.76, 0.7254545454545455
# 7932, representative_selected_in, DecisionTreeClassifier, 0.84, 0.7669565217391304
# 7932, representative_selected_on, SVC, 0.84, 0.7669565217391304
# 7932, representative_selected_in, SVC, 0.84, 0.7669565217391304
# 7932, balanced_on_on, GradientBoostingClassifier, 0.8, 0.7466666666666667
# 7932, balanced_on_in, GradientBoostingClassifier, 0.8, 0.7466666666666667
# 7932, balanced_on_on, DecisionTreeClassifier, 0.72, 0.7032558139534884
# 7932, balanced_on_in, DecisionTreeClassifier, 0.84, 0.7669565217391304
# 7932, balanced_on_on, SVC, 0.88, 0.8480000000000001
# 7932, balanced_on_in, SVC, 0.84, 0.7669565217391304
# 7932, balanced_in_on, GradientBoostingClassifier, 0.8, 0.7466666666666667
# 7932, balanced_in_in, GradientBoostingClassifier, 0.8, 0.7466666666666667
# 7932, balanced_in_on, DecisionTreeClassifier, 0.72, 0.7032558139534884
# 7932, balanced_in_in, DecisionTreeClassifier, 0.84, 0.7669565217391304
# 7932, balanced_in_on, SVC, 0.88, 0.8480000000000001
# 7932, balanced_in_in, SVC, 0.84, 0.7669565217391304
# 3846, base_on, GradientBoostingClassifier, 0.92, 0.9084848484848485
# 3846, base_in, GradientBoostingClassifier, 0.92, 0.9084848484848485
# 3846, base_on, DecisionTreeClassifier, 0.8, 0.8086720867208672
# 3846, base_in, DecisionTreeClassifier, 0.8, 0.8086720867208672
# 3846, base_on, SVC, 0.84, 0.7669565217391304
# 3846, base_in, SVC, 0.84, 0.7669565217391304
# 3846, random_selected_on, GradientBoostingClassifier, 0.92, 0.9084848484848485
# 3846, random_selected_in, GradientBoostingClassifier, 0.88, 0.8728239202657807
# 3846, random_selected_on, DecisionTreeClassifier, 0.88, 0.8728239202657807
# 3846, random_selected_in, DecisionTreeClassifier, 0.88, 0.8480000000000001
# 3846, random_selected_on, SVC, 0.84, 0.7669565217391304
# 3846, random_selected_in, SVC, 0.84, 0.7669565217391304
# 3846, proportional_selected_on, GradientBoostingClassifier, 0.88, 0.8480000000000001
# 3846, proportional_selected_in, GradientBoostingClassifier, 0.84, 0.8169696969696968
# 3846, proportional_selected_on, DecisionTreeClassifier, 0.8, 0.8086720867208672
# 3846, proportional_selected_in, DecisionTreeClassifier, 0.84, 0.84
# 3846, proportional_selected_on, SVC, 0.84, 0.7669565217391304
# 3846, proportional_selected_in, SVC, 0.84, 0.7669565217391304
# 3846, fewest_selected_on, GradientBoostingClassifier, 0.88, 0.8480000000000001
# 3846, fewest_selected_in, GradientBoostingClassifier, 0.88, 0.8480000000000001
# 3846, fewest_selected_on, DecisionTreeClassifier, 0.8, 0.7880398671096346
# 3846, fewest_selected_in, DecisionTreeClassifier, 0.8, 0.8086720867208672
# 3846, fewest_selected_on, SVC, 0.84, 0.7669565217391304
# 3846, fewest_selected_in, SVC, 0.84, 0.7669565217391304
# 3846, representative_selected_on, GradientBoostingClassifier, 0.88, 0.8480000000000001
# 3846, representative_selected_in, GradientBoostingClassifier, 0.88, 0.8480000000000001
# 3846, representative_selected_on, DecisionTreeClassifier, 0.84, 0.8169696969696968
# 3846, representative_selected_in, DecisionTreeClassifier, 0.72, 0.7321409214092143
# 3846, representative_selected_on, SVC, 0.84, 0.7669565217391304
# 3846, representative_selected_in, SVC, 0.84, 0.7669565217391304
# 3846, balanced_on_on, GradientBoostingClassifier, 0.88, 0.8480000000000001
# 3846, balanced_on_in, GradientBoostingClassifier, 0.88, 0.8480000000000001
# 3846, balanced_on_on, DecisionTreeClassifier, 0.76, 0.76
# 3846, balanced_on_in, DecisionTreeClassifier, 0.88, 0.8480000000000001
# 3846, balanced_on_on, SVC, 0.84, 0.7669565217391304
# 3846, balanced_on_in, SVC, 0.84, 0.7669565217391304
# 3846, balanced_in_on, GradientBoostingClassifier, 0.88, 0.8480000000000001
# 3846, balanced_in_in, GradientBoostingClassifier, 0.88, 0.8480000000000001
# 3846, balanced_in_on, DecisionTreeClassifier, 0.76, 0.76
# 3846, balanced_in_in, DecisionTreeClassifier, 0.88, 0.8480000000000001
# 3846, balanced_in_on, SVC, 0.84, 0.7669565217391304
# 3846, balanced_in_in, SVC, 0.84, 0.7669565217391304
# 2643, base_on, GradientBoostingClassifier, 0.92, 0.9017391304347826
# 2643, base_in, GradientBoostingClassifier, 0.92, 0.9017391304347826
# 2643, base_on, DecisionTreeClassifier, 0.92, 0.9017391304347826
# 2643, base_in, DecisionTreeClassifier, 0.92, 0.9017391304347826
# 2643, base_on, SVC, 0.88, 0.8238297872340425
# 2643, base_in, SVC, 0.88, 0.8238297872340425
# 2643, random_selected_on, GradientBoostingClassifier, 0.84, 0.8034782608695652
# 2643, random_selected_in, GradientBoostingClassifier, 0.84, 0.8034782608695652
# 2643, random_selected_on, DecisionTreeClassifier, 0.76, 0.7959999999999999
# 2643, random_selected_in, DecisionTreeClassifier, 0.8, 0.8119601328903654
# 2643, random_selected_on, SVC, 0.88, 0.8238297872340425
# 2643, random_selected_in, SVC, 0.88, 0.8238297872340425
# 2643, proportional_selected_on, GradientBoostingClassifier, 0.92, 0.9017391304347826
# 2643, proportional_selected_in, GradientBoostingClassifier, 0.88, 0.8693333333333332
# 2643, proportional_selected_on, DecisionTreeClassifier, 0.84, 0.84
# 2643, proportional_selected_in, DecisionTreeClassifier, 0.8, 0.8119601328903654
# 2643, proportional_selected_on, SVC, 0.88, 0.8238297872340425
# 2643, proportional_selected_in, SVC, 0.88, 0.8238297872340425
# 2643, fewest_selected_on, GradientBoostingClassifier, 0.8, 0.8119601328903654
# 2643, fewest_selected_in, GradientBoostingClassifier, 0.88, 0.8693333333333332
# 2643, fewest_selected_on, DecisionTreeClassifier, 0.92, 0.9017391304347826
# 2643, fewest_selected_in, DecisionTreeClassifier, 0.88, 0.8871760797342193
# 2643, fewest_selected_on, SVC, 0.88, 0.8238297872340425
# 2643, fewest_selected_in, SVC, 0.88, 0.8238297872340425
# 2643, representative_selected_on, GradientBoostingClassifier, 0.8, 0.7822222222222223
# 2643, representative_selected_in, GradientBoostingClassifier, 0.8, 0.8119601328903654
# 2643, representative_selected_on, DecisionTreeClassifier, 0.76, 0.7842857142857143
# 2643, representative_selected_in, DecisionTreeClassifier, 0.68, 0.7123809523809524
# 2643, representative_selected_on, SVC, 0.88, 0.8238297872340425
# 2643, representative_selected_in, SVC, 0.88, 0.8238297872340425
# 2643, balanced_on_on, GradientBoostingClassifier, 0.92, 0.9017391304347826
# 2643, balanced_on_in, GradientBoostingClassifier, 0.92, 0.9017391304347826
# 2643, balanced_on_on, DecisionTreeClassifier, 0.84, 0.84
# 2643, balanced_on_in, DecisionTreeClassifier, 0.8, 0.8119601328903654
# 2643, balanced_on_on, SVC, 0.76, 0.76
# 2643, balanced_on_in, SVC, 0.88, 0.8238297872340425
# 2643, balanced_in_on, GradientBoostingClassifier, 0.92, 0.9017391304347826
# 2643, balanced_in_in, GradientBoostingClassifier, 0.92, 0.9017391304347826
# 2643, balanced_in_on, DecisionTreeClassifier, 0.84, 0.84
# 2643, balanced_in_in, DecisionTreeClassifier, 0.8, 0.8119601328903654
# 2643, balanced_in_on, SVC, 0.76, 0.76
# 2643, balanced_in_in, SVC, 0.88, 0.8238297872340425
# 3832, base_on, GradientBoostingClassifier, 0.875, 0.8675958188153309
# 3832, base_in, GradientBoostingClassifier, 0.875, 0.8675958188153309
# 3832, base_on, DecisionTreeClassifier, 0.8333333333333334, 0.8095238095238094
# 3832, base_in, DecisionTreeClassifier, 0.8333333333333334, 0.8095238095238094
# 3832, base_on, SVC, 0.8333333333333334, 0.7575757575757575
# 3832, base_in, SVC, 0.8333333333333334, 0.7575757575757575
# 3832, random_selected_on, GradientBoostingClassifier, 0.875, 0.8418604651162792
# 3832, random_selected_in, GradientBoostingClassifier, 0.875, 0.8418604651162792
# 3832, random_selected_on, DecisionTreeClassifier, 0.75, 0.7684210526315791
# 3832, random_selected_in, DecisionTreeClassifier, 0.8333333333333334, 0.8333333333333334
# 3832, random_selected_on, SVC, 0.8333333333333334, 0.7575757575757575
# 3832, random_selected_in, SVC, 0.8333333333333334, 0.7575757575757575
# 3832, proportional_selected_on, GradientBoostingClassifier, 0.8333333333333334, 0.8095238095238094
# 3832, proportional_selected_in, GradientBoostingClassifier, 0.7916666666666666, 0.7364341085271319
# 3832, proportional_selected_on, DecisionTreeClassifier, 0.9166666666666666, 0.9047619047619048
# 3832, proportional_selected_in, DecisionTreeClassifier, 0.8333333333333334, 0.8095238095238094
# 3832, proportional_selected_on, SVC, 0.8333333333333334, 0.7575757575757575
# 3832, proportional_selected_in, SVC, 0.8333333333333334, 0.7575757575757575
# 3832, fewest_selected_on, GradientBoostingClassifier, 0.8333333333333334, 0.8095238095238094
# 3832, fewest_selected_in, GradientBoostingClassifier, 0.8333333333333334, 0.8095238095238094
# 3832, fewest_selected_on, DecisionTreeClassifier, 0.8333333333333334, 0.8333333333333334
# 3832, fewest_selected_in, DecisionTreeClassifier, 0.7916666666666666, 0.7793263646922183
# 3832, fewest_selected_on, SVC, 0.8333333333333334, 0.7575757575757575
# 3832, fewest_selected_in, SVC, 0.8333333333333334, 0.7575757575757575
# 3832, representative_selected_on, GradientBoostingClassifier, 0.8333333333333334, 0.8095238095238094
# 3832, representative_selected_in, GradientBoostingClassifier, 0.8333333333333334, 0.8095238095238094
# 3832, representative_selected_on, DecisionTreeClassifier, 0.7083333333333334, 0.7207977207977208
# 3832, representative_selected_in, DecisionTreeClassifier, 0.875, 0.8675958188153309
# 3832, representative_selected_on, SVC, 0.8333333333333334, 0.7575757575757575
# 3832, representative_selected_in, SVC, 0.8333333333333334, 0.7575757575757575
# 3832, balanced_on_on, GradientBoostingClassifier, 0.875, 0.8418604651162792
# 3832, balanced_on_in, GradientBoostingClassifier, 0.9166666666666666, 0.9047619047619048
# 3832, balanced_on_on, DecisionTreeClassifier, 0.7916666666666666, 0.7793263646922183
# 3832, balanced_on_in, DecisionTreeClassifier, 0.8333333333333334, 0.8095238095238094
# 3832, balanced_on_on, SVC, 0.8333333333333334, 0.7575757575757575
# 3832, balanced_on_in, SVC, 0.8333333333333334, 0.7575757575757575
# 3832, balanced_in_on, GradientBoostingClassifier, 0.875, 0.8418604651162792
# 3832, balanced_in_in, GradientBoostingClassifier, 0.9166666666666666, 0.9047619047619048
# 3832, balanced_in_on, DecisionTreeClassifier, 0.7916666666666666, 0.7793263646922183
# 3832, balanced_in_in, DecisionTreeClassifier, 0.8333333333333334, 0.8095238095238094
# 3832, balanced_in_on, SVC, 0.8333333333333334, 0.7575757575757575
# 3832, balanced_in_in, SVC, 0.8333333333333334, 0.7575757575757575
# 7950, base_on, GradientBoostingClassifier, 0.8, 0.7880398671096346
# 7950, base_in, GradientBoostingClassifier, 0.8, 0.7880398671096346
# 7950, base_on, DecisionTreeClassifier, 0.76, 0.7254545454545455
# 7950, base_in, DecisionTreeClassifier, 0.76, 0.7254545454545455
# 7950, base_on, SVC, 0.84, 0.7669565217391304
# 7950, base_in, SVC, 0.84, 0.7669565217391304
# 7950, random_selected_on, GradientBoostingClassifier, 0.76, 0.7254545454545455
# 7950, random_selected_in, GradientBoostingClassifier, 0.76, 0.7254545454545455
# 7950, random_selected_on, DecisionTreeClassifier, 0.76, 0.76
# 7950, random_selected_in, DecisionTreeClassifier, 0.76, 0.7780000000000001
# 7950, random_selected_on, SVC, 0.84, 0.7669565217391304
# 7950, random_selected_in, SVC, 0.84, 0.7669565217391304
# 7950, proportional_selected_on, GradientBoostingClassifier, 0.76, 0.76
# 7950, proportional_selected_in, GradientBoostingClassifier, 0.72, 0.7032558139534884
# 7950, proportional_selected_on, DecisionTreeClassifier, 0.76, 0.7780000000000001
# 7950, proportional_selected_in, DecisionTreeClassifier, 0.68, 0.7040000000000001
# 7950, proportional_selected_on, SVC, 0.84, 0.7669565217391304
# 7950, proportional_selected_in, SVC, 0.84, 0.7669565217391304
# 7950, fewest_selected_on, GradientBoostingClassifier, 0.76, 0.7254545454545455
# 7950, fewest_selected_in, GradientBoostingClassifier, 0.72, 0.7032558139534884
# 7950, fewest_selected_on, DecisionTreeClassifier, 0.72, 0.7321409214092143
# 7950, fewest_selected_in, DecisionTreeClassifier, 0.76, 0.76
# 7950, fewest_selected_on, SVC, 0.84, 0.7669565217391304
# 7950, fewest_selected_in, SVC, 0.84, 0.7669565217391304
# 7950, representative_selected_on, GradientBoostingClassifier, 0.8, 0.7880398671096346
# 7950, representative_selected_in, GradientBoostingClassifier, 0.72, 0.7321409214092143
# 7950, representative_selected_on, DecisionTreeClassifier, 0.76, 0.7780000000000001
# 7950, representative_selected_in, DecisionTreeClassifier, 0.72, 0.7321409214092143
# 7950, representative_selected_on, SVC, 0.84, 0.7669565217391304
# 7950, representative_selected_in, SVC, 0.84, 0.7669565217391304
# 7950, balanced_on_on, GradientBoostingClassifier, 0.84, 0.7669565217391304
# 7950, balanced_on_in, GradientBoostingClassifier, 0.84, 0.8169696969696968
# 7950, balanced_on_on, DecisionTreeClassifier, 0.68, 0.68
# 7950, balanced_on_in, DecisionTreeClassifier, 0.76, 0.7780000000000001
# 7950, balanced_on_on, SVC, 0.84, 0.8169696969696968
# 7950, balanced_on_in, SVC, 0.84, 0.7669565217391304
# 7950, balanced_in_on, GradientBoostingClassifier, 0.84, 0.7669565217391304
# 7950, balanced_in_in, GradientBoostingClassifier, 0.84, 0.8169696969696968
# 7950, balanced_in_on, DecisionTreeClassifier, 0.68, 0.68
# 7950, balanced_in_in, DecisionTreeClassifier, 0.76, 0.7780000000000001
# 7950, balanced_in_on, SVC, 0.84, 0.8169696969696968
# 7950, balanced_in_in, SVC, 0.84, 0.7669565217391304
# 2884, base_on, GradientBoostingClassifier, 0.96, 0.9635555555555555
# 2884, base_in, GradientBoostingClassifier, 0.96, 0.9635555555555555
# 2884, base_on, DecisionTreeClassifier, 0.92, 0.9315151515151514
# 2884, base_in, DecisionTreeClassifier, 0.92, 0.9315151515151514
# 2884, base_on, SVC, 0.92, 0.8816666666666667
# 2884, base_in, SVC, 0.92, 0.8816666666666667
# 2884, random_selected_on, GradientBoostingClassifier, 0.96, 0.953758865248227
# 2884, random_selected_in, GradientBoostingClassifier, 0.92, 0.8816666666666667
# 2884, random_selected_on, DecisionTreeClassifier, 0.84, 0.84
# 2884, random_selected_in, DecisionTreeClassifier, 0.8, 0.8177777777777778
# 2884, random_selected_on, SVC, 0.92, 0.8816666666666667
# 2884, random_selected_in, SVC, 0.92, 0.8816666666666667
# 2884, proportional_selected_on, GradientBoostingClassifier, 0.92, 0.8816666666666667
# 2884, proportional_selected_in, GradientBoostingClassifier, 0.88, 0.8612765957446809
# 2884, proportional_selected_on, DecisionTreeClassifier, 0.76, 0.7945454545454546
# 2884, proportional_selected_in, DecisionTreeClassifier, 0.84, 0.84
# 2884, proportional_selected_on, SVC, 0.92, 0.8816666666666667
# 2884, proportional_selected_in, SVC, 0.92, 0.8816666666666667
# 2884, fewest_selected_on, GradientBoostingClassifier, 0.88, 0.8612765957446809
# 2884, fewest_selected_in, GradientBoostingClassifier, 0.96, 0.953758865248227
# 2884, fewest_selected_on, DecisionTreeClassifier, 0.84, 0.8723809523809523
# 2884, fewest_selected_in, DecisionTreeClassifier, 0.88, 0.8906666666666666
# 2884, fewest_selected_on, SVC, 0.92, 0.8816666666666667
# 2884, fewest_selected_in, SVC, 0.92, 0.8816666666666667
# 2884, representative_selected_on, GradientBoostingClassifier, 0.96, 0.9635555555555555
# 2884, representative_selected_in, GradientBoostingClassifier, 0.92, 0.92
# 2884, representative_selected_on, DecisionTreeClassifier, 0.88, 0.8906666666666666
# 2884, representative_selected_in, DecisionTreeClassifier, 0.92, 0.9315151515151514
# 2884, representative_selected_on, SVC, 0.92, 0.8816666666666667
# 2884, representative_selected_in, SVC, 0.92, 0.8816666666666667
# 2884, balanced_on_on, GradientBoostingClassifier, 0.96, 0.9635555555555555
# 2884, balanced_on_in, GradientBoostingClassifier, 1.0, 1.0
# 2884, balanced_on_on, DecisionTreeClassifier, 0.84, 0.8723809523809523
# 2884, balanced_on_in, DecisionTreeClassifier, 0.88, 0.9015282392026578
# 2884, balanced_on_on, SVC, 0.96, 0.953758865248227
# 2884, balanced_on_in, SVC, 0.92, 0.8816666666666667
# 2884, balanced_in_on, GradientBoostingClassifier, 0.96, 0.9635555555555555
# 2884, balanced_in_in, GradientBoostingClassifier, 1.0, 1.0
# 2884, balanced_in_on, DecisionTreeClassifier, 0.84, 0.8723809523809523
# 2884, balanced_in_in, DecisionTreeClassifier, 0.88, 0.9015282392026578
# 2884, balanced_in_on, SVC, 0.96, 0.953758865248227
# 2884, balanced_in_in, SVC, 0.92, 0.8816666666666667
# 1971, base_on, GradientBoostingClassifier, 0.84, 0.8034782608695652
# 1971, base_in, GradientBoostingClassifier, 0.84, 0.8034782608695652
# 1971, base_on, DecisionTreeClassifier, 0.76, 0.76
# 1971, base_in, DecisionTreeClassifier, 0.76, 0.76
# 1971, base_on, SVC, 0.88, 0.8238297872340425
# 1971, base_in, SVC, 0.88, 0.8238297872340425
# 1971, random_selected_on, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 1971, random_selected_in, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 1971, random_selected_on, DecisionTreeClassifier, 0.72, 0.7367441860465117
# 1971, random_selected_in, DecisionTreeClassifier, 0.92, 0.9017391304347826
# 1971, random_selected_on, SVC, 0.88, 0.8238297872340425
# 1971, random_selected_in, SVC, 0.88, 0.8238297872340425
# 1971, proportional_selected_on, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 1971, proportional_selected_in, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 1971, proportional_selected_on, DecisionTreeClassifier, 0.84, 0.84
# 1971, proportional_selected_in, DecisionTreeClassifier, 0.84, 0.8034782608695652
# 1971, proportional_selected_on, SVC, 0.88, 0.8238297872340425
# 1971, proportional_selected_in, SVC, 0.88, 0.8238297872340425
# 1971, fewest_selected_on, GradientBoostingClassifier, 0.84, 0.8034782608695652
# 1971, fewest_selected_in, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 1971, fewest_selected_on, DecisionTreeClassifier, 0.92, 0.9017391304347826
# 1971, fewest_selected_in, DecisionTreeClassifier, 0.84, 0.8034782608695652
# 1971, fewest_selected_on, SVC, 0.88, 0.8238297872340425
# 1971, fewest_selected_in, SVC, 0.88, 0.8238297872340425
# 1971, representative_selected_on, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 1971, representative_selected_in, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 1971, representative_selected_on, DecisionTreeClassifier, 0.88, 0.8238297872340425
# 1971, representative_selected_in, DecisionTreeClassifier, 0.84, 0.8034782608695652
# 1971, representative_selected_on, SVC, 0.88, 0.8238297872340425
# 1971, representative_selected_in, SVC, 0.88, 0.8238297872340425
# 1971, balanced_on_on, GradientBoostingClassifier, 0.92, 0.9017391304347826
# 1971, balanced_on_in, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 1971, balanced_on_on, DecisionTreeClassifier, 0.8, 0.8119601328903654
# 1971, balanced_on_in, DecisionTreeClassifier, 0.88, 0.8693333333333332
# 1971, balanced_on_on, SVC, 0.88, 0.8238297872340425
# 1971, balanced_on_in, SVC, 0.88, 0.8238297872340425
# 1971, balanced_in_on, GradientBoostingClassifier, 0.92, 0.9017391304347826
# 1971, balanced_in_in, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 1971, balanced_in_on, DecisionTreeClassifier, 0.8, 0.8119601328903654
# 1971, balanced_in_in, DecisionTreeClassifier, 0.88, 0.8693333333333332
# 1971, balanced_in_on, SVC, 0.88, 0.8238297872340425
# 1971, balanced_in_in, SVC, 0.88, 0.8238297872340425
# 6939, base_on, GradientBoostingClassifier, 0.88, 0.8906666666666666
# 6939, base_in, GradientBoostingClassifier, 0.88, 0.8906666666666666
# 6939, base_on, DecisionTreeClassifier, 0.84, 0.8723809523809523
# 6939, base_in, DecisionTreeClassifier, 0.84, 0.8723809523809523
# 6939, base_on, SVC, 0.92, 0.8816666666666667
# 6939, base_in, SVC, 0.92, 0.8816666666666667
# 6939, random_selected_on, GradientBoostingClassifier, 0.92, 0.8816666666666667
# 6939, random_selected_in, GradientBoostingClassifier, 0.92, 0.8816666666666667
# 6939, random_selected_on, DecisionTreeClassifier, 0.76, 0.7945454545454546
# 6939, random_selected_in, DecisionTreeClassifier, 0.72, 0.770232558139535
# 6939, random_selected_on, SVC, 0.92, 0.8816666666666667
# 6939, random_selected_in, SVC, 0.92, 0.8816666666666667
# 6939, proportional_selected_on, GradientBoostingClassifier, 0.92, 0.8816666666666667
# 6939, proportional_selected_in, GradientBoostingClassifier, 0.88, 0.8612765957446809
# 6939, proportional_selected_on, DecisionTreeClassifier, 0.88, 0.8906666666666666
# 6939, proportional_selected_in, DecisionTreeClassifier, 0.88, 0.8906666666666666
# 6939, proportional_selected_on, SVC, 0.92, 0.8816666666666667
# 6939, proportional_selected_in, SVC, 0.92, 0.8816666666666667
# 6939, fewest_selected_on, GradientBoostingClassifier, 0.92, 0.8816666666666667
# 6939, fewest_selected_in, GradientBoostingClassifier, 0.84, 0.84
# 6939, fewest_selected_on, DecisionTreeClassifier, 0.8, 0.8358803986710965
# 6939, fewest_selected_in, DecisionTreeClassifier, 0.92, 0.92
# 6939, fewest_selected_on, SVC, 0.92, 0.8816666666666667
# 6939, fewest_selected_in, SVC, 0.92, 0.8816666666666667
# 6939, representative_selected_on, GradientBoostingClassifier, 0.88, 0.8612765957446809
# 6939, representative_selected_in, GradientBoostingClassifier, 0.88, 0.8612765957446809
# 6939, representative_selected_on, DecisionTreeClassifier, 0.8, 0.8358803986710965
# 6939, representative_selected_in, DecisionTreeClassifier, 0.84, 0.84
# 6939, representative_selected_on, SVC, 0.92, 0.8816666666666667
# 6939, representative_selected_in, SVC, 0.92, 0.8816666666666667
# 6939, balanced_on_on, GradientBoostingClassifier, 0.88, 0.8612765957446809
# 6939, balanced_on_in, GradientBoostingClassifier, 0.92, 0.8816666666666667
# 6939, balanced_on_on, DecisionTreeClassifier, 0.8, 0.8177777777777778
# 6939, balanced_on_in, DecisionTreeClassifier, 0.88, 0.8906666666666666
# 6939, balanced_on_on, SVC, 0.92, 0.8816666666666667
# 6939, balanced_on_in, SVC, 0.92, 0.8816666666666667
# 6939, balanced_in_on, GradientBoostingClassifier, 0.88, 0.8612765957446809
# 6939, balanced_in_in, GradientBoostingClassifier, 0.92, 0.8816666666666667
# 6939, balanced_in_on, DecisionTreeClassifier, 0.8, 0.8177777777777778
# 6939, balanced_in_in, DecisionTreeClassifier, 0.88, 0.8906666666666666
# 6939, balanced_in_on, SVC, 0.92, 0.8816666666666667
# 6939, balanced_in_in, SVC, 0.92, 0.8816666666666667
# 9375, base_on, GradientBoostingClassifier, 0.88, 0.8906666666666666
# 9375, base_in, GradientBoostingClassifier, 0.88, 0.8906666666666666
# 9375, base_on, DecisionTreeClassifier, 0.84, 0.8630303030303029
# 9375, base_in, DecisionTreeClassifier, 0.84, 0.8630303030303029
# 9375, base_on, SVC, 0.92, 0.8816666666666667
# 9375, base_in, SVC, 0.92, 0.8816666666666667
# 9375, random_selected_on, GradientBoostingClassifier, 0.92, 0.92
# 9375, random_selected_in, GradientBoostingClassifier, 0.92, 0.8816666666666667
# 9375, random_selected_on, DecisionTreeClassifier, 0.92, 0.92
# 9375, random_selected_in, DecisionTreeClassifier, 0.92, 0.92
# 9375, random_selected_on, SVC, 0.92, 0.8816666666666667
# 9375, random_selected_in, SVC, 0.92, 0.8816666666666667
# 9375, proportional_selected_on, GradientBoostingClassifier, 0.92, 0.8816666666666667
# 9375, proportional_selected_in, GradientBoostingClassifier, 0.92, 0.8816666666666667
# 9375, proportional_selected_on, DecisionTreeClassifier, 0.8, 0.8433604336043362
# 9375, proportional_selected_in, DecisionTreeClassifier, 0.84, 0.8630303030303029
# 9375, proportional_selected_on, SVC, 0.92, 0.8816666666666667
# 9375, proportional_selected_in, SVC, 0.92, 0.8816666666666667
# 9375, fewest_selected_on, GradientBoostingClassifier, 0.88, 0.8612765957446809
# 9375, fewest_selected_in, GradientBoostingClassifier, 0.92, 0.8816666666666667
# 9375, fewest_selected_on, DecisionTreeClassifier, 0.88, 0.8612765957446809
# 9375, fewest_selected_in, DecisionTreeClassifier, 0.88, 0.8612765957446809
# 9375, fewest_selected_on, SVC, 0.92, 0.8816666666666667
# 9375, fewest_selected_in, SVC, 0.92, 0.8816666666666667
# 9375, representative_selected_on, GradientBoostingClassifier, 0.84, 0.84
# 9375, representative_selected_in, GradientBoostingClassifier, 0.88, 0.8906666666666666
# 9375, representative_selected_on, DecisionTreeClassifier, 0.84, 0.84
# 9375, representative_selected_in, DecisionTreeClassifier, 0.84, 0.8630303030303029
# 9375, representative_selected_on, SVC, 0.92, 0.8816666666666667
# 9375, representative_selected_in, SVC, 0.92, 0.8816666666666667
# 9375, balanced_on_on, GradientBoostingClassifier, 0.88, 0.8906666666666666
# 9375, balanced_on_in, GradientBoostingClassifier, 0.88, 0.8906666666666666
# 9375, balanced_on_on, DecisionTreeClassifier, 0.88, 0.9015282392026578
# 9375, balanced_on_in, DecisionTreeClassifier, 0.84, 0.84
# 9375, balanced_on_on, SVC, 0.84, 0.8630303030303029
# 9375, balanced_on_in, SVC, 0.92, 0.8816666666666667
# 9375, balanced_in_on, GradientBoostingClassifier, 0.88, 0.8906666666666666
# 9375, balanced_in_in, GradientBoostingClassifier, 0.88, 0.8906666666666666
# 9375, balanced_in_on, DecisionTreeClassifier, 0.88, 0.9015282392026578
# 9375, balanced_in_in, DecisionTreeClassifier, 0.84, 0.84
# 9375, balanced_in_on, SVC, 0.84, 0.8630303030303029
# 9375, balanced_in_in, SVC, 0.92, 0.8816666666666667
# 1058, base_on, GradientBoostingClassifier, 0.88, 0.898723404255319
# 1058, base_in, GradientBoostingClassifier, 0.88, 0.898723404255319
# 1058, base_on, DecisionTreeClassifier, 0.88, 0.898723404255319
# 1058, base_in, DecisionTreeClassifier, 0.88, 0.898723404255319
# 1058, base_on, SVC, 0.96, 0.9404081632653061
# 1058, base_in, SVC, 0.96, 0.9404081632653061
# 1058, random_selected_on, GradientBoostingClassifier, 0.96, 0.9404081632653061
# 1058, random_selected_in, GradientBoostingClassifier, 0.96, 0.9404081632653061
# 1058, random_selected_on, DecisionTreeClassifier, 0.88, 0.898723404255319
# 1058, random_selected_in, DecisionTreeClassifier, 0.88, 0.898723404255319
# 1058, random_selected_on, SVC, 0.96, 0.9404081632653061
# 1058, random_selected_in, SVC, 0.96, 0.9404081632653061
# 1058, proportional_selected_on, GradientBoostingClassifier, 0.92, 0.92
# 1058, proportional_selected_in, GradientBoostingClassifier, 0.96, 0.9404081632653061
# 1058, proportional_selected_on, DecisionTreeClassifier, 0.84, 0.8765217391304347
# 1058, proportional_selected_in, DecisionTreeClassifier, 0.84, 0.8765217391304347
# 1058, proportional_selected_on, SVC, 0.96, 0.9404081632653061
# 1058, proportional_selected_in, SVC, 0.96, 0.9404081632653061
# 1058, fewest_selected_on, GradientBoostingClassifier, 0.88, 0.898723404255319
# 1058, fewest_selected_in, GradientBoostingClassifier, 0.92, 0.92
# 1058, fewest_selected_on, DecisionTreeClassifier, 0.84, 0.8765217391304347
# 1058, fewest_selected_in, DecisionTreeClassifier, 0.88, 0.898723404255319
# 1058, fewest_selected_on, SVC, 0.96, 0.9404081632653061
# 1058, fewest_selected_in, SVC, 0.96, 0.9404081632653061
# 1058, representative_selected_on, GradientBoostingClassifier, 0.96, 0.9404081632653061
# 1058, representative_selected_in, GradientBoostingClassifier, 0.96, 0.9404081632653061
# 1058, representative_selected_on, DecisionTreeClassifier, 0.84, 0.8765217391304347
# 1058, representative_selected_in, DecisionTreeClassifier, 0.88, 0.898723404255319
# 1058, representative_selected_on, SVC, 0.96, 0.9404081632653061
# 1058, representative_selected_in, SVC, 0.96, 0.9404081632653061
# 1058, balanced_on_on, GradientBoostingClassifier, 0.88, 0.898723404255319
# 1058, balanced_on_in, GradientBoostingClassifier, 0.96, 0.9404081632653061
# 1058, balanced_on_on, DecisionTreeClassifier, 0.8, 0.8533333333333334
# 1058, balanced_on_in, DecisionTreeClassifier, 0.84, 0.8765217391304347
# 1058, balanced_on_on, SVC, 0.88, 0.898723404255319
# 1058, balanced_on_in, SVC, 0.96, 0.9404081632653061
# 1058, balanced_in_on, GradientBoostingClassifier, 0.88, 0.898723404255319
# 1058, balanced_in_in, GradientBoostingClassifier, 0.96, 0.9404081632653061
# 1058, balanced_in_on, DecisionTreeClassifier, 0.8, 0.8533333333333334
# 1058, balanced_in_in, DecisionTreeClassifier, 0.84, 0.8765217391304347
# 1058, balanced_in_on, SVC, 0.88, 0.898723404255319
# 1058, balanced_in_in, SVC, 0.96, 0.9404081632653061
# 2097, base_on, GradientBoostingClassifier, 0.875, 0.863953488372093
# 2097, base_in, GradientBoostingClassifier, 0.875, 0.863953488372093
# 2097, base_on, DecisionTreeClassifier, 0.7916666666666666, 0.7732558139534884
# 2097, base_in, DecisionTreeClassifier, 0.7916666666666666, 0.7732558139534884
# 2097, base_on, SVC, 0.875, 0.8166666666666668
# 2097, base_in, SVC, 0.875, 0.8166666666666668
# 2097, random_selected_on, GradientBoostingClassifier, 0.875, 0.8166666666666668
# 2097, random_selected_in, GradientBoostingClassifier, 0.875, 0.8166666666666668
# 2097, random_selected_on, DecisionTreeClassifier, 0.6666666666666666, 0.7000000000000001
# 2097, random_selected_in, DecisionTreeClassifier, 0.7916666666666666, 0.7732558139534884
# 2097, random_selected_on, SVC, 0.875, 0.8166666666666668
# 2097, random_selected_in, SVC, 0.875, 0.8166666666666668
# 2097, proportional_selected_on, GradientBoostingClassifier, 0.875, 0.8166666666666668
# 2097, proportional_selected_in, GradientBoostingClassifier, 0.8333333333333334, 0.7954545454545453
# 2097, proportional_selected_on, DecisionTreeClassifier, 0.7083333333333334, 0.7256097560975611
# 2097, proportional_selected_in, DecisionTreeClassifier, 0.8333333333333334, 0.7954545454545453
# 2097, proportional_selected_on, SVC, 0.875, 0.8166666666666668
# 2097, proportional_selected_in, SVC, 0.875, 0.8166666666666668
# 2097, fewest_selected_on, GradientBoostingClassifier, 0.875, 0.8166666666666668
# 2097, fewest_selected_in, GradientBoostingClassifier, 0.875, 0.8166666666666668
# 2097, fewest_selected_on, DecisionTreeClassifier, 0.75, 0.75
# 2097, fewest_selected_in, DecisionTreeClassifier, 0.7916666666666666, 0.7732558139534884
# 2097, fewest_selected_on, SVC, 0.875, 0.8166666666666668
# 2097, fewest_selected_in, SVC, 0.875, 0.8166666666666668
# 2097, representative_selected_on, GradientBoostingClassifier, 0.875, 0.8166666666666668
# 2097, representative_selected_in, GradientBoostingClassifier, 0.7083333333333334, 0.7256097560975611
# 2097, representative_selected_on, DecisionTreeClassifier, 0.75, 0.75
# 2097, representative_selected_in, DecisionTreeClassifier, 0.7083333333333334, 0.7256097560975611
# 2097, representative_selected_on, SVC, 0.875, 0.8166666666666668
# 2097, representative_selected_in, SVC, 0.875, 0.8166666666666668
# 2097, balanced_on_on, GradientBoostingClassifier, 0.875, 0.863953488372093
# 2097, balanced_on_in, GradientBoostingClassifier, 0.875, 0.8166666666666668
# 2097, balanced_on_on, DecisionTreeClassifier, 0.7916666666666666, 0.804006968641115
# 2097, balanced_on_in, DecisionTreeClassifier, 0.875, 0.8166666666666668
# 2097, balanced_on_on, SVC, 0.875, 0.8166666666666668
# 2097, balanced_on_in, SVC, 0.875, 0.8166666666666668
# 2097, balanced_in_on, GradientBoostingClassifier, 0.875, 0.863953488372093
# 2097, balanced_in_in, GradientBoostingClassifier, 0.875, 0.8166666666666668
# 2097, balanced_in_on, DecisionTreeClassifier, 0.7916666666666666, 0.804006968641115
# 2097, balanced_in_in, DecisionTreeClassifier, 0.875, 0.8166666666666668
# 2097, balanced_in_on, SVC, 0.875, 0.8166666666666668
# 2097, balanced_in_in, SVC, 0.875, 0.8166666666666668
# 4944, base_on, GradientBoostingClassifier, 0.84, 0.84
# 4944, base_in, GradientBoostingClassifier, 0.84, 0.84
# 4944, base_on, DecisionTreeClassifier, 0.84, 0.8561904761904762
# 4944, base_in, DecisionTreeClassifier, 0.84, 0.8561904761904762
# 4944, base_on, SVC, 0.88, 0.8238297872340425
# 4944, base_in, SVC, 0.88, 0.8238297872340425
# 4944, random_selected_on, GradientBoostingClassifier, 0.92, 0.9017391304347826
# 4944, random_selected_in, GradientBoostingClassifier, 0.84, 0.8034782608695652
# 4944, random_selected_on, DecisionTreeClassifier, 0.88, 0.8693333333333332
# 4944, random_selected_in, DecisionTreeClassifier, 0.96, 0.9564444444444444
# 4944, random_selected_on, SVC, 0.88, 0.8238297872340425
# 4944, random_selected_in, SVC, 0.88, 0.8238297872340425
# 4944, proportional_selected_on, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 4944, proportional_selected_in, GradientBoostingClassifier, 0.8, 0.7822222222222223
# 4944, proportional_selected_on, DecisionTreeClassifier, 0.88, 0.8693333333333332
# 4944, proportional_selected_in, DecisionTreeClassifier, 0.68, 0.728
# 4944, proportional_selected_on, SVC, 0.88, 0.8238297872340425
# 4944, proportional_selected_in, SVC, 0.88, 0.8238297872340425
# 4944, fewest_selected_on, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 4944, fewest_selected_in, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 4944, fewest_selected_on, DecisionTreeClassifier, 0.84, 0.84
# 4944, fewest_selected_in, DecisionTreeClassifier, 0.84, 0.84
# 4944, fewest_selected_on, SVC, 0.88, 0.8238297872340425
# 4944, fewest_selected_in, SVC, 0.88, 0.8238297872340425
# 4944, representative_selected_on, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 4944, representative_selected_in, GradientBoostingClassifier, 0.92, 0.9017391304347826
# 4944, representative_selected_on, DecisionTreeClassifier, 0.96, 0.9564444444444444
# 4944, representative_selected_in, DecisionTreeClassifier, 0.68, 0.7123809523809524
# 4944, representative_selected_on, SVC, 0.88, 0.8238297872340425
# 4944, representative_selected_in, SVC, 0.88, 0.8238297872340425
# 4944, balanced_on_on, GradientBoostingClassifier, 0.92, 0.9017391304347826
# 4944, balanced_on_in, GradientBoostingClassifier, 0.92, 0.9017391304347826
# 4944, balanced_on_on, DecisionTreeClassifier, 0.8, 0.7822222222222223
# 4944, balanced_on_in, DecisionTreeClassifier, 0.88, 0.8871760797342193
# 4944, balanced_on_on, SVC, 0.84, 0.84
# 4944, balanced_on_in, SVC, 0.88, 0.8238297872340425
# 4944, balanced_in_on, GradientBoostingClassifier, 0.92, 0.9017391304347826
# 4944, balanced_in_in, GradientBoostingClassifier, 0.92, 0.9017391304347826
# 4944, balanced_in_on, DecisionTreeClassifier, 0.8, 0.7822222222222223
# 4944, balanced_in_in, DecisionTreeClassifier, 0.88, 0.8871760797342193
# 4944, balanced_in_on, SVC, 0.84, 0.84
# 4944, balanced_in_in, SVC, 0.88, 0.8238297872340425
# 5923, base_on, GradientBoostingClassifier, 0.96, 0.953758865248227
# 5923, base_in, GradientBoostingClassifier, 0.96, 0.953758865248227
# 5923, base_on, DecisionTreeClassifier, 0.88, 0.8906666666666666
# 5923, base_in, DecisionTreeClassifier, 0.88, 0.8906666666666666
# 5923, base_on, SVC, 0.92, 0.8816666666666667
# 5923, base_in, SVC, 0.92, 0.8816666666666667
# 5923, random_selected_on, GradientBoostingClassifier, 0.88, 0.8906666666666666
# 5923, random_selected_in, GradientBoostingClassifier, 0.84, 0.84
# 5923, random_selected_on, DecisionTreeClassifier, 0.8, 0.8177777777777778
# 5923, random_selected_in, DecisionTreeClassifier, 0.88, 0.8612765957446809
# 5923, random_selected_on, SVC, 0.92, 0.8816666666666667
# 5923, random_selected_in, SVC, 0.92, 0.8816666666666667
# 5923, proportional_selected_on, GradientBoostingClassifier, 0.88, 0.8612765957446809
# 5923, proportional_selected_in, GradientBoostingClassifier, 0.8, 0.8177777777777778
# 5923, proportional_selected_on, DecisionTreeClassifier, 0.84, 0.8630303030303029
# 5923, proportional_selected_in, DecisionTreeClassifier, 0.8, 0.8358803986710965
# 5923, proportional_selected_on, SVC, 0.92, 0.8816666666666667
# 5923, proportional_selected_in, SVC, 0.92, 0.8816666666666667
# 5923, fewest_selected_on, GradientBoostingClassifier, 0.92, 0.8816666666666667
# 5923, fewest_selected_in, GradientBoostingClassifier, 0.84, 0.84
# 5923, fewest_selected_on, DecisionTreeClassifier, 0.84, 0.8630303030303029
# 5923, fewest_selected_in, DecisionTreeClassifier, 0.8, 0.8177777777777778
# 5923, fewest_selected_on, SVC, 0.92, 0.8816666666666667
# 5923, fewest_selected_in, SVC, 0.92, 0.8816666666666667
# 5923, representative_selected_on, GradientBoostingClassifier, 0.88, 0.8612765957446809
# 5923, representative_selected_in, GradientBoostingClassifier, 0.92, 0.92
# 5923, representative_selected_on, DecisionTreeClassifier, 0.92, 0.92
# 5923, representative_selected_in, DecisionTreeClassifier, 0.92, 0.92
# 5923, representative_selected_on, SVC, 0.92, 0.8816666666666667
# 5923, representative_selected_in, SVC, 0.92, 0.8816666666666667
# 5923, balanced_on_on, GradientBoostingClassifier, 0.96, 0.953758865248227
# 5923, balanced_on_in, GradientBoostingClassifier, 0.96, 0.953758865248227
# 5923, balanced_on_on, DecisionTreeClassifier, 0.92, 0.92
# 5923, balanced_on_in, DecisionTreeClassifier, 0.92, 0.92
# 5923, balanced_on_on, SVC, 0.96, 0.953758865248227
# 5923, balanced_on_in, SVC, 0.92, 0.8816666666666667
# 5923, balanced_in_on, GradientBoostingClassifier, 0.96, 0.953758865248227
# 5923, balanced_in_in, GradientBoostingClassifier, 0.96, 0.953758865248227
# 5923, balanced_in_on, DecisionTreeClassifier, 0.92, 0.92
# 5923, balanced_in_in, DecisionTreeClassifier, 0.92, 0.92
# 5923, balanced_in_on, SVC, 0.96, 0.953758865248227
# 5923, balanced_in_in, SVC, 0.92, 0.8816666666666667
# 781, base_on, GradientBoostingClassifier, 0.875, 0.8166666666666668
# 781, base_in, GradientBoostingClassifier, 0.875, 0.8166666666666668
# 781, base_on, DecisionTreeClassifier, 0.75, 0.775
# 781, base_in, DecisionTreeClassifier, 0.75, 0.775
# 781, base_on, SVC, 0.875, 0.8166666666666668
# 781, base_in, SVC, 0.875, 0.8166666666666668
# 781, random_selected_on, GradientBoostingClassifier, 0.8333333333333334, 0.7954545454545453
# 781, random_selected_in, GradientBoostingClassifier, 0.7916666666666666, 0.7732558139534884
# 781, random_selected_on, DecisionTreeClassifier, 0.7916666666666666, 0.7732558139534884
# 781, random_selected_in, DecisionTreeClassifier, 0.75, 0.75
# 781, random_selected_on, SVC, 0.875, 0.8166666666666668
# 781, random_selected_in, SVC, 0.875, 0.8166666666666668
# 781, proportional_selected_on, GradientBoostingClassifier, 0.75, 0.75
# 781, proportional_selected_in, GradientBoostingClassifier, 0.7916666666666666, 0.7732558139534884
# 781, proportional_selected_on, DecisionTreeClassifier, 0.75, 0.775
# 781, proportional_selected_in, DecisionTreeClassifier, 0.75, 0.75
# 781, proportional_selected_on, SVC, 0.875, 0.8166666666666668
# 781, proportional_selected_in, SVC, 0.875, 0.8166666666666668
# 781, fewest_selected_on, GradientBoostingClassifier, 0.7916666666666666, 0.7732558139534884
# 781, fewest_selected_in, GradientBoostingClassifier, 0.7916666666666666, 0.7732558139534884
# 781, fewest_selected_on, DecisionTreeClassifier, 0.6666666666666666, 0.7000000000000001
# 781, fewest_selected_in, DecisionTreeClassifier, 0.6666666666666666, 0.7000000000000001
# 781, fewest_selected_on, SVC, 0.875, 0.8166666666666668
# 781, fewest_selected_in, SVC, 0.875, 0.8166666666666668
# 781, representative_selected_on, GradientBoostingClassifier, 0.8333333333333334, 0.7954545454545453
# 781, representative_selected_in, GradientBoostingClassifier, 0.7916666666666666, 0.7732558139534884
# 781, representative_selected_on, DecisionTreeClassifier, 0.875, 0.863953488372093
# 781, representative_selected_in, DecisionTreeClassifier, 0.8333333333333334, 0.7954545454545453
# 781, representative_selected_on, SVC, 0.875, 0.8166666666666668
# 781, representative_selected_in, SVC, 0.875, 0.8166666666666668
# 781, balanced_on_on, GradientBoostingClassifier, 0.875, 0.8166666666666668
# 781, balanced_on_in, GradientBoostingClassifier, 0.7916666666666666, 0.7732558139534884
# 781, balanced_on_on, DecisionTreeClassifier, 0.875, 0.863953488372093
# 781, balanced_on_in, DecisionTreeClassifier, 0.75, 0.75
# 781, balanced_on_on, SVC, 0.8333333333333334, 0.7954545454545453
# 781, balanced_on_in, SVC, 0.875, 0.8166666666666668
# 781, balanced_in_on, GradientBoostingClassifier, 0.875, 0.8166666666666668
# 781, balanced_in_in, GradientBoostingClassifier, 0.7916666666666666, 0.7732558139534884
# 781, balanced_in_on, DecisionTreeClassifier, 0.875, 0.863953488372093
# 781, balanced_in_in, DecisionTreeClassifier, 0.75, 0.75
# 781, balanced_in_on, SVC, 0.8333333333333334, 0.7954545454545453
# 781, balanced_in_in, SVC, 0.875, 0.8166666666666668
# 6406, base_on, GradientBoostingClassifier, 0.84, 0.8076190476190476
# 6406, base_in, GradientBoostingClassifier, 0.84, 0.8076190476190476
# 6406, base_on, DecisionTreeClassifier, 0.8, 0.7739837398373984
# 6406, base_in, DecisionTreeClassifier, 0.8, 0.7739837398373984
# 6406, base_on, SVC, 0.76, 0.6563636363636364
# 6406, base_in, SVC, 0.76, 0.6563636363636364
# 6406, random_selected_on, GradientBoostingClassifier, 0.76, 0.6563636363636364
# 6406, random_selected_in, GradientBoostingClassifier, 0.76, 0.7114285714285714
# 6406, random_selected_on, DecisionTreeClassifier, 0.84, 0.8076190476190476
# 6406, random_selected_in, DecisionTreeClassifier, 0.72, 0.6835772357723577
# 6406, random_selected_on, SVC, 0.76, 0.6563636363636364
# 6406, random_selected_in, SVC, 0.76, 0.6563636363636364
# 6406, proportional_selected_on, GradientBoostingClassifier, 0.76, 0.6563636363636364
# 6406, proportional_selected_in, GradientBoostingClassifier, 0.8, 0.7401993355481729
# 6406, proportional_selected_on, DecisionTreeClassifier, 0.76, 0.7114285714285714
# 6406, proportional_selected_in, DecisionTreeClassifier, 0.76, 0.7114285714285714
# 6406, proportional_selected_on, SVC, 0.76, 0.6563636363636364
# 6406, proportional_selected_in, SVC, 0.76, 0.6563636363636364
# 6406, fewest_selected_on, GradientBoostingClassifier, 0.76, 0.6563636363636364
# 6406, fewest_selected_in, GradientBoostingClassifier, 0.76, 0.6563636363636364
# 6406, fewest_selected_on, DecisionTreeClassifier, 0.76, 0.7114285714285714
# 6406, fewest_selected_in, DecisionTreeClassifier, 0.76, 0.7114285714285714
# 6406, fewest_selected_on, SVC, 0.76, 0.6563636363636364
# 6406, fewest_selected_in, SVC, 0.76, 0.6563636363636364
# 6406, representative_selected_on, GradientBoostingClassifier, 0.8, 0.7401993355481729
# 6406, representative_selected_in, GradientBoostingClassifier, 0.76, 0.6563636363636364
# 6406, representative_selected_on, DecisionTreeClassifier, 0.76, 0.7114285714285714
# 6406, representative_selected_in, DecisionTreeClassifier, 0.76, 0.7114285714285714
# 6406, representative_selected_on, SVC, 0.76, 0.6563636363636364
# 6406, representative_selected_in, SVC, 0.76, 0.6563636363636364
# 6406, balanced_on_on, GradientBoostingClassifier, 0.8, 0.7401993355481729
# 6406, balanced_on_in, GradientBoostingClassifier, 0.8, 0.7401993355481729
# 6406, balanced_on_on, DecisionTreeClassifier, 0.68, 0.6560000000000001
# 6406, balanced_on_in, DecisionTreeClassifier, 0.8, 0.7401993355481729
# 6406, balanced_on_on, SVC, 0.72, 0.636279069767442
# 6406, balanced_on_in, SVC, 0.76, 0.6563636363636364
# 6406, balanced_in_on, GradientBoostingClassifier, 0.8, 0.7401993355481729
# 6406, balanced_in_in, GradientBoostingClassifier, 0.8, 0.7401993355481729
# 6406, balanced_in_on, DecisionTreeClassifier, 0.68, 0.6560000000000001
# 6406, balanced_in_in, DecisionTreeClassifier, 0.8, 0.7401993355481729
# 6406, balanced_in_on, SVC, 0.72, 0.636279069767442
# 6406, balanced_in_in, SVC, 0.76, 0.6563636363636364
# 2862, base_on, GradientBoostingClassifier, 0.75, 0.7999999999999999
# 2862, base_in, GradientBoostingClassifier, 0.75, 0.7999999999999999
# 2862, base_on, DecisionTreeClassifier, 0.75, 0.7999999999999999
# 2862, base_in, DecisionTreeClassifier, 0.75, 0.7999999999999999
# 2862, base_on, SVC, 0.9166666666666666, 0.8768115942028986
# 2862, base_in, SVC, 0.9166666666666666, 0.8768115942028986
# 2862, random_selected_on, GradientBoostingClassifier, 0.8333333333333334, 0.8571428571428572
# 2862, random_selected_in, GradientBoostingClassifier, 0.7916666666666666, 0.8286875725900117
# 2862, random_selected_on, DecisionTreeClassifier, 0.8333333333333334, 0.8571428571428572
# 2862, random_selected_in, DecisionTreeClassifier, 0.7083333333333334, 0.7601626016260163
# 2862, random_selected_on, SVC, 0.9166666666666666, 0.8768115942028986
# 2862, random_selected_in, SVC, 0.9166666666666666, 0.8768115942028986
# 2862, proportional_selected_on, GradientBoostingClassifier, 0.7916666666666666, 0.810077519379845
# 2862, proportional_selected_in, GradientBoostingClassifier, 0.7916666666666666, 0.8286875725900117
# 2862, proportional_selected_on, DecisionTreeClassifier, 0.875, 0.886046511627907
# 2862, proportional_selected_in, DecisionTreeClassifier, 0.7916666666666666, 0.810077519379845
# 2862, proportional_selected_on, SVC, 0.9166666666666666, 0.8768115942028986
# 2862, proportional_selected_in, SVC, 0.9166666666666666, 0.8768115942028986
# 2862, fewest_selected_on, GradientBoostingClassifier, 0.875, 0.886046511627907
# 2862, fewest_selected_in, GradientBoostingClassifier, 0.75, 0.7857142857142857
# 2862, fewest_selected_on, DecisionTreeClassifier, 0.75, 0.7999999999999999
# 2862, fewest_selected_in, DecisionTreeClassifier, 0.9166666666666666, 0.9166666666666666
# 2862, fewest_selected_on, SVC, 0.9166666666666666, 0.8768115942028986
# 2862, fewest_selected_in, SVC, 0.9166666666666666, 0.8768115942028986
# 2862, representative_selected_on, GradientBoostingClassifier, 0.75, 0.7857142857142857
# 2862, representative_selected_in, GradientBoostingClassifier, 0.7916666666666666, 0.810077519379845
# 2862, representative_selected_on, DecisionTreeClassifier, 0.75, 0.7857142857142857
# 2862, representative_selected_in, DecisionTreeClassifier, 0.75, 0.7857142857142857
# 2862, representative_selected_on, SVC, 0.9166666666666666, 0.8768115942028986
# 2862, representative_selected_in, SVC, 0.9166666666666666, 0.8768115942028986
# 2862, balanced_on_on, GradientBoostingClassifier, 0.875, 0.886046511627907
# 2862, balanced_on_in, GradientBoostingClassifier, 0.75, 0.7857142857142857
# 2862, balanced_on_on, DecisionTreeClassifier, 0.75, 0.7999999999999999
# 2862, balanced_on_in, DecisionTreeClassifier, 0.75, 0.7857142857142857
# 2862, balanced_on_on, SVC, 0.875, 0.8555555555555555
# 2862, balanced_on_in, SVC, 0.9166666666666666, 0.8768115942028986
# 2862, balanced_in_on, GradientBoostingClassifier, 0.875, 0.886046511627907
# 2862, balanced_in_in, GradientBoostingClassifier, 0.75, 0.7857142857142857
# 2862, balanced_in_on, DecisionTreeClassifier, 0.75, 0.7999999999999999
# 2862, balanced_in_in, DecisionTreeClassifier, 0.75, 0.7857142857142857
# 2862, balanced_in_on, SVC, 0.875, 0.8555555555555555
# 2862, balanced_in_in, SVC, 0.9166666666666666, 0.8768115942028986
# 899, base_on, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 899, base_in, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 899, base_on, DecisionTreeClassifier, 0.88, 0.8693333333333332
# 899, base_in, DecisionTreeClassifier, 0.88, 0.8693333333333332
# 899, base_on, SVC, 0.88, 0.8238297872340425
# 899, base_in, SVC, 0.88, 0.8238297872340425
# 899, random_selected_on, GradientBoostingClassifier, 0.84, 0.8034782608695652
# 899, random_selected_in, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 899, random_selected_on, DecisionTreeClassifier, 0.72, 0.7367441860465117
# 899, random_selected_in, DecisionTreeClassifier, 0.8, 0.7822222222222223
# 899, random_selected_on, SVC, 0.88, 0.8238297872340425
# 899, random_selected_in, SVC, 0.88, 0.8238297872340425
# 899, proportional_selected_on, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 899, proportional_selected_in, GradientBoostingClassifier, 0.84, 0.8034782608695652
# 899, proportional_selected_on, DecisionTreeClassifier, 0.8, 0.7822222222222223
# 899, proportional_selected_in, DecisionTreeClassifier, 0.84, 0.8034782608695652
# 899, proportional_selected_on, SVC, 0.88, 0.8238297872340425
# 899, proportional_selected_in, SVC, 0.88, 0.8238297872340425
# 899, fewest_selected_on, GradientBoostingClassifier, 0.84, 0.8034782608695652
# 899, fewest_selected_in, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 899, fewest_selected_on, DecisionTreeClassifier, 0.68, 0.7123809523809524
# 899, fewest_selected_in, DecisionTreeClassifier, 0.76, 0.7842857142857143
# 899, fewest_selected_on, SVC, 0.88, 0.8238297872340425
# 899, fewest_selected_in, SVC, 0.88, 0.8238297872340425
# 899, representative_selected_on, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 899, representative_selected_in, GradientBoostingClassifier, 0.84, 0.8034782608695652
# 899, representative_selected_on, DecisionTreeClassifier, 0.8, 0.7822222222222223
# 899, representative_selected_in, DecisionTreeClassifier, 0.84, 0.8034782608695652
# 899, representative_selected_on, SVC, 0.88, 0.8238297872340425
# 899, representative_selected_in, SVC, 0.88, 0.8238297872340425
# 899, balanced_on_on, GradientBoostingClassifier, 0.84, 0.8034782608695652
# 899, balanced_on_in, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 899, balanced_on_on, DecisionTreeClassifier, 0.84, 0.8034782608695652
# 899, balanced_on_in, DecisionTreeClassifier, 0.84, 0.8034782608695652
# 899, balanced_on_on, SVC, 0.84, 0.8034782608695652
# 899, balanced_on_in, SVC, 0.88, 0.8238297872340425
# 899, balanced_in_on, GradientBoostingClassifier, 0.84, 0.8034782608695652
# 899, balanced_in_in, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 899, balanced_in_on, DecisionTreeClassifier, 0.84, 0.8034782608695652
# 899, balanced_in_in, DecisionTreeClassifier, 0.84, 0.8034782608695652
# 899, balanced_in_on, SVC, 0.84, 0.8034782608695652
# 899, balanced_in_in, SVC, 0.88, 0.8238297872340425

# %%
import csv

# Specify the file path to save the CSV file
file_path = "traffic_results.csv"

# Write the list to a CSV file
with open(file_path, mode="w", newline="") as file:
    writer = csv.writer(file)
    for item in final_results:
        writer.writerow(item.split(", "))
