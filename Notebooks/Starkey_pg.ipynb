# %%
from ptrail.core.Datasets import Datasets
from ptrail.features.kinematic_features import KinematicFeatures

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import f1_score, accuracy_score
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

from src.utils.general_utils import Utilities
from TestUtils.test_utils import TestUtils
from TestUtils.Keys import *

# %%
starkey_dataset = Datasets.load_starkey()
ready_dataset = KinematicFeatures.create_distance_column(starkey_dataset)
# Out:
# ------------------------ Dataset Facts ------------------------------
#
# Number of unique Trajectories in the data: 253
# Number of points in the data: 287136
# Dataset time range: 1196 days 22:51:45
# Datatype of the DataFrame: <class 'ptrail.core.TrajectoryDF.PTRAILDataFrame'>
# Dataset Bounding Box: (45.18896978643169, -118.61020848239596, 45.314545642992, -118.50455596234036)
#
# ---------------------------------------------------------------------

# %%
# Get the 20 seed values that we are going to use.
seed_generator = Utilities.generate_pi_seed(20)
seed_vals = [next(seed_generator) for i in range(20)]
final_results = ["seed, strategy, model, accuracy, f1_score"]

# All our selection strategies.
select_strategies = [
    BASE, BALANCED_IN, BALANCED_ON, BALANCED_DROP, BALANCED_STRETCH
]

models = [GradientBoostingClassifier(), DecisionTreeClassifier(), SVC()]

for seed in seed_vals:
    iter_map = TestUtils.get_iterable_map(ready_dataset, seed, 'Species')
    for select_strategy in select_strategies:
        for model in models:
            train_x, train_y = TestUtils.select_correct_test_train_split(iter_map, select_strategy,
                                                                         BASE, 'Species', 3)
            if (train_x is not None) and (train_y is not None):
                # Fit the model and predict.
                model.random_state = seed
                model.fit(X=train_x, y=train_y)
                pred_vals = model.predict(X=iter_map[TEST_X])

                # Calculate the accuracy and f1 score.
                acc = accuracy_score(y_true=iter_map[TEST_Y], y_pred=pred_vals)
                score = f1_score(y_true=iter_map[TEST_Y], y_pred=pred_vals, average='weighted')
                if 'balanced' not in select_strategy:
                    print(f"{seed}, base, {model.__class__.__name__}, {acc}, {score}")
                    final_results.append(f"{seed}, base,"f" {model.__class__.__name__}, {acc}, {score}")
                else:
                    print(f"{seed}, {select_strategy}, {model.__class__.__name__}, {acc}, {score}")
                    final_results.append(f"{seed}, {select_strategy},"f" {model.__class__.__name__}, {acc}, {score}")
# Out:
# 1415, base, GradientBoostingClassifier, 0.9411764705882353, 0.94213898743228
# 1415, base, DecisionTreeClassifier, 0.9215686274509803, 0.9203891803400677
# 1415, base, SVC, 0.7450980392156863, 0.7311415794387932
# 1415, balanced_in, GradientBoostingClassifier, 0.9607843137254902, 0.9607843137254902
# 1415, balanced_in, DecisionTreeClassifier, 0.8823529411764706, 0.8812215082111277
# 1415, balanced_in, SVC, 0.7647058823529411, 0.7586945592060681
# 1415, balanced_on, GradientBoostingClassifier, 0.9215686274509803, 0.9207683073229292
# 1415, balanced_on, DecisionTreeClassifier, 0.8627450980392157, 0.8605576104681223
# 1415, balanced_on, SVC, 0.47058823529411764, 0.30117647058823527
# 1415, balanced_drop, GradientBoostingClassifier, 0.9607843137254902, 0.9607855185084787
# 1415, balanced_drop, DecisionTreeClassifier, 0.8235294117647058, 0.8212942465988953
# 1415, balanced_drop, SVC, 0.7843137254901961, 0.7826831882178158
# 1415, balanced_stretch, GradientBoostingClassifier, 0.8823529411764706, 0.8813071895424837
# 1415, balanced_stretch, DecisionTreeClassifier, 0.9803921568627451, 0.980125383486728
# 1415, balanced_stretch, SVC, 0.7058823529411765, 0.6884859206840631
# 9265, base, GradientBoostingClassifier, 0.9215686274509803, 0.9220235408741502
# 9265, base, DecisionTreeClassifier, 0.9411764705882353, 0.9405300581771169
# 9265, base, SVC, 0.6666666666666666, 0.6464850415584027
# 9265, balanced_in, GradientBoostingClassifier, 0.9019607843137255, 0.9058710840658102
# 9265, balanced_in, DecisionTreeClassifier, 0.8431372549019608, 0.8452380952380952
# 9265, balanced_in, SVC, 0.7450980392156863, 0.7402232210713743
# 9265, balanced_on, GradientBoostingClassifier, 0.9411764705882353, 0.9421171767057648
# 9265, balanced_on, DecisionTreeClassifier, 0.8627450980392157, 0.863862186553782
# 9265, balanced_on, SVC, 0.5098039215686274, 0.4058271195802265
# 9265, balanced_drop, GradientBoostingClassifier, 0.9215686274509803, 0.9234360410830998
# 9265, balanced_drop, DecisionTreeClassifier, 0.9019607843137255, 0.9047142261159784
# 9265, balanced_drop, SVC, 0.803921568627451, 0.8023408638817846
# 9265, balanced_stretch, GradientBoostingClassifier, 0.9215686274509803, 0.9215686274509803
# 9265, balanced_stretch, DecisionTreeClassifier, 0.8627450980392157, 0.8599078928904027
# 9265, balanced_stretch, SVC, 0.6078431372549019, 0.5945378151260504
# 3589, base, GradientBoostingClassifier, 0.9411764705882353, 0.9416912017645035
# 3589, base, DecisionTreeClassifier, 0.8235294117647058, 0.8320454281419312
# 3589, base, SVC, 0.6862745098039216, 0.6628248587570621
# 3589, balanced_in, GradientBoostingClassifier, 0.8823529411764706, 0.8843326804405972
# 3589, balanced_in, DecisionTreeClassifier, 0.8823529411764706, 0.8854791916766707
# 3589, balanced_in, SVC, 0.6078431372549019, 0.5926992584059326
# 3589, balanced_on, GradientBoostingClassifier, 0.9215686274509803, 0.9222253494699315
# 3589, balanced_on, DecisionTreeClassifier, 0.8627450980392157, 0.8667357852231802
# 3589, balanced_on, SVC, 0.5098039215686274, 0.3889873757722267
# 3589, balanced_drop, GradientBoostingClassifier, 0.8823529411764706, 0.8830586414132217
# 3589, balanced_drop, DecisionTreeClassifier, 0.8431372549019608, 0.8426129810212856
# 3589, balanced_drop, SVC, 0.6274509803921569, 0.6212577714012434
# 3589, balanced_stretch, GradientBoostingClassifier, 0.8823529411764706, 0.8823529411764706
# 3589, balanced_stretch, DecisionTreeClassifier, 0.803921568627451, 0.8105965790571549
# 3589, balanced_stretch, SVC, 0.6274509803921569, 0.6225867910178305
# 7932, base, GradientBoostingClassifier, 0.8235294117647058, 0.8202138790374085
# 7932, base, DecisionTreeClassifier, 0.8823529411764706, 0.8781275751914875
# 7932, base, SVC, 0.6274509803921569, 0.6097536450477626
# 7932, balanced_in, GradientBoostingClassifier, 0.8823529411764706, 0.8834995986698774
# 7932, balanced_in, DecisionTreeClassifier, 0.8627450980392157, 0.8589979721307509
# 7932, balanced_in, SVC, 0.6470588235294118, 0.6504987960096319
# 7932, balanced_on, GradientBoostingClassifier, 0.9019607843137255, 0.9020725099156472
# 7932, balanced_on, DecisionTreeClassifier, 0.8235294117647058, 0.8216619981325863
# 7932, balanced_on, SVC, 0.3333333333333333, 0.16666666666666666
# 7932, balanced_drop, GradientBoostingClassifier, 0.8823529411764706, 0.8834799711992695
# 7932, balanced_drop, DecisionTreeClassifier, 0.7843137254901961, 0.7866070404770096
# 7932, balanced_drop, SVC, 0.6862745098039216, 0.6915393183151363
# 7932, balanced_stretch, GradientBoostingClassifier, 0.8823529411764706, 0.8824111560953666
# 7932, balanced_stretch, DecisionTreeClassifier, 0.7843137254901961, 0.7829641978248788
# 7932, balanced_stretch, SVC, 0.6078431372549019, 0.5938997821350762
# 3846, base, GradientBoostingClassifier, 0.9019607843137255, 0.8918248226206704
# 3846, base, DecisionTreeClassifier, 0.8823529411764706, 0.8785332314744079
# 3846, base, SVC, 0.7647058823529411, 0.7611800939281186
# 3846, balanced_in, GradientBoostingClassifier, 0.9019607843137255, 0.8918248226206704
# 3846, balanced_in, DecisionTreeClassifier, 0.7647058823529411, 0.7732351982826366
# 3846, balanced_in, SVC, 0.7058823529411765, 0.7176663768955858
# 3846, balanced_on, GradientBoostingClassifier, 0.9019607843137255, 0.8918248226206704
# 3846, balanced_on, DecisionTreeClassifier, 0.7647058823529411, 0.7649167193759225
# 3846, balanced_on, SVC, 0.6862745098039216, 0.657481010422187
# 3846, balanced_drop, GradientBoostingClassifier, 0.9019607843137255, 0.8922688230646708
# 3846, balanced_drop, DecisionTreeClassifier, 0.8823529411764706, 0.8735548911141539
# 3846, balanced_drop, SVC, 0.6666666666666666, 0.6766483683256584
# 3846, balanced_stretch, GradientBoostingClassifier, 0.8823529411764706, 0.8738489988251413
# 3846, balanced_stretch, DecisionTreeClassifier, 0.8431372549019608, 0.8301069723369987
# 3846, balanced_stretch, SVC, 0.7254901960784313, 0.7279178338001868
# 2643, base, GradientBoostingClassifier, 0.9803921568627451, 0.9811652259470097
# 2643, base, DecisionTreeClassifier, 0.9019607843137255, 0.9122239017713883
# 2643, base, SVC, 0.7254901960784313, 0.7105809223456282
# 2643, balanced_in, GradientBoostingClassifier, 1.0, 1.0
# 2643, balanced_in, DecisionTreeClassifier, 0.9215686274509803, 0.9241830065359479
# 2643, balanced_in, SVC, 0.7254901960784313, 0.7276535565493254
# 2643, balanced_on, GradientBoostingClassifier, 1.0, 1.0
# 2643, balanced_on, DecisionTreeClassifier, 0.8431372549019608, 0.8456489118503077
# 2643, balanced_on, SVC, 0.5882352941176471, 0.4502541757443718
# 2643, balanced_drop, GradientBoostingClassifier, 1.0, 1.0
# 2643, balanced_drop, DecisionTreeClassifier, 0.9215686274509803, 0.9314372065012174
# 2643, balanced_drop, SVC, 0.7450980392156863, 0.7473719709013826
# 2643, balanced_stretch, GradientBoostingClassifier, 0.9803921568627451, 0.9805285253694125
# 2643, balanced_stretch, DecisionTreeClassifier, 0.9607843137254902, 0.9615573828097548
# 2643, balanced_stretch, SVC, 0.7450980392156863, 0.7434514366296492
# 3832, base, GradientBoostingClassifier, 0.9411764705882353, 0.9438771822165214
# 3832, base, DecisionTreeClassifier, 0.8627450980392157, 0.8598817304699657
# 3832, base, SVC, 0.7647058823529411, 0.7561497326203208
# 3832, balanced_in, GradientBoostingClassifier, 0.9607843137254902, 0.9623093681917211
# 3832, balanced_in, DecisionTreeClassifier, 0.8823529411764706, 0.8844328473916085
# 3832, balanced_in, SVC, 0.6666666666666666, 0.6716883436148392
# 3832, balanced_on, GradientBoostingClassifier, 0.9411764705882353, 0.9424803169349582
# 3832, balanced_on, DecisionTreeClassifier, 0.8823529411764706, 0.8810457516339869
# 3832, balanced_on, SVC, 0.7058823529411765, 0.6518518518518519
# 3832, balanced_drop, GradientBoostingClassifier, 0.9803921568627451, 0.9805426006719824
# 3832, balanced_drop, DecisionTreeClassifier, 0.8235294117647058, 0.8281045751633987
# 3832, balanced_drop, SVC, 0.6666666666666666, 0.6705653021442495
# 3832, balanced_stretch, GradientBoostingClassifier, 0.9607843137254902, 0.9611804317686671
# 3832, balanced_stretch, DecisionTreeClassifier, 0.8823529411764706, 0.8827047727303482
# 3832, balanced_stretch, SVC, 0.7058823529411765, 0.703527787926765
# 7950, base, GradientBoostingClassifier, 0.8823529411764706, 0.8833492798550779
# 7950, base, DecisionTreeClassifier, 0.8431372549019608, 0.8428296808919646
# 7950, base, SVC, 0.7450980392156863, 0.7300232635427052
# 7950, balanced_in, GradientBoostingClassifier, 0.8823529411764706, 0.8833492798550779
# 7950, balanced_in, DecisionTreeClassifier, 0.803921568627451, 0.8135254101640657
# 7950, balanced_in, SVC, 0.6666666666666666, 0.6655794490587983
# 7950, balanced_on, GradientBoostingClassifier, 0.9215686274509803, 0.922167848463664
# 7950, balanced_on, DecisionTreeClassifier, 0.7647058823529411, 0.7650519031141868
# 7950, balanced_on, SVC, 0.5098039215686274, 0.34428316781257956
# 7950, balanced_drop, GradientBoostingClassifier, 0.8823529411764706, 0.882439253213247
# 7950, balanced_drop, DecisionTreeClassifier, 0.8431372549019608, 0.843959711544192
# 7950, balanced_drop, SVC, 0.6666666666666666, 0.6660843904125118
# 7950, balanced_stretch, GradientBoostingClassifier, 0.9019607843137255, 0.9022753486421307
# 7950, balanced_stretch, DecisionTreeClassifier, 0.7254901960784313, 0.7532647462732482
# 7950, balanced_stretch, SVC, 0.7254901960784313, 0.7125396577729235
# 2884, base, GradientBoostingClassifier, 0.9411764705882353, 0.9407486631016041
# 2884, base, DecisionTreeClassifier, 0.8627450980392157, 0.8609377664109121
# 2884, base, SVC, 0.7254901960784313, 0.7163013125126784
# 2884, balanced_in, GradientBoostingClassifier, 0.9215686274509803, 0.919711362805992
# 2884, balanced_in, DecisionTreeClassifier, 0.8431372549019608, 0.8385026737967914
# 2884, balanced_in, SVC, 0.6666666666666666, 0.6769987544736469
# 2884, balanced_on, GradientBoostingClassifier, 0.9411764705882353, 0.9400759513291481
# 2884, balanced_on, DecisionTreeClassifier, 0.8823529411764706, 0.8829744728079912
# 2884, balanced_on, SVC, 0.5490196078431373, 0.4298039215686274
# 2884, balanced_drop, GradientBoostingClassifier, 0.9411764705882353, 0.9400759513291481
# 2884, balanced_drop, DecisionTreeClassifier, 0.9019607843137255, 0.9034953111679455
# 2884, balanced_drop, SVC, 0.6470588235294118, 0.6595206825385854
# 2884, balanced_stretch, GradientBoostingClassifier, 0.9607843137254902, 0.959572192513369
# 2884, balanced_stretch, DecisionTreeClassifier, 0.8235294117647058, 0.8179898532839709
# 2884, balanced_stretch, SVC, 0.6274509803921569, 0.6301884390119684
# 1971, base, GradientBoostingClassifier, 0.9215686274509803, 0.9174030902683654
# 1971, base, DecisionTreeClassifier, 0.8627450980392157, 0.8627689663814401
# 1971, base, SVC, 0.6862745098039216, 0.6789592760180996
# 1971, balanced_in, GradientBoostingClassifier, 0.9215686274509803, 0.9203732830030408
# 1971, balanced_in, DecisionTreeClassifier, 0.8431372549019608, 0.8457350272232305
# 1971, balanced_in, SVC, 0.5882352941176471, 0.5964363348922996
# 1971, balanced_on, GradientBoostingClassifier, 0.8823529411764706, 0.8792910125927204
# 1971, balanced_on, DecisionTreeClassifier, 0.8431372549019608, 0.8412011863568957
# 1971, balanced_on, SVC, 0.5098039215686274, 0.4356351236146632
# 1971, balanced_drop, GradientBoostingClassifier, 0.9019607843137255, 0.8947368421052633
# 1971, balanced_drop, DecisionTreeClassifier, 0.8627450980392157, 0.8566176470588235
# 1971, balanced_drop, SVC, 0.6078431372549019, 0.6138541389406441
# 1971, balanced_stretch, GradientBoostingClassifier, 0.8627450980392157, 0.856283422459893
# 1971, balanced_stretch, DecisionTreeClassifier, 0.8431372549019608, 0.8400491126241768
# 1971, balanced_stretch, SVC, 0.6274509803921569, 0.6261501210653753
# 6939, base, GradientBoostingClassifier, 0.9215686274509803, 0.9242226183402653
# 6939, base, DecisionTreeClassifier, 0.8627450980392157, 0.868997668997669
# 6939, base, SVC, 0.7450980392156863, 0.7284313725490196
# 6939, balanced_in, GradientBoostingClassifier, 0.9215686274509803, 0.9247639796659405
# 6939, balanced_in, DecisionTreeClassifier, 0.8823529411764706, 0.8902939868533654
# 6939, balanced_in, SVC, 0.7058823529411765, 0.7095845331139449
# 6939, balanced_on, GradientBoostingClassifier, 0.9215686274509803, 0.9213719343536788
# 6939, balanced_on, DecisionTreeClassifier, 0.8235294117647058, 0.8400871459694988
# 6939, balanced_on, SVC, 0.5490196078431373, 0.3891784561926036
# 6939, balanced_drop, GradientBoostingClassifier, 0.9607843137254902, 0.9607843137254902
# 6939, balanced_drop, DecisionTreeClassifier, 0.8627450980392157, 0.8700072621641249
# 6939, balanced_drop, SVC, 0.7450980392156863, 0.7471593765711413
# 6939, balanced_stretch, GradientBoostingClassifier, 0.9215686274509803, 0.9215686274509803
# 6939, balanced_stretch, DecisionTreeClassifier, 0.803921568627451, 0.7560114159921296
# 6939, balanced_stretch, SVC, 0.7450980392156863, 0.7307911875385923
# 9375, base, GradientBoostingClassifier, 0.9019607843137255, 0.8997629680741634
# 9375, base, DecisionTreeClassifier, 0.8627450980392157, 0.8600607690121758
# 9375, base, SVC, 0.6470588235294118, 0.6178409825468648
# 9375, balanced_in, GradientBoostingClassifier, 0.9019607843137255, 0.89760348583878
# 9375, balanced_in, DecisionTreeClassifier, 0.8823529411764706, 0.8784335349800246
# 9375, balanced_in, SVC, 0.6666666666666666, 0.6682910464890442
# 9375, balanced_on, GradientBoostingClassifier, 0.9019607843137255, 0.89760348583878
# 9375, balanced_on, DecisionTreeClassifier, 0.8823529411764706, 0.8779956427015251
# 9375, balanced_on, SVC, 0.43137254901960786, 0.29705408733541727
# 9375, balanced_drop, GradientBoostingClassifier, 0.8823529411764706, 0.8804091333503098
# 9375, balanced_drop, DecisionTreeClassifier, 0.8823529411764706, 0.8799053983444711
# 9375, balanced_drop, SVC, 0.7058823529411765, 0.7054729584141348
# 9375, balanced_stretch, GradientBoostingClassifier, 0.8823529411764706, 0.8784335349800246
# 9375, balanced_stretch, DecisionTreeClassifier, 0.8235294117647058, 0.8198332206445795
# 9375, balanced_stretch, SVC, 0.6666666666666666, 0.6633685268979386
# 1058, base, GradientBoostingClassifier, 0.9019607843137255, 0.9001960784313726
# 1058, base, DecisionTreeClassifier, 0.8235294117647058, 0.8194444444444443
# 1058, base, SVC, 0.6666666666666666, 0.6223514193829904
# 1058, balanced_in, GradientBoostingClassifier, 0.9215686274509803, 0.9211123843476784
# 1058, balanced_in, DecisionTreeClassifier, 0.9215686274509803, 0.9252129134482076
# 1058, balanced_in, SVC, 0.6470588235294118, 0.63828197945845
# 1058, balanced_on, GradientBoostingClassifier, 0.9019607843137255, 0.9004709727028067
# 1058, balanced_on, DecisionTreeClassifier, 0.803921568627451, 0.803921568627451
# 1058, balanced_on, SVC, 0.45098039215686275, 0.31089324618736386
# 1058, balanced_drop, GradientBoostingClassifier, 0.9019607843137255, 0.9021968403548319
# 1058, balanced_drop, DecisionTreeClassifier, 0.803921568627451, 0.8109741920483609
# 1058, balanced_drop, SVC, 0.7254901960784313, 0.7243305984756052
# 1058, balanced_stretch, GradientBoostingClassifier, 0.9411764705882353, 0.9405184295940598
# 1058, balanced_stretch, DecisionTreeClassifier, 0.8431372549019608, 0.8435107376283847
# 1058, balanced_stretch, SVC, 0.6470588235294118, 0.6183391003460207
# 2097, base, GradientBoostingClassifier, 0.9607843137254902, 0.9625090777051563
# 2097, base, DecisionTreeClassifier, 0.9215686274509803, 0.9249902505102118
# 2097, base, SVC, 0.7254901960784313, 0.7163132862930023
# 2097, balanced_in, GradientBoostingClassifier, 0.9607843137254902, 0.9625090777051563
# 2097, balanced_in, DecisionTreeClassifier, 0.9215686274509803, 0.9249902505102118
# 2097, balanced_in, SVC, 0.7058823529411765, 0.6983144134846921
# 2097, balanced_on, GradientBoostingClassifier, 0.9607843137254902, 0.9625090777051563
# 2097, balanced_on, DecisionTreeClassifier, 0.9019607843137255, 0.9034986543637062
# 2097, balanced_on, SVC, 0.6078431372549019, 0.5036119711042312
# 2097, balanced_drop, GradientBoostingClassifier, 1.0, 1.0
# 2097, balanced_drop, DecisionTreeClassifier, 0.9607843137254902, 0.9607843137254902
# 2097, balanced_drop, SVC, 0.6862745098039216, 0.679647206770642
# 2097, balanced_stretch, GradientBoostingClassifier, 1.0, 1.0
# 2097, balanced_stretch, DecisionTreeClassifier, 0.9215686274509803, 0.927266633148986
# 2097, balanced_stretch, SVC, 0.7254901960784313, 0.720199190787426
# 4944, base, GradientBoostingClassifier, 0.8823529411764706, 0.880409479025396
# 4944, base, DecisionTreeClassifier, 0.8235294117647058, 0.8241295561744545
# 4944, base, SVC, 0.6862745098039216, 0.6650980392156863
# 4944, balanced_in, GradientBoostingClassifier, 0.9215686274509803, 0.9213956170703576
# 4944, balanced_in, DecisionTreeClassifier, 0.8823529411764706, 0.8841467829655398
# 4944, balanced_in, SVC, 0.6862745098039216, 0.6694661709425443
# 4944, balanced_on, GradientBoostingClassifier, 0.9019607843137255, 0.9015256177885936
# 4944, balanced_on, DecisionTreeClassifier, 0.7254901960784313, 0.7256929921289783
# 4944, balanced_on, SVC, 0.37254901960784315, 0.2022408963585434
# 4944, balanced_drop, GradientBoostingClassifier, 0.9019607843137255, 0.9022508815909103
# 4944, balanced_drop, DecisionTreeClassifier, 0.8823529411764706, 0.8833297421532715
# 4944, balanced_drop, SVC, 0.7058823529411765, 0.6995836172306761
# 4944, balanced_stretch, GradientBoostingClassifier, 0.9019607843137255, 0.9008446789568542
# 4944, balanced_stretch, DecisionTreeClassifier, 0.7647058823529411, 0.7630303030303031
# 4944, balanced_stretch, SVC, 0.6666666666666666, 0.6570172228435535
# 5923, base, GradientBoostingClassifier, 0.9411764705882353, 0.9383833305401933
# 5923, base, DecisionTreeClassifier, 0.8627450980392157, 0.866995337583573
# 5923, base, SVC, 0.6666666666666666, 0.6287673111202523
# 5923, balanced_in, GradientBoostingClassifier, 0.9411764705882353, 0.9383833305401933
# 5923, balanced_in, DecisionTreeClassifier, 0.9215686274509803, 0.923006802585049
# 5923, balanced_in, SVC, 0.7254901960784313, 0.7320966122297976
# 5923, balanced_on, GradientBoostingClassifier, 0.9411764705882353, 0.9430032552878514
# 5923, balanced_on, DecisionTreeClassifier, 0.8431372549019608, 0.8453159041394336
# 5923, balanced_on, SVC, 0.5098039215686274, 0.3787865222192377
# 5923, balanced_drop, GradientBoostingClassifier, 0.9607843137254902, 0.9607179107734046
# 5923, balanced_drop, DecisionTreeClassifier, 0.9411764705882353, 0.9404441515168159
# 5923, balanced_drop, SVC, 0.6862745098039216, 0.6882268058738649
# 5923, balanced_stretch, GradientBoostingClassifier, 0.9803921568627451, 0.979487811896247
# 5923, balanced_stretch, DecisionTreeClassifier, 0.9019607843137255, 0.903880433292198
# 5923, balanced_stretch, SVC, 0.6470588235294118, 0.6127765208647561
# 781, base, GradientBoostingClassifier, 0.9215686274509803, 0.9182024161015757
# 781, base, DecisionTreeClassifier, 0.9019607843137255, 0.893534165093126
# 781, base, SVC, 0.5882352941176471, 0.5776401788785689
# 781, balanced_in, GradientBoostingClassifier, 0.9215686274509803, 0.9182024161015757
# 781, balanced_in, DecisionTreeClassifier, 0.9019607843137255, 0.893534165093126
# 781, balanced_in, SVC, 0.6078431372549019, 0.6030897207367796
# 781, balanced_on, GradientBoostingClassifier, 0.8627450980392157, 0.8520208083233294
# 781, balanced_on, DecisionTreeClassifier, 0.8823529411764706, 0.8672853131246244
# 781, balanced_on, SVC, 0.5490196078431373, 0.45588235294117646
# 781, balanced_drop, GradientBoostingClassifier, 0.9411764705882353, 0.937094837935174
# 781, balanced_drop, DecisionTreeClassifier, 0.9019607843137255, 0.8997030601977962
# 781, balanced_drop, SVC, 0.6078431372549019, 0.6030501089324618
# 781, balanced_stretch, GradientBoostingClassifier, 0.9215686274509803, 0.9124162485507022
# 781, balanced_stretch, DecisionTreeClassifier, 0.7843137254901961, 0.7873093681917211
# 781, balanced_stretch, SVC, 0.5686274509803921, 0.5636395290635677
# 6406, base, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, base, DecisionTreeClassifier, 0.803921568627451, 0.8019559730050378
# 6406, base, SVC, 0.6862745098039216, 0.6757066462948815
# 6406, balanced_in, GradientBoostingClassifier, 0.9215686274509803, 0.9215686274509803
# 6406, balanced_in, DecisionTreeClassifier, 0.8823529411764706, 0.8839837675882731
# 6406, balanced_in, SVC, 0.6666666666666666, 0.6599631305513659
# 6406, balanced_on, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, balanced_on, DecisionTreeClassifier, 0.8823529411764706, 0.8812388591800356
# 6406, balanced_on, SVC, 0.5490196078431373, 0.453781512605042
# 6406, balanced_drop, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, balanced_drop, DecisionTreeClassifier, 0.7647058823529411, 0.7713875148168015
# 6406, balanced_drop, SVC, 0.7450980392156863, 0.7446311858076564
# 6406, balanced_stretch, GradientBoostingClassifier, 0.9411764705882353, 0.940497938305757
# 6406, balanced_stretch, DecisionTreeClassifier, 0.8431372549019608, 0.8472412220702235
# 6406, balanced_stretch, SVC, 0.6666666666666666, 0.6706142867704267
# 2862, base, GradientBoostingClassifier, 0.8823529411764706, 0.8807088366822478
# 2862, base, DecisionTreeClassifier, 0.8823529411764706, 0.8839883428118722
# 2862, base, SVC, 0.7254901960784313, 0.7048887939930963
# 2862, balanced_in, GradientBoostingClassifier, 0.9215686274509803, 0.920667957585511
# 2862, balanced_in, DecisionTreeClassifier, 0.8823529411764706, 0.8805882352941177
# 2862, balanced_in, SVC, 0.7647058823529411, 0.7647058823529411
# 2862, balanced_on, GradientBoostingClassifier, 0.9411764705882353, 0.9405184295940598
# 2862, balanced_on, DecisionTreeClassifier, 0.9215686274509803, 0.920667957585511
# 2862, balanced_on, SVC, 0.43137254901960786, 0.2718237980123557
# 2862, balanced_drop, GradientBoostingClassifier, 0.9019607843137255, 0.9024413687043445
# 2862, balanced_drop, DecisionTreeClassifier, 0.8431372549019608, 0.8515151515151514
# 2862, balanced_drop, SVC, 0.7450980392156863, 0.7481877599524658
# 2862, balanced_stretch, GradientBoostingClassifier, 0.9019607843137255, 0.9037674310441741
# 2862, balanced_stretch, DecisionTreeClassifier, 0.8823529411764706, 0.8860730062776099
# 2862, balanced_stretch, SVC, 0.7843137254901961, 0.7780038331121923
# 899, base, GradientBoostingClassifier, 0.9019607843137255, 0.9083488599059533
# 899, base, DecisionTreeClassifier, 0.8627450980392157, 0.8673317280128425
# 899, base, SVC, 0.6666666666666666, 0.6367231638418079
# 899, balanced_in, GradientBoostingClassifier, 0.9607843137254902, 0.9607843137254902
# 899, balanced_in, DecisionTreeClassifier, 0.9019607843137255, 0.9108867338120529
# 899, balanced_in, SVC, 0.6078431372549019, 0.5955302551127977
# 899, balanced_on, GradientBoostingClassifier, 0.9607843137254902, 0.9607843137254902
# 899, balanced_on, DecisionTreeClassifier, 0.8235294117647058, 0.829093507112083
# 899, balanced_on, SVC, 0.45098039215686275, 0.28033916269210385
# 899, balanced_drop, GradientBoostingClassifier, 0.9411764705882353, 0.9428981348637017
# 899, balanced_drop, DecisionTreeClassifier, 0.8235294117647058, 0.829093507112083
# 899, balanced_drop, SVC, 0.7254901960784313, 0.7273533847928312
# 899, balanced_stretch, GradientBoostingClassifier, 0.9019607843137255, 0.9058823529411765
# 899, balanced_stretch, DecisionTreeClassifier, 0.7843137254901961, 0.798086124401914
# 899, balanced_stretch, SVC, 0.5882352941176471, 0.5581861227463121

# %%
TestUtils.write_csv_file('./balance_starkey.csv', final_results)
# Out:
# File successfully written to: ./balance_starkey.csv
