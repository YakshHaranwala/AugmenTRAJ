# %%
from ptrail.core.Datasets import Datasets
from ptrail.features.kinematic_features import KinematicFeatures

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import f1_score, accuracy_score
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

from src.utils.general_utils import Utilities
from TestUtils.test_utils import TestUtils
from TestUtils.Keys import *

# %%
traffic_data = Datasets.load_traffic_data()
ready_dataset = KinematicFeatures.create_distance_column(traffic_data)
ready_dataset
# Out:
# ------------------------ Dataset Facts ------------------------------
#
# Number of unique Trajectories in the data: 125
# Number of points in the data: 44905
# Dataset time range: 0 days 00:00:59.900000
# Datatype of the DataFrame: <class 'ptrail.core.TrajectoryDF.PTRAILDataFrame'>
# Dataset Bounding Box: (34.7107417, 135.4640652, 34.7156517, 135.4702002)
#
# ---------------------------------------------------------------------
#                                  vehicle_type  velocity  traffic_lane  \
# traj_id DateTime
# 1371    1900-01-01 07:30:00.000             1      48.0             2
#         1900-01-01 07:30:00.100             1      47.9             2
#         1900-01-01 07:30:00.200             1      47.9             2
#         1900-01-01 07:30:00.300             1      47.9             2
#         1900-01-01 07:30:00.400             1      47.9             2
# ...                                       ...       ...           ...
# 3357    1900-01-01 07:30:59.500             1      27.7             1
#         1900-01-01 07:30:59.600             1      27.7             1
#         1900-01-01 07:30:59.700             1      29.0             1
#         1900-01-01 07:30:59.800             1      30.3             1
#         1900-01-01 07:30:59.900             1      31.0             1
#
#                                         lon        lat  kilopost  \
# traj_id DateTime
# 1371    1900-01-01 07:30:00.000  135.469950  34.710999    3539.5
#         1900-01-01 07:30:00.100  135.469957  34.710991    3532.5
#         1900-01-01 07:30:00.200  135.469963  34.710984    3532.5
#         1900-01-01 07:30:00.300  135.469968  34.710979    3531.5
#         1900-01-01 07:30:00.400  135.469972  34.710974    3530.8
# ...                                     ...        ...       ...
# 3357    1900-01-01 07:30:59.500  135.468970  34.712177    3697.6
#         1900-01-01 07:30:59.600  135.468975  34.712172    3696.6
#         1900-01-01 07:30:59.700  135.468981  34.712166    3695.6
#         1900-01-01 07:30:59.800  135.468986  34.712160    3694.7
#         1900-01-01 07:30:59.900  135.468992  34.712154    3693.7
#
#                                  vehicle_length  detected_flag  Distance
# traj_id DateTime
# 1371    1900-01-01 07:30:00.000             3.0              0       NaN
#         1900-01-01 07:30:00.100             3.0              0  1.115504
#         1900-01-01 07:30:00.200             3.0              0  0.939478
#         1900-01-01 07:30:00.300             3.0              0  0.763477
#         1900-01-01 07:30:00.400             3.0              0  0.596403
# ...                                         ...            ...       ...
# 3357    1900-01-01 07:30:59.500             3.5              0  0.737022
#         1900-01-01 07:30:59.600             3.5              1  0.760166
#         1900-01-01 07:30:59.700             3.5              1  0.788944
#         1900-01-01 07:30:59.800             3.5              1  0.835374
#         1900-01-01 07:30:59.900             3.5              1  0.873034
#
# [44905 rows x 9 columns]

# %%
# Get the 20 seed values that we are going to use.
seed_generator = Utilities.generate_pi_seed(20)
seed_vals = [next(seed_generator) for i in range(20)]
final_results = ["seed, strategy, model, accuracy, f1_score"]

# All our selection strategies.
select_strategies = [
    BASE, BALANCED_ON, BALANCED_IN, BALANCED_DROP, BALANCED_STRETCH
]

augment_strategies = [
    ON, IN, DROP, STRETCH
]

models = [GradientBoostingClassifier(), DecisionTreeClassifier(), SVC()]

for seed in seed_vals:
    # Get the iterable map for the seed.
    iter_map = TestUtils.get_iterable_map(ready_dataset, seed, 'vehicle_type')
    for select_strategy in select_strategies:
        for model in models:
            if select_strategy != BASE and 'balanced' not in select_strategy:
                for augment_strategy in augment_strategies:
                    train_x, train_y = TestUtils.select_correct_test_train_split(iter_map, select_strategy,
                                                                                 augment_strategy, 'vehicle_type', 3)
                    if (train_x is not None) and (train_y is not None):
                        # Fit the model and predict.
                        model.random_state = seed
                        model.fit(X=train_x, y=train_y)
                        pred_vals = model.predict(X=iter_map[TEST_X])

                        # Calculate the accuracy and f1 score.
                        acc = accuracy_score(y_true=iter_map[TEST_Y], y_pred=pred_vals)
                        score = f1_score(y_true=iter_map[TEST_Y], y_pred=pred_vals, average='weighted')
                        print(f"{seed}, {select_strategy}_{augment_strategy}, {model.__class__.__name__}, {acc}, {score}")
                        final_results.append(f"{seed}, {select_strategy}_{augment_strategy}, {model.__class__.__name__}, {acc}, {score}")
            else:
                train_x, train_y = TestUtils.select_correct_test_train_split(iter_map, select_strategy,
                                                                             BASE, 'vehicle_type', 3)
                if (train_x is not None) and (train_y is not None):
                    # Fit the model and predict.
                    model.random_state = seed
                    model.fit(X=train_x, y=train_y)
                    pred_vals = model.predict(X=iter_map[TEST_X])

                    # Calculate the accuracy and f1 score.
                    acc = accuracy_score(y_true=iter_map[TEST_Y], y_pred=pred_vals)
                    score = f1_score(y_true=iter_map[TEST_Y], y_pred=pred_vals, average='weighted')
                    if 'balanced' not in select_strategy:
                        print(f"{seed}, base, {model.__class__.__name__}, {acc}, {score}")
                        final_results.append(f"{seed}, base,"f" {model.__class__.__name__}, {acc}, {score}")
                    else:
                        print(f"{seed}, {select_strategy}, {model.__class__.__name__}, {acc}, {score}")
                        final_results.append(f"{seed}, {select_strategy},"f" {model.__class__.__name__}, {acc}, {score}")
# Out:
# 1415, base, GradientBoostingClassifier, 0.875, 0.8944444444444444
# 1415, base, DecisionTreeClassifier, 0.875, 0.8944444444444444
# 1415, base, SVC, 0.9583333333333334, 0.9379432624113475
# 1415, balanced_on, GradientBoostingClassifier, 0.9166666666666666, 0.9166666666666666
# 1415, balanced_on, DecisionTreeClassifier, 0.9166666666666666, 0.9166666666666666
# 1415, balanced_on, SVC, 0.9166666666666666, 0.9166666666666666
# 1415, balanced_in, GradientBoostingClassifier, 0.9583333333333334, 0.9379432624113475
# 1415, balanced_in, DecisionTreeClassifier, 0.7916666666666666, 0.8533681765389084
# 1415, balanced_in, SVC, 0.9583333333333334, 0.9379432624113475
# 1415, balanced_drop, GradientBoostingClassifier, 0.9583333333333334, 0.9379432624113475
# 1415, balanced_drop, DecisionTreeClassifier, 0.7916666666666666, 0.8468992248062017
# 1415, balanced_drop, SVC, 0.5833333333333334, 0.6990740740740741
# 1415, balanced_stretch, GradientBoostingClassifier, 0.9166666666666666, 0.9166666666666666
# 1415, balanced_stretch, DecisionTreeClassifier, 0.8333333333333334, 0.8712121212121211
# 1415, balanced_stretch, SVC, 0.9583333333333334, 0.9379432624113475
# 9265, base, GradientBoostingClassifier, 0.92, 0.92
# 9265, base, DecisionTreeClassifier, 0.92, 0.92
# 9265, base, SVC, 0.96, 0.9404081632653061
# 9265, balanced_on, GradientBoostingClassifier, 0.96, 0.9404081632653061
# 9265, balanced_on, DecisionTreeClassifier, 0.84, 0.8765217391304347
# 9265, balanced_on, SVC, 0.96, 0.9404081632653061
# 9265, balanced_in, GradientBoostingClassifier, 1.0, 1.0
# 9265, balanced_in, DecisionTreeClassifier, 0.88, 0.898723404255319
# 9265, balanced_in, SVC, 0.96, 0.9404081632653061
# 9265, balanced_drop, GradientBoostingClassifier, 0.92, 0.92
# 9265, balanced_drop, DecisionTreeClassifier, 0.92, 0.92
# 9265, balanced_drop, SVC, 0.56, 0.6807484407484408
# 9265, balanced_stretch, GradientBoostingClassifier, 1.0, 1.0
# 9265, balanced_stretch, DecisionTreeClassifier, 0.92, 0.92
# 9265, balanced_stretch, SVC, 0.96, 0.9404081632653061
# 3589, base, GradientBoostingClassifier, 0.92, 0.92
# 3589, base, DecisionTreeClassifier, 0.84, 0.8765217391304347
# 3589, base, SVC, 0.96, 0.9404081632653061
# 3589, balanced_on, GradientBoostingClassifier, 0.96, 0.9404081632653061
# 3589, balanced_on, DecisionTreeClassifier, 0.88, 0.898723404255319
# 3589, balanced_on, SVC, 0.88, 0.898723404255319
# 3589, balanced_in, GradientBoostingClassifier, 0.92, 0.92
# 3589, balanced_in, DecisionTreeClassifier, 0.84, 0.8765217391304347
# 3589, balanced_in, SVC, 0.96, 0.9404081632653061
# 3589, balanced_drop, GradientBoostingClassifier, 0.92, 0.92
# 3589, balanced_drop, DecisionTreeClassifier, 0.84, 0.8765217391304347
# 3589, balanced_drop, SVC, 0.92, 0.92
# 3589, balanced_stretch, GradientBoostingClassifier, 0.92, 0.92
# 3589, balanced_stretch, DecisionTreeClassifier, 0.88, 0.898723404255319
# 3589, balanced_stretch, SVC, 0.96, 0.9404081632653061
# 7932, base, GradientBoostingClassifier, 0.76, 0.7254545454545455
# 7932, base, DecisionTreeClassifier, 0.8, 0.8086720867208672
# 7932, base, SVC, 0.84, 0.7669565217391304
# 7932, balanced_on, GradientBoostingClassifier, 0.8, 0.7466666666666667
# 7932, balanced_on, DecisionTreeClassifier, 0.72, 0.7032558139534884
# 7932, balanced_on, SVC, 0.88, 0.8480000000000001
# 7932, balanced_in, GradientBoostingClassifier, 0.8, 0.7466666666666667
# 7932, balanced_in, DecisionTreeClassifier, 0.84, 0.7669565217391304
# 7932, balanced_in, SVC, 0.84, 0.7669565217391304
# 7932, balanced_drop, GradientBoostingClassifier, 0.8, 0.7466666666666667
# 7932, balanced_drop, DecisionTreeClassifier, 0.84, 0.7669565217391304
# 7932, balanced_drop, SVC, 0.56, 0.6148856548856547
# 7932, balanced_stretch, GradientBoostingClassifier, 0.76, 0.7254545454545455
# 7932, balanced_stretch, DecisionTreeClassifier, 0.72, 0.7032558139534884
# 7932, balanced_stretch, SVC, 0.84, 0.7669565217391304
# 3846, base, GradientBoostingClassifier, 0.92, 0.9084848484848485
# 3846, base, DecisionTreeClassifier, 0.8, 0.8086720867208672
# 3846, base, SVC, 0.84, 0.7669565217391304
# 3846, balanced_on, GradientBoostingClassifier, 0.88, 0.8480000000000001
# 3846, balanced_on, DecisionTreeClassifier, 0.76, 0.76
# 3846, balanced_on, SVC, 0.84, 0.7669565217391304
# 3846, balanced_in, GradientBoostingClassifier, 0.88, 0.8480000000000001
# 3846, balanced_in, DecisionTreeClassifier, 0.88, 0.8480000000000001
# 3846, balanced_in, SVC, 0.84, 0.7669565217391304
# 3846, balanced_drop, GradientBoostingClassifier, 0.88, 0.8480000000000001
# 3846, balanced_drop, DecisionTreeClassifier, 0.88, 0.8480000000000001
# 3846, balanced_drop, SVC, 0.76, 0.76
# 3846, balanced_stretch, GradientBoostingClassifier, 0.88, 0.8480000000000001
# 3846, balanced_stretch, DecisionTreeClassifier, 0.76, 0.76
# 3846, balanced_stretch, SVC, 0.84, 0.7669565217391304
# 2643, base, GradientBoostingClassifier, 0.92, 0.9017391304347826
# 2643, base, DecisionTreeClassifier, 0.92, 0.9017391304347826
# 2643, base, SVC, 0.88, 0.8238297872340425
# 2643, balanced_on, GradientBoostingClassifier, 0.92, 0.9017391304347826
# 2643, balanced_on, DecisionTreeClassifier, 0.84, 0.84
# 2643, balanced_on, SVC, 0.76, 0.76
# 2643, balanced_in, GradientBoostingClassifier, 0.92, 0.9017391304347826
# 2643, balanced_in, DecisionTreeClassifier, 0.8, 0.8119601328903654
# 2643, balanced_in, SVC, 0.88, 0.8238297872340425
# 2643, balanced_drop, GradientBoostingClassifier, 0.88, 0.8693333333333332
# 2643, balanced_drop, DecisionTreeClassifier, 0.92, 0.9017391304347826
# 2643, balanced_drop, SVC, 0.52, 0.6038095238095237
# 2643, balanced_stretch, GradientBoostingClassifier, 0.84, 0.84
# 2643, balanced_stretch, DecisionTreeClassifier, 0.88, 0.8693333333333332
# 2643, balanced_stretch, SVC, 0.88, 0.8238297872340425
# 3832, base, GradientBoostingClassifier, 0.875, 0.8675958188153309
# 3832, base, DecisionTreeClassifier, 0.8333333333333334, 0.8095238095238094
# 3832, base, SVC, 0.8333333333333334, 0.7575757575757575
# 3832, balanced_on, GradientBoostingClassifier, 0.875, 0.8418604651162792
# 3832, balanced_on, DecisionTreeClassifier, 0.7916666666666666, 0.7793263646922183
# 3832, balanced_on, SVC, 0.8333333333333334, 0.7575757575757575
# 3832, balanced_in, GradientBoostingClassifier, 0.9166666666666666, 0.9047619047619048
# 3832, balanced_in, DecisionTreeClassifier, 0.8333333333333334, 0.8095238095238094
# 3832, balanced_in, SVC, 0.8333333333333334, 0.7575757575757575
# 3832, balanced_drop, GradientBoostingClassifier, 0.8333333333333334, 0.8095238095238094
# 3832, balanced_drop, DecisionTreeClassifier, 0.8333333333333334, 0.8095238095238094
# 3832, balanced_drop, SVC, 0.5416666666666666, 0.5970695970695971
# 3832, balanced_stretch, GradientBoostingClassifier, 0.875, 0.8675958188153309
# 3832, balanced_stretch, DecisionTreeClassifier, 0.75, 0.75
# 3832, balanced_stretch, SVC, 0.8333333333333334, 0.7575757575757575
# 7950, base, GradientBoostingClassifier, 0.8, 0.7880398671096346
# 7950, base, DecisionTreeClassifier, 0.76, 0.7254545454545455
# 7950, base, SVC, 0.84, 0.7669565217391304
# 7950, balanced_on, GradientBoostingClassifier, 0.84, 0.7669565217391304
# 7950, balanced_on, DecisionTreeClassifier, 0.68, 0.68
# 7950, balanced_on, SVC, 0.84, 0.8169696969696968
# 7950, balanced_in, GradientBoostingClassifier, 0.84, 0.8169696969696968
# 7950, balanced_in, DecisionTreeClassifier, 0.76, 0.7780000000000001
# 7950, balanced_in, SVC, 0.84, 0.7669565217391304
# 7950, balanced_drop, GradientBoostingClassifier, 0.84, 0.7669565217391304
# 7950, balanced_drop, DecisionTreeClassifier, 0.72, 0.7032558139534884
# 7950, balanced_drop, SVC, 0.52, 0.5828571428571429
# 7950, balanced_stretch, GradientBoostingClassifier, 0.76, 0.7254545454545455
# 7950, balanced_stretch, DecisionTreeClassifier, 0.72, 0.7321409214092143
# 7950, balanced_stretch, SVC, 0.84, 0.7669565217391304
# 2884, base, GradientBoostingClassifier, 0.96, 0.9635555555555555
# 2884, base, DecisionTreeClassifier, 0.92, 0.9315151515151514
# 2884, base, SVC, 0.92, 0.8816666666666667
# 2884, balanced_on, GradientBoostingClassifier, 0.96, 0.9635555555555555
# 2884, balanced_on, DecisionTreeClassifier, 0.84, 0.8723809523809523
# 2884, balanced_on, SVC, 0.96, 0.953758865248227
# 2884, balanced_in, GradientBoostingClassifier, 1.0, 1.0
# 2884, balanced_in, DecisionTreeClassifier, 0.88, 0.9015282392026578
# 2884, balanced_in, SVC, 0.92, 0.8816666666666667
# 2884, balanced_drop, GradientBoostingClassifier, 0.88, 0.9015282392026578
# 2884, balanced_drop, DecisionTreeClassifier, 0.88, 0.9015282392026578
# 2884, balanced_drop, SVC, 0.56, 0.6605128205128206
# 2884, balanced_stretch, GradientBoostingClassifier, 0.92, 0.92
# 2884, balanced_stretch, DecisionTreeClassifier, 0.96, 0.9635555555555555
# 2884, balanced_stretch, SVC, 0.92, 0.8816666666666667
# 1971, base, GradientBoostingClassifier, 0.84, 0.8034782608695652
# 1971, base, DecisionTreeClassifier, 0.76, 0.76
# 1971, base, SVC, 0.88, 0.8238297872340425
# 1971, balanced_on, GradientBoostingClassifier, 0.92, 0.9017391304347826
# 1971, balanced_on, DecisionTreeClassifier, 0.8, 0.8119601328903654
# 1971, balanced_on, SVC, 0.88, 0.8238297872340425
# 1971, balanced_in, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 1971, balanced_in, DecisionTreeClassifier, 0.88, 0.8693333333333332
# 1971, balanced_in, SVC, 0.88, 0.8238297872340425
# 1971, balanced_drop, GradientBoostingClassifier, 0.84, 0.8034782608695652
# 1971, balanced_drop, DecisionTreeClassifier, 0.88, 0.8693333333333332
# 1971, balanced_drop, SVC, 0.84, 0.8034782608695652
# 1971, balanced_stretch, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 1971, balanced_stretch, DecisionTreeClassifier, 0.84, 0.8034782608695652
# 1971, balanced_stretch, SVC, 0.88, 0.8238297872340425
# 6939, base, GradientBoostingClassifier, 0.88, 0.8906666666666666
# 6939, base, DecisionTreeClassifier, 0.84, 0.8723809523809523
# 6939, base, SVC, 0.92, 0.8816666666666667
# 6939, balanced_on, GradientBoostingClassifier, 0.88, 0.8612765957446809
# 6939, balanced_on, DecisionTreeClassifier, 0.8, 0.8177777777777778
# 6939, balanced_on, SVC, 0.92, 0.8816666666666667
# 6939, balanced_in, GradientBoostingClassifier, 0.92, 0.8816666666666667
# 6939, balanced_in, DecisionTreeClassifier, 0.88, 0.8906666666666666
# 6939, balanced_in, SVC, 0.92, 0.8816666666666667
# 6939, balanced_drop, GradientBoostingClassifier, 0.88, 0.8612765957446809
# 6939, balanced_drop, DecisionTreeClassifier, 0.8, 0.8177777777777778
# 6939, balanced_drop, SVC, 0.68, 0.7447619047619048
# 6939, balanced_stretch, GradientBoostingClassifier, 0.84, 0.84
# 6939, balanced_stretch, DecisionTreeClassifier, 0.92, 0.92
# 6939, balanced_stretch, SVC, 0.92, 0.8816666666666667
# 9375, base, GradientBoostingClassifier, 0.88, 0.8906666666666666
# 9375, base, DecisionTreeClassifier, 0.84, 0.8630303030303029
# 9375, base, SVC, 0.92, 0.8816666666666667
# 9375, balanced_on, GradientBoostingClassifier, 0.88, 0.8906666666666666
# 9375, balanced_on, DecisionTreeClassifier, 0.88, 0.9015282392026578
# 9375, balanced_on, SVC, 0.84, 0.8630303030303029
# 9375, balanced_in, GradientBoostingClassifier, 0.88, 0.8906666666666666
# 9375, balanced_in, DecisionTreeClassifier, 0.84, 0.84
# 9375, balanced_in, SVC, 0.92, 0.8816666666666667
# 9375, balanced_drop, GradientBoostingClassifier, 0.88, 0.8906666666666666
# 9375, balanced_drop, DecisionTreeClassifier, 0.8, 0.8358803986710965
# 9375, balanced_drop, SVC, 0.56, 0.6587941787941786
# 9375, balanced_stretch, GradientBoostingClassifier, 0.92, 0.92
# 9375, balanced_stretch, DecisionTreeClassifier, 0.84, 0.84
# 9375, balanced_stretch, SVC, 0.92, 0.8816666666666667
# 1058, base, GradientBoostingClassifier, 0.88, 0.898723404255319
# 1058, base, DecisionTreeClassifier, 0.88, 0.898723404255319
# 1058, base, SVC, 0.96, 0.9404081632653061
# 1058, balanced_on, GradientBoostingClassifier, 0.88, 0.898723404255319
# 1058, balanced_on, DecisionTreeClassifier, 0.8, 0.8533333333333334
# 1058, balanced_on, SVC, 0.88, 0.898723404255319
# 1058, balanced_in, GradientBoostingClassifier, 0.96, 0.9404081632653061
# 1058, balanced_in, DecisionTreeClassifier, 0.84, 0.8765217391304347
# 1058, balanced_in, SVC, 0.96, 0.9404081632653061
# 1058, balanced_drop, GradientBoostingClassifier, 0.92, 0.92
# 1058, balanced_drop, DecisionTreeClassifier, 0.88, 0.898723404255319
# 1058, balanced_drop, SVC, 0.72, 0.8049864498644986
# 1058, balanced_stretch, GradientBoostingClassifier, 0.96, 0.9404081632653061
# 1058, balanced_stretch, DecisionTreeClassifier, 0.92, 0.92
# 1058, balanced_stretch, SVC, 0.96, 0.9404081632653061
# 2097, base, GradientBoostingClassifier, 0.875, 0.863953488372093
# 2097, base, DecisionTreeClassifier, 0.7916666666666666, 0.7732558139534884
# 2097, base, SVC, 0.875, 0.8166666666666668
# 2097, balanced_on, GradientBoostingClassifier, 0.875, 0.863953488372093
# 2097, balanced_on, DecisionTreeClassifier, 0.7916666666666666, 0.804006968641115
# 2097, balanced_on, SVC, 0.875, 0.8166666666666668
# 2097, balanced_in, GradientBoostingClassifier, 0.875, 0.8166666666666668
# 2097, balanced_in, DecisionTreeClassifier, 0.875, 0.8166666666666668
# 2097, balanced_in, SVC, 0.875, 0.8166666666666668
# 2097, balanced_drop, GradientBoostingClassifier, 0.875, 0.8166666666666668
# 2097, balanced_drop, DecisionTreeClassifier, 0.875, 0.863953488372093
# 2097, balanced_drop, SVC, 0.7916666666666666, 0.7732558139534884
# 2097, balanced_stretch, GradientBoostingClassifier, 0.875, 0.8166666666666668
# 2097, balanced_stretch, DecisionTreeClassifier, 0.7916666666666666, 0.7732558139534884
# 2097, balanced_stretch, SVC, 0.875, 0.8166666666666668
# 4944, base, GradientBoostingClassifier, 0.84, 0.84
# 4944, base, DecisionTreeClassifier, 0.84, 0.8561904761904762
# 4944, base, SVC, 0.88, 0.8238297872340425
# 4944, balanced_on, GradientBoostingClassifier, 0.92, 0.9017391304347826
# 4944, balanced_on, DecisionTreeClassifier, 0.8, 0.7822222222222223
# 4944, balanced_on, SVC, 0.84, 0.84
# 4944, balanced_in, GradientBoostingClassifier, 0.92, 0.9017391304347826
# 4944, balanced_in, DecisionTreeClassifier, 0.88, 0.8871760797342193
# 4944, balanced_in, SVC, 0.88, 0.8238297872340425
# 4944, balanced_drop, GradientBoostingClassifier, 0.92, 0.9017391304347826
# 4944, balanced_drop, DecisionTreeClassifier, 0.8, 0.8260162601626015
# 4944, balanced_drop, SVC, 0.64, 0.686829268292683
# 4944, balanced_stretch, GradientBoostingClassifier, 0.92, 0.9017391304347826
# 4944, balanced_stretch, DecisionTreeClassifier, 0.96, 0.9564444444444444
# 4944, balanced_stretch, SVC, 0.88, 0.8238297872340425
# 5923, base, GradientBoostingClassifier, 0.96, 0.953758865248227
# 5923, base, DecisionTreeClassifier, 0.88, 0.8906666666666666
# 5923, base, SVC, 0.92, 0.8816666666666667
# 5923, balanced_on, GradientBoostingClassifier, 0.96, 0.953758865248227
# 5923, balanced_on, DecisionTreeClassifier, 0.92, 0.92
# 5923, balanced_on, SVC, 0.96, 0.953758865248227
# 5923, balanced_in, GradientBoostingClassifier, 0.96, 0.953758865248227
# 5923, balanced_in, DecisionTreeClassifier, 0.92, 0.92
# 5923, balanced_in, SVC, 0.92, 0.8816666666666667
# 5923, balanced_drop, GradientBoostingClassifier, 0.96, 0.953758865248227
# 5923, balanced_drop, DecisionTreeClassifier, 0.8, 0.8433604336043362
# 5923, balanced_drop, SVC, 0.92, 0.8816666666666667
# 5923, balanced_stretch, GradientBoostingClassifier, 0.96, 0.953758865248227
# 5923, balanced_stretch, DecisionTreeClassifier, 0.92, 0.92
# 5923, balanced_stretch, SVC, 0.92, 0.8816666666666667
# 781, base, GradientBoostingClassifier, 0.875, 0.8166666666666668
# 781, base, DecisionTreeClassifier, 0.75, 0.775
# 781, base, SVC, 0.875, 0.8166666666666668
# 781, balanced_on, GradientBoostingClassifier, 0.875, 0.8166666666666668
# 781, balanced_on, DecisionTreeClassifier, 0.875, 0.863953488372093
# 781, balanced_on, SVC, 0.8333333333333334, 0.7954545454545453
# 781, balanced_in, GradientBoostingClassifier, 0.7916666666666666, 0.7732558139534884
# 781, balanced_in, DecisionTreeClassifier, 0.75, 0.75
# 781, balanced_in, SVC, 0.875, 0.8166666666666668
# 781, balanced_drop, GradientBoostingClassifier, 0.7916666666666666, 0.7732558139534884
# 781, balanced_drop, DecisionTreeClassifier, 0.9166666666666666, 0.8977272727272726
# 781, balanced_drop, SVC, 0.625, 0.6848894348894349
# 781, balanced_stretch, GradientBoostingClassifier, 0.75, 0.75
# 781, balanced_stretch, DecisionTreeClassifier, 0.7916666666666666, 0.804006968641115
# 781, balanced_stretch, SVC, 0.875, 0.8166666666666668
# 6406, base, GradientBoostingClassifier, 0.84, 0.8076190476190476
# 6406, base, DecisionTreeClassifier, 0.8, 0.7739837398373984
# 6406, base, SVC, 0.76, 0.6563636363636364
# 6406, balanced_on, GradientBoostingClassifier, 0.8, 0.7401993355481729
# 6406, balanced_on, DecisionTreeClassifier, 0.68, 0.6560000000000001
# 6406, balanced_on, SVC, 0.72, 0.636279069767442
# 6406, balanced_in, GradientBoostingClassifier, 0.8, 0.7401993355481729
# 6406, balanced_in, DecisionTreeClassifier, 0.8, 0.7401993355481729
# 6406, balanced_in, SVC, 0.76, 0.6563636363636364
# 6406, balanced_drop, GradientBoostingClassifier, 0.8, 0.7401993355481729
# 6406, balanced_drop, DecisionTreeClassifier, 0.76, 0.7114285714285714
# 6406, balanced_drop, SVC, 0.76, 0.6563636363636364
# 6406, balanced_stretch, GradientBoostingClassifier, 0.8, 0.7401993355481729
# 6406, balanced_stretch, DecisionTreeClassifier, 0.84, 0.8280000000000001
# 6406, balanced_stretch, SVC, 0.76, 0.6563636363636364
# 2862, base, GradientBoostingClassifier, 0.75, 0.7999999999999999
# 2862, base, DecisionTreeClassifier, 0.75, 0.7999999999999999
# 2862, base, SVC, 0.9166666666666666, 0.8768115942028986
# 2862, balanced_on, GradientBoostingClassifier, 0.875, 0.886046511627907
# 2862, balanced_on, DecisionTreeClassifier, 0.75, 0.7999999999999999
# 2862, balanced_on, SVC, 0.875, 0.8555555555555555
# 2862, balanced_in, GradientBoostingClassifier, 0.75, 0.7857142857142857
# 2862, balanced_in, DecisionTreeClassifier, 0.75, 0.7857142857142857
# 2862, balanced_in, SVC, 0.9166666666666666, 0.8768115942028986
# 2862, balanced_drop, GradientBoostingClassifier, 0.7916666666666666, 0.8286875725900117
# 2862, balanced_drop, DecisionTreeClassifier, 0.75, 0.7999999999999999
# 2862, balanced_drop, SVC, 0.4583333333333333, 0.5666666666666668
# 2862, balanced_stretch, GradientBoostingClassifier, 0.7916666666666666, 0.810077519379845
# 2862, balanced_stretch, DecisionTreeClassifier, 0.7916666666666666, 0.8286875725900117
# 2862, balanced_stretch, SVC, 0.9166666666666666, 0.8768115942028986
# 899, base, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 899, base, DecisionTreeClassifier, 0.88, 0.8693333333333332
# 899, base, SVC, 0.88, 0.8238297872340425
# 899, balanced_on, GradientBoostingClassifier, 0.84, 0.8034782608695652
# 899, balanced_on, DecisionTreeClassifier, 0.84, 0.8034782608695652
# 899, balanced_on, SVC, 0.84, 0.8034782608695652
# 899, balanced_in, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 899, balanced_in, DecisionTreeClassifier, 0.84, 0.8034782608695652
# 899, balanced_in, SVC, 0.88, 0.8238297872340425
# 899, balanced_drop, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 899, balanced_drop, DecisionTreeClassifier, 0.84, 0.84
# 899, balanced_drop, SVC, 0.88, 0.8238297872340425
# 899, balanced_stretch, GradientBoostingClassifier, 0.88, 0.8238297872340425
# 899, balanced_stretch, DecisionTreeClassifier, 0.88, 0.8238297872340425
# 899, balanced_stretch, SVC, 0.88, 0.8238297872340425

# %%
TestUtils.write_csv_file('./balance_traffic.csv', final_results)
# Out:
# File successfully written to: ./balance_traffic.csv
