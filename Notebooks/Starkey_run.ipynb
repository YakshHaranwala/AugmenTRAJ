# %%
from ptrail.core.Datasets import Datasets
from ptrail.features.kinematic_features import KinematicFeatures

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import f1_score, accuracy_score
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

from src.utils.general_utils import Utilities
from Test_Utils.test_utils import TestUtils
from Test_Utils.Keys import *

# %%
starkey_dataset = Datasets.load_starkey()
ready_dataset = KinematicFeatures.create_distance_column(starkey_dataset)
# Out:
# ------------------------ Dataset Facts ------------------------------
#
# Number of unique Trajectories in the data: 253
# Number of points in the data: 287136
# Dataset time range: 1196 days 22:51:45
# Datatype of the DataFrame: <class 'ptrail.core.TrajectoryDF.PTRAILDataFrame'>
# Dataset Bounding Box: (45.18896978643169, -118.61020848239596, 45.314545642992, -118.50455596234036)
#
# ---------------------------------------------------------------------

# %%
# Get the 20 seed values that we are going to use.
seed_generator = Utilities.generate_pi_seed(20)
seed_vals = [next(seed_generator) for i in range(20)]
final_results = ["seed, strategy, model, accuracy, f1_score"]

# All our selection strategies.
select_strategies = [
    BASE, RANDOM_SELECTED, PROPORTIONAL_SELECTED, FEWEST_SELECTED, REPRESENTATIVE_SELECTED, BALANCED_ON, BALANCED_IN
]

augment_strategies = [
    ON, IN, DROP, STRETCH
]

models = [GradientBoostingClassifier(), DecisionTreeClassifier(), SVC()]

for seed in seed_vals:
    # Get the iterable map for the seed.
    iter_map = TestUtils.get_iterable_map(ready_dataset, seed, 'Species')
    for select_strategy in select_strategies:
        for model in models:
            if select_strategy != BASE and 'balanced' not in select_strategy:
                for augment_strategy in augment_strategies:
                    train_x, train_y = TestUtils.select_correct_test_train_split(iter_map, select_strategy,
                                                                                 augment_strategy, 'Species', 1)
                    if (train_x is not None) and (train_y is not None):
                        # Fit the model and predict.
                        model.random_state = seed
                        model.fit(X=train_x, y=train_y)
                        pred_vals = model.predict(X=iter_map[TEST_X])

                        # Calculate the accuracy and f1 score.
                        acc = accuracy_score(y_true=iter_map[TEST_Y], y_pred=pred_vals)
                        score = f1_score(y_true=iter_map[TEST_Y], y_pred=pred_vals, average='weighted')
                        print(f"{seed}, {select_strategy}_{augment_strategy}, {model.__class__.__name__}, {acc}, {score}")
                        final_results.append(f"{seed}, {select_strategy}_{augment_strategy}, {model.__class__.__name__}, {acc}, {score}")
            else:
                train_x, train_y = TestUtils.select_correct_test_train_split(iter_map, select_strategy,
                                                                             BASE, 'Species', 1)
                if (train_x is not None) and (train_y is not None):
                    # Fit the model and predict.
                    model.random_state = seed
                    model.fit(X=train_x, y=train_y)
                    pred_vals = model.predict(X=iter_map[TEST_X])

                    # Calculate the accuracy and f1 score.
                    acc = accuracy_score(y_true=iter_map[TEST_Y], y_pred=pred_vals)
                    score = f1_score(y_true=iter_map[TEST_Y], y_pred=pred_vals, average='weighted')
                    if 'balanced' not in select_strategy:
                        print(f"{seed}, base, {model.__class__.__name__}, {acc}, {score}")
                        final_results.append(f"{seed}, base,"f" {model.__class__.__name__}, {acc}, {score}")
                    else:
                        print(f"{seed}, {select_strategy}, {model.__class__.__name__}, {acc}, {score}")
                        final_results.append(f"{seed}, {select_strategy},"f" {model.__class__.__name__}, {acc}, {score}")
# Out:
# 1415, base, GradientBoostingClassifier, 0.9411764705882353, 0.94213898743228
# 1415, base, DecisionTreeClassifier, 0.9215686274509803, 0.9203891803400677
# 1415, base, SVC, 0.7450980392156863, 0.7311415794387932
# 1415, random_selected_on, GradientBoostingClassifier, 0.9607843137254902, 0.9607843137254902
# 1415, random_selected_in, GradientBoostingClassifier, 0.9411764705882353, 0.94213898743228
# 1415, random_selected_drop, GradientBoostingClassifier, 0.9215686274509803, 0.9215686274509803
# 1415, random_selected_stretch, GradientBoostingClassifier, 0.9411764705882353, 0.9400000000000001
# 1415, random_selected_on, DecisionTreeClassifier, 0.8627450980392157, 0.8627450980392157
# 1415, random_selected_in, DecisionTreeClassifier, 0.9215686274509803, 0.9203891803400677
# 1415, random_selected_drop, DecisionTreeClassifier, 0.9019607843137255, 0.9011800849372007
# 1415, random_selected_stretch, DecisionTreeClassifier, 0.8627450980392157, 0.8607340372046255
# 1415, random_selected_on, SVC, 0.6274509803921569, 0.5187683871663356
# 1415, random_selected_in, SVC, 0.7843137254901961, 0.7737972381935231
# 1415, random_selected_drop, SVC, 0.7843137254901961, 0.7737972381935231
# 1415, random_selected_stretch, SVC, 0.7843137254901961, 0.7737972381935231
# 1415, proportional_selected_on, GradientBoostingClassifier, 0.9215686274509803, 0.9218300653594772
# 1415, proportional_selected_in, GradientBoostingClassifier, 0.8823529411764706, 0.8824700894850694
# 1415, proportional_selected_drop, GradientBoostingClassifier, 0.9215686274509803, 0.9215686274509803
# 1415, proportional_selected_stretch, GradientBoostingClassifier, 0.9215686274509803, 0.9203891803400677
# 1415, proportional_selected_on, DecisionTreeClassifier, 0.9019607843137255, 0.8996078431372548
# 1415, proportional_selected_in, DecisionTreeClassifier, 0.9019607843137255, 0.9011800849372007
# 1415, proportional_selected_drop, DecisionTreeClassifier, 0.9019607843137255, 0.9011800849372007
# 1415, proportional_selected_stretch, DecisionTreeClassifier, 0.9215686274509803, 0.9203891803400677
# 1415, proportional_selected_on, SVC, 0.5686274509803921, 0.45749299719887954
# 1415, proportional_selected_in, SVC, 0.7647058823529411, 0.749062443568132
# 1415, proportional_selected_drop, SVC, 0.7647058823529411, 0.749062443568132
# 1415, proportional_selected_stretch, SVC, 0.7254901960784313, 0.6950513538748834
# 1415, fewest_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.9011800849372007
# 1415, fewest_selected_in, GradientBoostingClassifier, 0.9607843137254902, 0.9607843137254902
# 1415, fewest_selected_drop, GradientBoostingClassifier, 0.9411764705882353, 0.9400729988965284
# 1415, fewest_selected_stretch, GradientBoostingClassifier, 0.9215686274509803, 0.9207683073229292
# 1415, fewest_selected_on, DecisionTreeClassifier, 0.9019607843137255, 0.8996078431372548
# 1415, fewest_selected_in, DecisionTreeClassifier, 0.9019607843137255, 0.9002267573696144
# 1415, fewest_selected_drop, DecisionTreeClassifier, 0.9215686274509803, 0.9215686274509803
# 1415, fewest_selected_stretch, DecisionTreeClassifier, 0.9215686274509803, 0.9215686274509803
# 1415, fewest_selected_on, SVC, 0.49019607843137253, 0.34215530409302036
# 1415, fewest_selected_in, SVC, 0.8235294117647058, 0.8197841374311963
# 1415, fewest_selected_drop, SVC, 0.8235294117647058, 0.8197841374311963
# 1415, fewest_selected_stretch, SVC, 0.803921568627451, 0.8041407867494823
# 1415, representative_selected_on, GradientBoostingClassifier, 0.9215686274509803, 0.9218300653594772
# 1415, representative_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9215686274509803
# 1415, representative_selected_drop, GradientBoostingClassifier, 0.9215686274509803, 0.9215686274509803
# 1415, representative_selected_stretch, GradientBoostingClassifier, 0.9411764705882353, 0.9400729988965284
# 1415, representative_selected_on, DecisionTreeClassifier, 0.8823529411764706, 0.8810190742963853
# 1415, representative_selected_in, DecisionTreeClassifier, 0.9019607843137255, 0.901581894957072
# 1415, representative_selected_drop, DecisionTreeClassifier, 0.8823529411764706, 0.8824346714813247
# 1415, representative_selected_stretch, DecisionTreeClassifier, 0.9019607843137255, 0.901581894957072
# 1415, representative_selected_on, SVC, 0.6666666666666666, 0.5988586347719473
# 1415, representative_selected_in, SVC, 0.7450980392156863, 0.7311415794387932
# 1415, representative_selected_drop, SVC, 0.7450980392156863, 0.7311415794387932
# 1415, representative_selected_stretch, SVC, 0.7254901960784313, 0.7055547856323939
# 1415, balanced_on, GradientBoostingClassifier, 0.9411764705882353, 0.94213898743228
# 1415, balanced_on, DecisionTreeClassifier, 0.9215686274509803, 0.9203891803400677
# 1415, balanced_on, SVC, 0.7450980392156863, 0.7311415794387932
# 1415, balanced_in, GradientBoostingClassifier, 0.9411764705882353, 0.94213898743228
# 1415, balanced_in, DecisionTreeClassifier, 0.9215686274509803, 0.9203891803400677
# 1415, balanced_in, SVC, 0.7450980392156863, 0.7311415794387932
# 9265, base, GradientBoostingClassifier, 0.9215686274509803, 0.9220235408741502
# 9265, base, DecisionTreeClassifier, 0.9411764705882353, 0.9405300581771169
# 9265, base, SVC, 0.6666666666666666, 0.6464850415584027
# 9265, random_selected_on, GradientBoostingClassifier, 0.9215686274509803, 0.9220235408741502
# 9265, random_selected_in, GradientBoostingClassifier, 0.9411764705882353, 0.9412469164989099
# 9265, random_selected_drop, GradientBoostingClassifier, 0.9411764705882353, 0.9405300581771169
# 9265, random_selected_stretch, GradientBoostingClassifier, 0.9215686274509803, 0.9234360410830998
# 9265, random_selected_on, DecisionTreeClassifier, 0.9019607843137255, 0.9010543209326171
# 9265, random_selected_in, DecisionTreeClassifier, 0.9411764705882353, 0.9405424368836671
# 9265, random_selected_drop, DecisionTreeClassifier, 0.8431372549019608, 0.8460683478627541
# 9265, random_selected_stretch, DecisionTreeClassifier, 0.9019607843137255, 0.8986898337734575
# 9265, random_selected_on, SVC, 0.6470588235294118, 0.6013480392156864
# 9265, random_selected_in, SVC, 0.6666666666666666, 0.6464850415584027
# 9265, random_selected_drop, SVC, 0.6666666666666666, 0.6464850415584027
# 9265, random_selected_stretch, SVC, 0.6470588235294118, 0.6189090328785187
# 9265, proportional_selected_on, GradientBoostingClassifier, 0.9411764705882353, 0.9414151055959911
# 9265, proportional_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9220235408741502
# 9265, proportional_selected_drop, GradientBoostingClassifier, 0.9411764705882353, 0.9405300581771169
# 9265, proportional_selected_stretch, GradientBoostingClassifier, 0.9215686274509803, 0.9234360410830998
# 9265, proportional_selected_on, DecisionTreeClassifier, 0.8627450980392157, 0.8616178976165462
# 9265, proportional_selected_in, DecisionTreeClassifier, 0.9411764705882353, 0.9412469164989099
# 9265, proportional_selected_drop, DecisionTreeClassifier, 0.8235294117647058, 0.8309272426919486
# 9265, proportional_selected_stretch, DecisionTreeClassifier, 0.8823529411764706, 0.8842203548085901
# 9265, proportional_selected_on, SVC, 0.6078431372549019, 0.5687293099057806
# 9265, proportional_selected_in, SVC, 0.6666666666666666, 0.6545377044098272
# 9265, proportional_selected_drop, SVC, 0.6666666666666666, 0.6545377044098272
# 9265, proportional_selected_stretch, SVC, 0.6666666666666666, 0.6545377044098272
# 9265, fewest_selected_on, GradientBoostingClassifier, 0.9411764705882353, 0.9414151055959911
# 9265, fewest_selected_in, GradientBoostingClassifier, 0.9411764705882353, 0.9399698340874811
# 9265, fewest_selected_drop, GradientBoostingClassifier, 0.9215686274509803, 0.9199080162569007
# 9265, fewest_selected_stretch, GradientBoostingClassifier, 0.9607843137254902, 0.9607335418694446
# 9265, fewest_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.8442684766214178
# 9265, fewest_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.8822598092945617
# 9265, fewest_selected_drop, DecisionTreeClassifier, 0.803921568627451, 0.8102112639927767
# 9265, fewest_selected_stretch, DecisionTreeClassifier, 0.8627450980392157, 0.8599078928904027
# 9265, fewest_selected_on, SVC, 0.6274509803921569, 0.5956305132775721
# 9265, fewest_selected_in, SVC, 0.7450980392156863, 0.7441261244480742
# 9265, fewest_selected_drop, SVC, 0.7254901960784313, 0.723096596498131
# 9265, fewest_selected_stretch, SVC, 0.7450980392156863, 0.7422953267695257
# 9265, representative_selected_on, GradientBoostingClassifier, 0.9411764705882353, 0.9414151055959911
# 9265, representative_selected_in, GradientBoostingClassifier, 0.9607843137254902, 0.9607335418694446
# 9265, representative_selected_drop, GradientBoostingClassifier, 0.9411764705882353, 0.9405300581771169
# 9265, representative_selected_stretch, GradientBoostingClassifier, 0.9411764705882353, 0.9405300581771169
# 9265, representative_selected_on, DecisionTreeClassifier, 0.8235294117647058, 0.8187462119350664
# 9265, representative_selected_in, DecisionTreeClassifier, 0.9019607843137255, 0.9020685197155787
# 9265, representative_selected_drop, DecisionTreeClassifier, 0.9411764705882353, 0.9405300581771169
# 9265, representative_selected_stretch, DecisionTreeClassifier, 0.9019607843137255, 0.9020685197155787
# 9265, representative_selected_on, SVC, 0.6666666666666666, 0.620292561469032
# 9265, representative_selected_in, SVC, 0.6666666666666666, 0.6464850415584027
# 9265, representative_selected_drop, SVC, 0.6274509803921569, 0.6025472112428634
# 9265, representative_selected_stretch, SVC, 0.6078431372549019, 0.5849775646935891
# 9265, balanced_on, GradientBoostingClassifier, 0.9215686274509803, 0.9220235408741502
# 9265, balanced_on, DecisionTreeClassifier, 0.9411764705882353, 0.9405300581771169
# 9265, balanced_on, SVC, 0.6666666666666666, 0.6464850415584027
# 9265, balanced_in, GradientBoostingClassifier, 0.9215686274509803, 0.9220235408741502
# 9265, balanced_in, DecisionTreeClassifier, 0.9411764705882353, 0.9405300581771169
# 9265, balanced_in, SVC, 0.6666666666666666, 0.6464850415584027
# 3589, base, GradientBoostingClassifier, 0.9411764705882353, 0.9416912017645035
# 3589, base, DecisionTreeClassifier, 0.8235294117647058, 0.8320454281419312
# 3589, base, SVC, 0.6862745098039216, 0.6628248587570621
# 3589, random_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.9002639517345399
# 3589, random_selected_in, GradientBoostingClassifier, 0.9411764705882353, 0.9407051282051281
# 3589, random_selected_drop, GradientBoostingClassifier, 0.9411764705882353, 0.9416912017645035
# 3589, random_selected_stretch, GradientBoostingClassifier, 0.9019607843137255, 0.9016462199853204
# 3589, random_selected_on, DecisionTreeClassifier, 0.803921568627451, 0.80620258713565
# 3589, random_selected_in, DecisionTreeClassifier, 0.803921568627451, 0.8045081916384518
# 3589, random_selected_drop, DecisionTreeClassifier, 0.803921568627451, 0.8061840120663649
# 3589, random_selected_stretch, DecisionTreeClassifier, 0.803921568627451, 0.8000548971871158
# 3589, random_selected_on, SVC, 0.6666666666666666, 0.6116408101702219
# 3589, random_selected_in, SVC, 0.6862745098039216, 0.6633986928104576
# 3589, random_selected_drop, SVC, 0.6862745098039216, 0.6633986928104576
# 3589, random_selected_stretch, SVC, 0.6470588235294118, 0.6275266597867216
# 3589, proportional_selected_on, GradientBoostingClassifier, 0.9215686274509803, 0.921024463069804
# 3589, proportional_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9212540631225753
# 3589, proportional_selected_drop, GradientBoostingClassifier, 0.9411764705882353, 0.9416912017645035
# 3589, proportional_selected_stretch, GradientBoostingClassifier, 0.8627450980392157, 0.8661764705882352
# 3589, proportional_selected_on, DecisionTreeClassifier, 0.803921568627451, 0.80620258713565
# 3589, proportional_selected_in, DecisionTreeClassifier, 0.7647058823529411, 0.7674034784192314
# 3589, proportional_selected_drop, DecisionTreeClassifier, 0.7843137254901961, 0.7859793298124202
# 3589, proportional_selected_stretch, DecisionTreeClassifier, 0.803921568627451, 0.8175000205360737
# 3589, proportional_selected_on, SVC, 0.6470588235294118, 0.5929208046855106
# 3589, proportional_selected_in, SVC, 0.6862745098039216, 0.6628248587570621
# 3589, proportional_selected_drop, SVC, 0.6862745098039216, 0.6628248587570621
# 3589, proportional_selected_stretch, SVC, 0.6862745098039216, 0.6628248587570621
# 3589, fewest_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.9022820170379813
# 3589, fewest_selected_in, GradientBoostingClassifier, 0.8823529411764706, 0.8792739250295373
# 3589, fewest_selected_drop, GradientBoostingClassifier, 0.9411764705882353, 0.9407051282051281
# 3589, fewest_selected_stretch, GradientBoostingClassifier, 0.9215686274509803, 0.9197014058605754
# 3589, fewest_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.845997815571852
# 3589, fewest_selected_in, DecisionTreeClassifier, 0.7647058823529411, 0.7676377571901625
# 3589, fewest_selected_drop, DecisionTreeClassifier, 0.8235294117647058, 0.8200435729847496
# 3589, fewest_selected_stretch, DecisionTreeClassifier, 0.8235294117647058, 0.8320454281419312
# 3589, fewest_selected_on, SVC, 0.6470588235294118, 0.6100310601589374
# 3589, fewest_selected_in, SVC, 0.7450980392156863, 0.7434954751131221
# 3589, fewest_selected_drop, SVC, 0.7450980392156863, 0.7434954751131221
# 3589, fewest_selected_stretch, SVC, 0.6078431372549019, 0.6036287709698323
# 3589, representative_selected_on, GradientBoostingClassifier, 0.9411764705882353, 0.9407051282051281
# 3589, representative_selected_in, GradientBoostingClassifier, 0.9411764705882353, 0.9407051282051281
# 3589, representative_selected_drop, GradientBoostingClassifier, 0.9411764705882353, 0.9407051282051281
# 3589, representative_selected_stretch, GradientBoostingClassifier, 0.8431372549019608, 0.8498217468805703
# 3589, representative_selected_on, DecisionTreeClassifier, 0.8235294117647058, 0.8212050467552018
# 3589, representative_selected_in, DecisionTreeClassifier, 0.7843137254901961, 0.7850057670126873
# 3589, representative_selected_drop, DecisionTreeClassifier, 0.8235294117647058, 0.8320454281419312
# 3589, representative_selected_stretch, DecisionTreeClassifier, 0.8235294117647058, 0.828080205689314
# 3589, representative_selected_on, SVC, 0.6862745098039216, 0.6395212630506748
# 3589, representative_selected_in, SVC, 0.6862745098039216, 0.6633986928104576
# 3589, representative_selected_drop, SVC, 0.6862745098039216, 0.6633986928104576
# 3589, representative_selected_stretch, SVC, 0.6666666666666666, 0.6541933264533885
# 3589, balanced_on, GradientBoostingClassifier, 0.9411764705882353, 0.9416912017645035
# 3589, balanced_on, DecisionTreeClassifier, 0.8235294117647058, 0.8320454281419312
# 3589, balanced_on, SVC, 0.6862745098039216, 0.6628248587570621
# 3589, balanced_in, GradientBoostingClassifier, 0.9411764705882353, 0.9416912017645035
# 3589, balanced_in, DecisionTreeClassifier, 0.8235294117647058, 0.8320454281419312
# 3589, balanced_in, SVC, 0.6862745098039216, 0.6628248587570621
# 7932, base, GradientBoostingClassifier, 0.8235294117647058, 0.8202138790374085
# 7932, base, DecisionTreeClassifier, 0.8823529411764706, 0.8781275751914875
# 7932, base, SVC, 0.6274509803921569, 0.6097536450477626
# 7932, random_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.9020725099156472
# 7932, random_selected_in, GradientBoostingClassifier, 0.8823529411764706, 0.8798444073985869
# 7932, random_selected_drop, GradientBoostingClassifier, 0.803921568627451, 0.8009843613558785
# 7932, random_selected_stretch, GradientBoostingClassifier, 0.9019607843137255, 0.9020725099156472
# 7932, random_selected_on, DecisionTreeClassifier, 0.7843137254901961, 0.7882123609677789
# 7932, random_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.8815512344924109
# 7932, random_selected_drop, DecisionTreeClassifier, 0.8627450980392157, 0.8631459116495236
# 7932, random_selected_stretch, DecisionTreeClassifier, 0.8431372549019608, 0.8451209830520175
# 7932, random_selected_on, SVC, 0.45098039215686275, 0.34750158127767233
# 7932, random_selected_in, SVC, 0.6274509803921569, 0.6097536450477626
# 7932, random_selected_drop, SVC, 0.6274509803921569, 0.6097536450477626
# 7932, random_selected_stretch, SVC, 0.6274509803921569, 0.6097536450477626
# 7932, proportional_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.9020725099156472
# 7932, proportional_selected_in, GradientBoostingClassifier, 0.8431372549019608, 0.8392827216356629
# 7932, proportional_selected_drop, GradientBoostingClassifier, 0.803921568627451, 0.8009843613558785
# 7932, proportional_selected_stretch, GradientBoostingClassifier, 0.8823529411764706, 0.8800067035361153
# 7932, proportional_selected_on, DecisionTreeClassifier, 0.803921568627451, 0.808171254418719
# 7932, proportional_selected_in, DecisionTreeClassifier, 0.8627450980392157, 0.8623005477494642
# 7932, proportional_selected_drop, DecisionTreeClassifier, 0.8431372549019608, 0.8388872947553004
# 7932, proportional_selected_stretch, DecisionTreeClassifier, 0.8431372549019608, 0.8425060767682027
# 7932, proportional_selected_on, SVC, 0.45098039215686275, 0.34750158127767233
# 7932, proportional_selected_in, SVC, 0.6274509803921569, 0.6097536450477626
# 7932, proportional_selected_drop, SVC, 0.6274509803921569, 0.6097536450477626
# 7932, proportional_selected_stretch, SVC, 0.6274509803921569, 0.6097536450477626
# 7932, fewest_selected_on, GradientBoostingClassifier, 0.8823529411764706, 0.8815512344924109
# 7932, fewest_selected_in, GradientBoostingClassifier, 0.9019607843137255, 0.901458019105078
# 7932, fewest_selected_drop, GradientBoostingClassifier, 0.8235294117647058, 0.8232050419872917
# 7932, fewest_selected_stretch, GradientBoostingClassifier, 0.9019607843137255, 0.901458019105078
# 7932, fewest_selected_on, DecisionTreeClassifier, 0.7843137254901961, 0.7829641978248788
# 7932, fewest_selected_in, DecisionTreeClassifier, 0.8235294117647058, 0.8267090620031796
# 7932, fewest_selected_drop, DecisionTreeClassifier, 0.7254901960784313, 0.726291902762491
# 7932, fewest_selected_stretch, DecisionTreeClassifier, 0.7647058823529411, 0.7659672055956886
# 7932, fewest_selected_on, SVC, 0.39215686274509803, 0.2803346979817568
# 7932, fewest_selected_in, SVC, 0.6470588235294118, 0.6362817719680465
# 7932, fewest_selected_drop, SVC, 0.6274509803921569, 0.6097536450477626
# 7932, fewest_selected_stretch, SVC, 0.6862745098039216, 0.6951775304716481
# 7932, representative_selected_on, GradientBoostingClassifier, 0.8823529411764706, 0.8824111560953666
# 7932, representative_selected_in, GradientBoostingClassifier, 0.8627450980392157, 0.861627842019999
# 7932, representative_selected_drop, GradientBoostingClassifier, 0.8431372549019608, 0.838876523582406
# 7932, representative_selected_stretch, GradientBoostingClassifier, 0.9019607843137255, 0.9020725099156472
# 7932, representative_selected_on, DecisionTreeClassifier, 0.8235294117647058, 0.8174087918333443
# 7932, representative_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.8781275751914875
# 7932, representative_selected_drop, DecisionTreeClassifier, 0.8823529411764706, 0.8781275751914875
# 7932, representative_selected_stretch, DecisionTreeClassifier, 0.8627450980392157, 0.8649054734247431
# 7932, representative_selected_on, SVC, 0.49019607843137253, 0.4092436974789916
# 7932, representative_selected_in, SVC, 0.6274509803921569, 0.6097536450477626
# 7932, representative_selected_drop, SVC, 0.6274509803921569, 0.6097536450477626
# 7932, representative_selected_stretch, SVC, 0.6470588235294118, 0.6362817719680465
# 7932, balanced_on, GradientBoostingClassifier, 0.8235294117647058, 0.8202138790374085
# 7932, balanced_on, DecisionTreeClassifier, 0.8823529411764706, 0.8781275751914875
# 7932, balanced_on, SVC, 0.6274509803921569, 0.6097536450477626
# 7932, balanced_in, GradientBoostingClassifier, 0.8235294117647058, 0.8202138790374085
# 7932, balanced_in, DecisionTreeClassifier, 0.8823529411764706, 0.8781275751914875
# 7932, balanced_in, SVC, 0.6274509803921569, 0.6097536450477626
# 3846, base, GradientBoostingClassifier, 0.9019607843137255, 0.8918248226206704
# 3846, base, DecisionTreeClassifier, 0.8823529411764706, 0.8785332314744079
# 3846, base, SVC, 0.7647058823529411, 0.7611800939281186
# 3846, random_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.8918248226206704
# 3846, random_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9164015530797539
# 3846, random_selected_drop, GradientBoostingClassifier, 0.9215686274509803, 0.9164015530797539
# 3846, random_selected_stretch, GradientBoostingClassifier, 0.9019607843137255, 0.8918248226206704
# 3846, random_selected_on, DecisionTreeClassifier, 0.8235294117647058, 0.8122816603940396
# 3846, random_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.8738489988251413
# 3846, random_selected_drop, DecisionTreeClassifier, 0.8823529411764706, 0.8785332314744079
# 3846, random_selected_stretch, DecisionTreeClassifier, 0.803921568627451, 0.7890397184514832
# 3846, random_selected_on, SVC, 0.7254901960784313, 0.7122601538508747
# 3846, random_selected_in, SVC, 0.7450980392156863, 0.7403711123252191
# 3846, random_selected_drop, SVC, 0.7254901960784313, 0.7177417827034195
# 3846, random_selected_stretch, SVC, 0.7254901960784313, 0.7177417827034195
# 3846, proportional_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.8918248226206704
# 3846, proportional_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9164015530797539
# 3846, proportional_selected_drop, GradientBoostingClassifier, 0.9019607843137255, 0.8918248226206704
# 3846, proportional_selected_stretch, GradientBoostingClassifier, 0.9019607843137255, 0.8918248226206704
# 3846, proportional_selected_on, DecisionTreeClassifier, 0.803921568627451, 0.8039646627881921
# 3846, proportional_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.8846977044320498
# 3846, proportional_selected_drop, DecisionTreeClassifier, 0.8823529411764706, 0.8832030714383654
# 3846, proportional_selected_stretch, DecisionTreeClassifier, 0.8627450980392157, 0.8545635448749636
# 3846, proportional_selected_on, SVC, 0.7254901960784313, 0.6847265221878225
# 3846, proportional_selected_in, SVC, 0.7647058823529411, 0.7611800939281186
# 3846, proportional_selected_drop, SVC, 0.7647058823529411, 0.7611800939281186
# 3846, proportional_selected_stretch, SVC, 0.7647058823529411, 0.7611800939281186
# 3846, fewest_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.8918248226206704
# 3846, fewest_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9164015530797539
# 3846, fewest_selected_drop, GradientBoostingClassifier, 0.9215686274509803, 0.9164015530797539
# 3846, fewest_selected_stretch, GradientBoostingClassifier, 0.8627450980392157, 0.8460298790522952
# 3846, fewest_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.8311364679651125
# 3846, fewest_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.8738489988251413
# 3846, fewest_selected_drop, DecisionTreeClassifier, 0.8823529411764706, 0.878882896442159
# 3846, fewest_selected_stretch, DecisionTreeClassifier, 0.8431372549019608, 0.8337153043035397
# 3846, fewest_selected_on, SVC, 0.7843137254901961, 0.7791529884955491
# 3846, fewest_selected_in, SVC, 0.7058823529411765, 0.7104575163398693
# 3846, fewest_selected_drop, SVC, 0.7058823529411765, 0.7104575163398693
# 3846, fewest_selected_stretch, SVC, 0.6274509803921569, 0.6410130718954249
# 3846, representative_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.8918248226206704
# 3846, representative_selected_in, GradientBoostingClassifier, 0.9019607843137255, 0.8918248226206704
# 3846, representative_selected_drop, GradientBoostingClassifier, 0.9019607843137255, 0.8918248226206704
# 3846, representative_selected_stretch, GradientBoostingClassifier, 0.9019607843137255, 0.8918248226206704
# 3846, representative_selected_on, DecisionTreeClassifier, 0.7843137254901961, 0.780638968874263
# 3846, representative_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.882999353587589
# 3846, representative_selected_drop, DecisionTreeClassifier, 0.8627450980392157, 0.8608776844070963
# 3846, representative_selected_stretch, DecisionTreeClassifier, 0.8431372549019608, 0.8382188995999736
# 3846, representative_selected_on, SVC, 0.7450980392156863, 0.7340466462256023
# 3846, representative_selected_in, SVC, 0.7450980392156863, 0.7403711123252191
# 3846, representative_selected_drop, SVC, 0.7450980392156863, 0.7403711123252191
# 3846, representative_selected_stretch, SVC, 0.7254901960784313, 0.7237804784128892
# 3846, balanced_on, GradientBoostingClassifier, 0.9019607843137255, 0.8918248226206704
# 3846, balanced_on, DecisionTreeClassifier, 0.8823529411764706, 0.8785332314744079
# 3846, balanced_on, SVC, 0.7647058823529411, 0.7611800939281186
# 3846, balanced_in, GradientBoostingClassifier, 0.9019607843137255, 0.8918248226206704
# 3846, balanced_in, DecisionTreeClassifier, 0.8823529411764706, 0.8785332314744079
# 3846, balanced_in, SVC, 0.7647058823529411, 0.7611800939281186
# 2643, base, GradientBoostingClassifier, 0.9803921568627451, 0.9811652259470097
# 2643, base, DecisionTreeClassifier, 0.9019607843137255, 0.9122239017713883
# 2643, base, SVC, 0.7254901960784313, 0.7105809223456282
# 2643, random_selected_on, GradientBoostingClassifier, 0.9803921568627451, 0.9802315191309499
# 2643, random_selected_in, GradientBoostingClassifier, 0.9803921568627451, 0.9802315191309499
# 2643, random_selected_drop, GradientBoostingClassifier, 0.9803921568627451, 0.9802315191309499
# 2643, random_selected_stretch, GradientBoostingClassifier, 0.9607843137254902, 0.9617129183185114
# 2643, random_selected_on, DecisionTreeClassifier, 0.9019607843137255, 0.9122239017713883
# 2643, random_selected_in, DecisionTreeClassifier, 0.9411764705882353, 0.9417836351298261
# 2643, random_selected_drop, DecisionTreeClassifier, 0.9411764705882353, 0.9417836351298261
# 2643, random_selected_stretch, DecisionTreeClassifier, 0.9607843137254902, 0.9640522875816993
# 2643, random_selected_on, SVC, 0.6666666666666666, 0.598752499477721
# 2643, random_selected_in, SVC, 0.7450980392156863, 0.7285493097608988
# 2643, random_selected_drop, SVC, 0.7450980392156863, 0.7285493097608988
# 2643, random_selected_stretch, SVC, 0.7450980392156863, 0.7285493097608988
# 2643, proportional_selected_on, GradientBoostingClassifier, 0.9803921568627451, 0.9813207614557663
# 2643, proportional_selected_in, GradientBoostingClassifier, 0.9803921568627451, 0.9811652259470097
# 2643, proportional_selected_drop, GradientBoostingClassifier, 0.9607843137254902, 0.9600898692810458
# 2643, proportional_selected_stretch, GradientBoostingClassifier, 1.0, 1.0
# 2643, proportional_selected_on, DecisionTreeClassifier, 0.8823529411764706, 0.8968335858344365
# 2643, proportional_selected_in, DecisionTreeClassifier, 0.9019607843137255, 0.9122239017713883
# 2643, proportional_selected_drop, DecisionTreeClassifier, 0.9019607843137255, 0.9122239017713883
# 2643, proportional_selected_stretch, DecisionTreeClassifier, 0.9019607843137255, 0.9115079233125322
# 2643, proportional_selected_on, SVC, 0.6862745098039216, 0.6321195144724557
# 2643, proportional_selected_in, SVC, 0.7450980392156863, 0.7285493097608988
# 2643, proportional_selected_drop, SVC, 0.7450980392156863, 0.7352629940865235
# 2643, proportional_selected_stretch, SVC, 0.7254901960784313, 0.711295966197927
# 2643, fewest_selected_on, GradientBoostingClassifier, 1.0, 1.0
# 2643, fewest_selected_in, GradientBoostingClassifier, 1.0, 1.0
# 2643, fewest_selected_drop, GradientBoostingClassifier, 0.9607843137254902, 0.9607220666044196
# 2643, fewest_selected_stretch, GradientBoostingClassifier, 0.9803921568627451, 0.9811652259470097
# 2643, fewest_selected_on, DecisionTreeClassifier, 0.9607843137254902, 0.9642289067927541
# 2643, fewest_selected_in, DecisionTreeClassifier, 0.9019607843137255, 0.9042810961056226
# 2643, fewest_selected_drop, DecisionTreeClassifier, 0.9019607843137255, 0.9028643915747311
# 2643, fewest_selected_stretch, DecisionTreeClassifier, 0.9411764705882353, 0.9482280106568531
# 2643, fewest_selected_on, SVC, 0.7058823529411765, 0.6761390546556787
# 2643, fewest_selected_in, SVC, 0.7647058823529411, 0.7647058823529411
# 2643, fewest_selected_drop, SVC, 0.7450980392156863, 0.7458070233743215
# 2643, fewest_selected_stretch, SVC, 0.6666666666666666, 0.6669217280408097
# 2643, representative_selected_on, GradientBoostingClassifier, 0.9607843137254902, 0.9642289067927541
# 2643, representative_selected_in, GradientBoostingClassifier, 0.9803921568627451, 0.9802315191309499
# 2643, representative_selected_drop, GradientBoostingClassifier, 0.9607843137254902, 0.9607220666044196
# 2643, representative_selected_stretch, GradientBoostingClassifier, 0.9803921568627451, 0.9811652259470097
# 2643, representative_selected_on, DecisionTreeClassifier, 0.8823529411764706, 0.8968335858344365
# 2643, representative_selected_in, DecisionTreeClassifier, 0.9411764705882353, 0.9417836351298261
# 2643, representative_selected_drop, DecisionTreeClassifier, 0.9411764705882353, 0.9417836351298261
# 2643, representative_selected_stretch, DecisionTreeClassifier, 0.9411764705882353, 0.9417836351298261
# 2643, representative_selected_on, SVC, 0.7058823529411765, 0.6761390546556787
# 2643, representative_selected_in, SVC, 0.7254901960784313, 0.7105809223456282
# 2643, representative_selected_drop, SVC, 0.7254901960784313, 0.7105809223456282
# 2643, representative_selected_stretch, SVC, 0.7254901960784313, 0.7105809223456282
# 2643, balanced_on, GradientBoostingClassifier, 0.9803921568627451, 0.9811652259470097
# 2643, balanced_on, DecisionTreeClassifier, 0.9019607843137255, 0.9122239017713883
# 2643, balanced_on, SVC, 0.7254901960784313, 0.7105809223456282
# 2643, balanced_in, GradientBoostingClassifier, 0.9803921568627451, 0.9811652259470097
# 2643, balanced_in, DecisionTreeClassifier, 0.9019607843137255, 0.9122239017713883
# 2643, balanced_in, SVC, 0.7254901960784313, 0.7105809223456282
# 3832, base, GradientBoostingClassifier, 0.9411764705882353, 0.9438771822165214
# 3832, base, DecisionTreeClassifier, 0.8627450980392157, 0.8598817304699657
# 3832, base, SVC, 0.7647058823529411, 0.7561497326203208
# 3832, random_selected_on, GradientBoostingClassifier, 0.9607843137254902, 0.9594914889032534
# 3832, random_selected_in, GradientBoostingClassifier, 0.9607843137254902, 0.9611804317686671
# 3832, random_selected_drop, GradientBoostingClassifier, 0.9607843137254902, 0.9611804317686671
# 3832, random_selected_stretch, GradientBoostingClassifier, 0.9803921568627451, 0.9808081381057727
# 3832, random_selected_on, DecisionTreeClassifier, 0.8627450980392157, 0.8627450980392157
# 3832, random_selected_in, DecisionTreeClassifier, 0.8431372549019608, 0.8418300653594772
# 3832, random_selected_drop, DecisionTreeClassifier, 0.8431372549019608, 0.8393732492997199
# 3832, random_selected_stretch, DecisionTreeClassifier, 0.8823529411764706, 0.879789662817628
# 3832, random_selected_on, SVC, 0.7450980392156863, 0.7148989061109268
# 3832, random_selected_in, SVC, 0.7647058823529411, 0.7566596579526831
# 3832, random_selected_drop, SVC, 0.7843137254901961, 0.7804099015171679
# 3832, random_selected_stretch, SVC, 0.7843137254901961, 0.7804099015171679
# 3832, proportional_selected_on, GradientBoostingClassifier, 0.9411764705882353, 0.9438771822165214
# 3832, proportional_selected_in, GradientBoostingClassifier, 0.9411764705882353, 0.9438771822165214
# 3832, proportional_selected_drop, GradientBoostingClassifier, 0.9803921568627451, 0.9805426006719824
# 3832, proportional_selected_stretch, GradientBoostingClassifier, 0.9411764705882353, 0.9447405812057852
# 3832, proportional_selected_on, DecisionTreeClassifier, 0.9019607843137255, 0.8922662141779789
# 3832, proportional_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.8798630563336446
# 3832, proportional_selected_drop, DecisionTreeClassifier, 0.8627450980392157, 0.8598817304699657
# 3832, proportional_selected_stretch, DecisionTreeClassifier, 0.9215686274509803, 0.9228165711800632
# 3832, proportional_selected_on, SVC, 0.7647058823529411, 0.7418300653594772
# 3832, proportional_selected_in, SVC, 0.7647058823529411, 0.7561497326203208
# 3832, proportional_selected_drop, SVC, 0.7647058823529411, 0.7561497326203208
# 3832, proportional_selected_stretch, SVC, 0.7843137254901961, 0.7743018652865703
# 3832, fewest_selected_on, GradientBoostingClassifier, 0.9411764705882353, 0.9427458543687485
# 3832, fewest_selected_in, GradientBoostingClassifier, 0.9607843137254902, 0.9611804317686671
# 3832, fewest_selected_drop, GradientBoostingClassifier, 0.9607843137254902, 0.9611804317686671
# 3832, fewest_selected_stretch, GradientBoostingClassifier, 0.9215686274509803, 0.9224233283056813
# 3832, fewest_selected_on, DecisionTreeClassifier, 0.9215686274509803, 0.9102463549522375
# 3832, fewest_selected_in, DecisionTreeClassifier, 0.8235294117647058, 0.8150638032990974
# 3832, fewest_selected_drop, DecisionTreeClassifier, 0.8627450980392157, 0.8627450980392157
# 3832, fewest_selected_stretch, DecisionTreeClassifier, 0.9215686274509803, 0.9171918767507001
# 3832, fewest_selected_on, SVC, 0.7843137254901961, 0.7668522313793321
# 3832, fewest_selected_in, SVC, 0.7647058823529411, 0.7671010707641182
# 3832, fewest_selected_drop, SVC, 0.7647058823529411, 0.7671010707641182
# 3832, fewest_selected_stretch, SVC, 0.7058823529411765, 0.7096571248820382
# 3832, representative_selected_on, GradientBoostingClassifier, 0.9803921568627451, 0.9808081381057727
# 3832, representative_selected_in, GradientBoostingClassifier, 0.9411764705882353, 0.9438771822165214
# 3832, representative_selected_drop, GradientBoostingClassifier, 0.9411764705882353, 0.9438771822165214
# 3832, representative_selected_stretch, GradientBoostingClassifier, 1.0, 1.0
# 3832, representative_selected_on, DecisionTreeClassifier, 0.8823529411764706, 0.8836678200692042
# 3832, representative_selected_in, DecisionTreeClassifier, 0.8235294117647058, 0.821350762527233
# 3832, representative_selected_drop, DecisionTreeClassifier, 0.8627450980392157, 0.8598817304699657
# 3832, representative_selected_stretch, DecisionTreeClassifier, 0.8235294117647058, 0.8302832244008715
# 3832, representative_selected_on, SVC, 0.7647058823529411, 0.7537586758129464
# 3832, representative_selected_in, SVC, 0.7647058823529411, 0.7561497326203208
# 3832, representative_selected_drop, SVC, 0.7647058823529411, 0.7561497326203208
# 3832, representative_selected_stretch, SVC, 0.7450980392156863, 0.7381776239907727
# 3832, balanced_on, GradientBoostingClassifier, 0.9411764705882353, 0.9438771822165214
# 3832, balanced_on, DecisionTreeClassifier, 0.8627450980392157, 0.8598817304699657
# 3832, balanced_on, SVC, 0.7647058823529411, 0.7561497326203208
# 3832, balanced_in, GradientBoostingClassifier, 0.9411764705882353, 0.9438771822165214
# 3832, balanced_in, DecisionTreeClassifier, 0.8627450980392157, 0.8598817304699657
# 3832, balanced_in, SVC, 0.7647058823529411, 0.7561497326203208
# 7950, base, GradientBoostingClassifier, 0.8823529411764706, 0.8833492798550779
# 7950, base, DecisionTreeClassifier, 0.8431372549019608, 0.8428296808919646
# 7950, base, SVC, 0.7450980392156863, 0.7300232635427052
# 7950, random_selected_on, GradientBoostingClassifier, 0.8823529411764706, 0.8833492798550779
# 7950, random_selected_in, GradientBoostingClassifier, 0.8823529411764706, 0.8833492798550779
# 7950, random_selected_drop, GradientBoostingClassifier, 0.8823529411764706, 0.8833492798550779
# 7950, random_selected_stretch, GradientBoostingClassifier, 0.8235294117647058, 0.8295509171410499
# 7950, random_selected_on, DecisionTreeClassifier, 0.803921568627451, 0.8027210884353742
# 7950, random_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.8832065333873488
# 7950, random_selected_drop, DecisionTreeClassifier, 0.8431372549019608, 0.8451460684398915
# 7950, random_selected_stretch, DecisionTreeClassifier, 0.8627450980392157, 0.865150908848388
# 7950, random_selected_on, SVC, 0.6470588235294118, 0.6108989050165522
# 7950, random_selected_in, SVC, 0.7450980392156863, 0.7300232635427052
# 7950, random_selected_drop, SVC, 0.7450980392156863, 0.7300232635427052
# 7950, random_selected_stretch, SVC, 0.7450980392156863, 0.7300232635427052
# 7950, proportional_selected_on, GradientBoostingClassifier, 0.8823529411764706, 0.8833492798550779
# 7950, proportional_selected_in, GradientBoostingClassifier, 0.8823529411764706, 0.8833492798550779
# 7950, proportional_selected_drop, GradientBoostingClassifier, 0.8823529411764706, 0.8833492798550779
# 7950, proportional_selected_stretch, GradientBoostingClassifier, 0.8823529411764706, 0.8841165308628195
# 7950, proportional_selected_on, DecisionTreeClassifier, 0.8235294117647058, 0.8234522845433542
# 7950, proportional_selected_in, DecisionTreeClassifier, 0.8431372549019608, 0.8438223586648282
# 7950, proportional_selected_drop, DecisionTreeClassifier, 0.8235294117647058, 0.8230140353354963
# 7950, proportional_selected_stretch, DecisionTreeClassifier, 0.8235294117647058, 0.8230140353354963
# 7950, proportional_selected_on, SVC, 0.6666666666666666, 0.6205182072829132
# 7950, proportional_selected_in, SVC, 0.7450980392156863, 0.7300232635427052
# 7950, proportional_selected_drop, SVC, 0.7450980392156863, 0.7300232635427052
# 7950, proportional_selected_stretch, SVC, 0.7254901960784313, 0.7045751633986927
# 7950, fewest_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.9021113642411616
# 7950, fewest_selected_in, GradientBoostingClassifier, 0.8823529411764706, 0.8833492798550779
# 7950, fewest_selected_drop, GradientBoostingClassifier, 0.8627450980392157, 0.8674780256930358
# 7950, fewest_selected_stretch, GradientBoostingClassifier, 0.8431372549019608, 0.846228226537824
# 7950, fewest_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.8423509754779105
# 7950, fewest_selected_in, DecisionTreeClassifier, 0.7450980392156863, 0.7640366491424155
# 7950, fewest_selected_drop, DecisionTreeClassifier, 0.7450980392156863, 0.7553074015529966
# 7950, fewest_selected_stretch, DecisionTreeClassifier, 0.7647058823529411, 0.7713501823016596
# 7950, fewest_selected_on, SVC, 0.5882352941176471, 0.5263427109974425
# 7950, fewest_selected_in, SVC, 0.6862745098039216, 0.6880738177623991
# 7950, fewest_selected_drop, SVC, 0.6862745098039216, 0.6880738177623991
# 7950, fewest_selected_stretch, SVC, 0.6666666666666666, 0.668808984203227
# 7950, representative_selected_on, GradientBoostingClassifier, 0.8823529411764706, 0.8842847483821115
# 7950, representative_selected_in, GradientBoostingClassifier, 0.8823529411764706, 0.8833492798550779
# 7950, representative_selected_drop, GradientBoostingClassifier, 0.8823529411764706, 0.8833492798550779
# 7950, representative_selected_stretch, GradientBoostingClassifier, 0.8823529411764706, 0.8841165308628195
# 7950, representative_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.8428296808919646
# 7950, representative_selected_in, DecisionTreeClassifier, 0.8431372549019608, 0.8451460684398915
# 7950, representative_selected_drop, DecisionTreeClassifier, 0.8431372549019608, 0.8428296808919646
# 7950, representative_selected_stretch, DecisionTreeClassifier, 0.8235294117647058, 0.8234522845433542
# 7950, representative_selected_on, SVC, 0.6666666666666666, 0.6205182072829132
# 7950, representative_selected_in, SVC, 0.7450980392156863, 0.7300232635427052
# 7950, representative_selected_drop, SVC, 0.7450980392156863, 0.7300232635427052
# 7950, representative_selected_stretch, SVC, 0.7058823529411765, 0.685662311311679
# 7950, balanced_on, GradientBoostingClassifier, 0.8823529411764706, 0.8833492798550779
# 7950, balanced_on, DecisionTreeClassifier, 0.8431372549019608, 0.8428296808919646
# 7950, balanced_on, SVC, 0.7450980392156863, 0.7300232635427052
# 7950, balanced_in, GradientBoostingClassifier, 0.8823529411764706, 0.8833492798550779
# 7950, balanced_in, DecisionTreeClassifier, 0.8431372549019608, 0.8428296808919646
# 7950, balanced_in, SVC, 0.7450980392156863, 0.7300232635427052
# 2884, base, GradientBoostingClassifier, 0.9411764705882353, 0.9407486631016041
# 2884, base, DecisionTreeClassifier, 0.8627450980392157, 0.8609377664109121
# 2884, base, SVC, 0.7254901960784313, 0.7163013125126784
# 2884, random_selected_on, GradientBoostingClassifier, 0.9215686274509803, 0.9204863763687292
# 2884, random_selected_in, GradientBoostingClassifier, 0.9411764705882353, 0.9407486631016041
# 2884, random_selected_drop, GradientBoostingClassifier, 0.9411764705882353, 0.9407486631016041
# 2884, random_selected_stretch, GradientBoostingClassifier, 0.9215686274509803, 0.9208246144307526
# 2884, random_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.8391683696569953
# 2884, random_selected_in, DecisionTreeClassifier, 0.9215686274509803, 0.9206349206349206
# 2884, random_selected_drop, DecisionTreeClassifier, 0.8823529411764706, 0.8819813321092093
# 2884, random_selected_stretch, DecisionTreeClassifier, 0.9411764705882353, 0.9409022350198821
# 2884, random_selected_on, SVC, 0.6470588235294118, 0.6408068914286241
# 2884, random_selected_in, SVC, 0.7647058823529411, 0.7601904085953083
# 2884, random_selected_drop, SVC, 0.7647058823529411, 0.7601904085953083
# 2884, random_selected_stretch, SVC, 0.7450980392156863, 0.7350123542416229
# 2884, proportional_selected_on, GradientBoostingClassifier, 0.9411764705882353, 0.9401717208622579
# 2884, proportional_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9228026875085698
# 2884, proportional_selected_drop, GradientBoostingClassifier, 0.9411764705882353, 0.9407486631016041
# 2884, proportional_selected_stretch, GradientBoostingClassifier, 0.9019607843137255, 0.9026427962489343
# 2884, proportional_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.8391683696569953
# 2884, proportional_selected_in, DecisionTreeClassifier, 0.9215686274509803, 0.9216771293497638
# 2884, proportional_selected_drop, DecisionTreeClassifier, 0.8627450980392157, 0.8629966703662597
# 2884, proportional_selected_stretch, DecisionTreeClassifier, 0.8823529411764706, 0.8808050512436945
# 2884, proportional_selected_on, SVC, 0.5686274509803921, 0.5086834733893557
# 2884, proportional_selected_in, SVC, 0.7450980392156863, 0.7365266946358753
# 2884, proportional_selected_drop, SVC, 0.7450980392156863, 0.7365266946358753
# 2884, proportional_selected_stretch, SVC, 0.7450980392156863, 0.7433321154548775
# 2884, fewest_selected_on, GradientBoostingClassifier, 0.9607843137254902, 0.9597020626432391
# 2884, fewest_selected_in, GradientBoostingClassifier, 0.9411764705882353, 0.9400759513291481
# 2884, fewest_selected_drop, GradientBoostingClassifier, 0.9411764705882353, 0.9407486631016041
# 2884, fewest_selected_stretch, GradientBoostingClassifier, 0.9607843137254902, 0.959572192513369
# 2884, fewest_selected_on, DecisionTreeClassifier, 0.9019607843137255, 0.9013104542516306
# 2884, fewest_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.8818044700397641
# 2884, fewest_selected_drop, DecisionTreeClassifier, 0.8627450980392157, 0.8598930481283422
# 2884, fewest_selected_stretch, DecisionTreeClassifier, 0.9019607843137255, 0.9026427962489343
# 2884, fewest_selected_on, SVC, 0.5882352941176471, 0.5527374586198117
# 2884, fewest_selected_in, SVC, 0.7058823529411765, 0.7243014507855928
# 2884, fewest_selected_drop, SVC, 0.7058823529411765, 0.7243014507855928
# 2884, fewest_selected_stretch, SVC, 0.6274509803921569, 0.6447419888671582
# 2884, representative_selected_on, GradientBoostingClassifier, 0.9215686274509803, 0.9187038451744334
# 2884, representative_selected_in, GradientBoostingClassifier, 0.9411764705882353, 0.9407486631016041
# 2884, representative_selected_drop, GradientBoostingClassifier, 0.9411764705882353, 0.9407486631016041
# 2884, representative_selected_stretch, GradientBoostingClassifier, 0.9019607843137255, 0.9026737967914438
# 2884, representative_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.8465608465608465
# 2884, representative_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.8823529411764706
# 2884, representative_selected_drop, DecisionTreeClassifier, 0.8431372549019608, 0.8381079704609117
# 2884, representative_selected_stretch, DecisionTreeClassifier, 0.8627450980392157, 0.8609377664109121
# 2884, representative_selected_on, SVC, 0.6274509803921569, 0.6234491286513821
# 2884, representative_selected_in, SVC, 0.7254901960784313, 0.6975157359371436
# 2884, representative_selected_drop, SVC, 0.7254901960784313, 0.6975157359371436
# 2884, representative_selected_stretch, SVC, 0.7254901960784313, 0.6975157359371436
# 2884, balanced_on, GradientBoostingClassifier, 0.9411764705882353, 0.9407486631016041
# 2884, balanced_on, DecisionTreeClassifier, 0.8627450980392157, 0.8609377664109121
# 2884, balanced_on, SVC, 0.7254901960784313, 0.7163013125126784
# 2884, balanced_in, GradientBoostingClassifier, 0.9411764705882353, 0.9407486631016041
# 2884, balanced_in, DecisionTreeClassifier, 0.8627450980392157, 0.8609377664109121
# 2884, balanced_in, SVC, 0.7254901960784313, 0.7163013125126784
# 1971, base, GradientBoostingClassifier, 0.9215686274509803, 0.9174030902683654
# 1971, base, DecisionTreeClassifier, 0.8627450980392157, 0.8627689663814401
# 1971, base, SVC, 0.6862745098039216, 0.6789592760180996
# 1971, random_selected_on, GradientBoostingClassifier, 0.9215686274509803, 0.9174030902683654
# 1971, random_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9174030902683654
# 1971, random_selected_drop, GradientBoostingClassifier, 0.9215686274509803, 0.9174030902683654
# 1971, random_selected_stretch, GradientBoostingClassifier, 0.8823529411764706, 0.8803607004299046
# 1971, random_selected_on, DecisionTreeClassifier, 0.8627450980392157, 0.8666883539362396
# 1971, random_selected_in, DecisionTreeClassifier, 0.7843137254901961, 0.7958645276292335
# 1971, random_selected_drop, DecisionTreeClassifier, 0.8627450980392157, 0.8654321708822557
# 1971, random_selected_stretch, DecisionTreeClassifier, 0.8431372549019608, 0.8492151577612177
# 1971, random_selected_on, SVC, 0.5882352941176471, 0.5650075414781297
# 1971, random_selected_in, SVC, 0.6862745098039216, 0.6789592760180996
# 1971, random_selected_drop, SVC, 0.6862745098039216, 0.6789592760180996
# 1971, random_selected_stretch, SVC, 0.7058823529411765, 0.6987760551887843
# 1971, proportional_selected_on, GradientBoostingClassifier, 0.9215686274509803, 0.9174030902683654
# 1971, proportional_selected_in, GradientBoostingClassifier, 0.9019607843137255, 0.901481344889053
# 1971, proportional_selected_drop, GradientBoostingClassifier, 0.9019607843137255, 0.8984593837535013
# 1971, proportional_selected_stretch, GradientBoostingClassifier, 0.9215686274509803, 0.9178765880217787
# 1971, proportional_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.8458243277450007
# 1971, proportional_selected_in, DecisionTreeClassifier, 0.8431372549019608, 0.8481792717086833
# 1971, proportional_selected_drop, DecisionTreeClassifier, 0.8431372549019608, 0.8400491126241768
# 1971, proportional_selected_stretch, DecisionTreeClassifier, 0.8823529411764706, 0.8826665594467451
# 1971, proportional_selected_on, SVC, 0.6078431372549019, 0.5880602240896359
# 1971, proportional_selected_in, SVC, 0.7058823529411765, 0.6962873674059789
# 1971, proportional_selected_drop, SVC, 0.6862745098039216, 0.6789592760180996
# 1971, proportional_selected_stretch, SVC, 0.6470588235294118, 0.6484593837535013
# 1971, fewest_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.8936525374156453
# 1971, fewest_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9203732830030408
# 1971, fewest_selected_drop, GradientBoostingClassifier, 0.9215686274509803, 0.9174030902683654
# 1971, fewest_selected_stretch, GradientBoostingClassifier, 0.9019607843137255, 0.8984593837535013
# 1971, fewest_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.8496645342487127
# 1971, fewest_selected_in, DecisionTreeClassifier, 0.8627450980392157, 0.8654321708822557
# 1971, fewest_selected_drop, DecisionTreeClassifier, 0.7843137254901961, 0.7922118449501816
# 1971, fewest_selected_stretch, DecisionTreeClassifier, 0.7843137254901961, 0.79113245818822
# 1971, fewest_selected_on, SVC, 0.6274509803921569, 0.6134453781512604
# 1971, fewest_selected_in, SVC, 0.6470588235294118, 0.6507352941176471
# 1971, fewest_selected_drop, SVC, 0.6666666666666666, 0.6689063308607901
# 1971, fewest_selected_stretch, SVC, 0.6470588235294118, 0.6507352941176471
# 1971, representative_selected_on, GradientBoostingClassifier, 0.9215686274509803, 0.9174030902683654
# ...
# 781, representative_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.8363594909422543
# 781, representative_selected_in, DecisionTreeClassifier, 0.9215686274509803, 0.9121615312791784
# 781, representative_selected_drop, DecisionTreeClassifier, 0.9019607843137255, 0.893534165093126
# 781, representative_selected_stretch, DecisionTreeClassifier, 0.8627450980392157, 0.8486692003588123
# 781, representative_selected_on, SVC, 0.5490196078431373, 0.46796828184009925
# 781, representative_selected_in, SVC, 0.5686274509803921, 0.5528035775713794
# 781, representative_selected_drop, SVC, 0.5882352941176471, 0.576316978404265
# 781, representative_selected_stretch, SVC, 0.6078431372549019, 0.5988636363636364
# 781, balanced_on, GradientBoostingClassifier, 0.9215686274509803, 0.9182024161015757
# 781, balanced_on, DecisionTreeClassifier, 0.9019607843137255, 0.893534165093126
# 781, balanced_on, SVC, 0.5882352941176471, 0.5776401788785689
# 781, balanced_in, GradientBoostingClassifier, 0.9215686274509803, 0.9182024161015757
# 781, balanced_in, DecisionTreeClassifier, 0.9019607843137255, 0.893534165093126
# 781, balanced_in, SVC, 0.5882352941176471, 0.5776401788785689
# 6406, base, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, base, DecisionTreeClassifier, 0.803921568627451, 0.8019559730050378
# 6406, base, SVC, 0.6862745098039216, 0.6757066462948815
# 6406, random_selected_on, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, random_selected_in, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, random_selected_drop, GradientBoostingClassifier, 0.9607843137254902, 0.9595181180976788
# 6406, random_selected_stretch, GradientBoostingClassifier, 0.9607843137254902, 0.9595181180976788
# 6406, random_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.8427094474153298
# 6406, random_selected_in, DecisionTreeClassifier, 0.8235294117647058, 0.8251627531762182
# 6406, random_selected_drop, DecisionTreeClassifier, 0.7647058823529411, 0.7639926251900899
# 6406, random_selected_stretch, DecisionTreeClassifier, 0.8235294117647058, 0.8236128493950773
# 6406, random_selected_on, SVC, 0.5490196078431373, 0.45457520207751695
# 6406, random_selected_in, SVC, 0.7254901960784313, 0.7170231729055259
# 6406, random_selected_drop, SVC, 0.7254901960784313, 0.7170231729055259
# 6406, random_selected_stretch, SVC, 0.7450980392156863, 0.7344648531349297
# 6406, proportional_selected_on, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, proportional_selected_in, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, proportional_selected_drop, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, proportional_selected_stretch, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, proportional_selected_on, DecisionTreeClassifier, 0.8235294117647058, 0.8230936819172112
# 6406, proportional_selected_in, DecisionTreeClassifier, 0.8627450980392157, 0.8631314594803439
# 6406, proportional_selected_drop, DecisionTreeClassifier, 0.8235294117647058, 0.8229794021395375
# 6406, proportional_selected_stretch, DecisionTreeClassifier, 0.7843137254901961, 0.7847642886942011
# 6406, proportional_selected_on, SVC, 0.5490196078431373, 0.47383163791832517
# 6406, proportional_selected_in, SVC, 0.6862745098039216, 0.6757066462948815
# 6406, proportional_selected_drop, SVC, 0.6862745098039216, 0.6757066462948815
# 6406, proportional_selected_stretch, SVC, 0.7058823529411765, 0.7003775069692166
# 6406, fewest_selected_on, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, fewest_selected_in, GradientBoostingClassifier, 0.9411764705882353, 0.9407859769391805
# 6406, fewest_selected_drop, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, fewest_selected_stretch, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, fewest_selected_on, DecisionTreeClassifier, 0.8235294117647058, 0.8231988447552934
# 6406, fewest_selected_in, DecisionTreeClassifier, 0.803921568627451, 0.8020739551583127
# 6406, fewest_selected_drop, DecisionTreeClassifier, 0.8235294117647058, 0.821319073083779
# 6406, fewest_selected_stretch, DecisionTreeClassifier, 0.8431372549019608, 0.8450483340189222
# 6406, fewest_selected_on, SVC, 0.5686274509803921, 0.523109243697479
# 6406, fewest_selected_in, SVC, 0.7450980392156863, 0.7471776589423649
# 6406, fewest_selected_drop, SVC, 0.7450980392156863, 0.7471776589423649
# 6406, fewest_selected_stretch, SVC, 0.7254901960784313, 0.7275080079457645
# 6406, representative_selected_on, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, representative_selected_in, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, representative_selected_drop, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, representative_selected_stretch, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, representative_selected_on, DecisionTreeClassifier, 0.803921568627451, 0.8041838809102235
# 6406, representative_selected_in, DecisionTreeClassifier, 0.8627450980392157, 0.8627021140937193
# 6406, representative_selected_drop, DecisionTreeClassifier, 0.8235294117647058, 0.8229794021395375
# 6406, representative_selected_stretch, DecisionTreeClassifier, 0.9019607843137255, 0.9020475606801821
# 6406, representative_selected_on, SVC, 0.6862745098039216, 0.6550284629981025
# 6406, representative_selected_in, SVC, 0.7058823529411765, 0.6994652406417112
# 6406, representative_selected_drop, SVC, 0.6862745098039216, 0.6757066462948815
# 6406, representative_selected_stretch, SVC, 0.6862745098039216, 0.6863724510783336
# 6406, balanced_on, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, balanced_on, DecisionTreeClassifier, 0.803921568627451, 0.8019559730050378
# 6406, balanced_on, SVC, 0.6862745098039216, 0.6757066462948815
# 6406, balanced_in, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, balanced_in, DecisionTreeClassifier, 0.803921568627451, 0.8019559730050378
# 6406, balanced_in, SVC, 0.6862745098039216, 0.6757066462948815
# 2862, base, GradientBoostingClassifier, 0.8823529411764706, 0.8807088366822478
# 2862, base, DecisionTreeClassifier, 0.8823529411764706, 0.8839883428118722
# 2862, base, SVC, 0.7254901960784313, 0.7048887939930963
# 2862, random_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.9037674310441741
# 2862, random_selected_in, GradientBoostingClassifier, 0.8823529411764706, 0.8836473983532807
# 2862, random_selected_drop, GradientBoostingClassifier, 0.9019607843137255, 0.9010877078103969
# 2862, random_selected_stretch, GradientBoostingClassifier, 0.8823529411764706, 0.8856525201956991
# 2862, random_selected_on, DecisionTreeClassifier, 0.8627450980392157, 0.8648247177658942
# 2862, random_selected_in, DecisionTreeClassifier, 0.9019607843137255, 0.9032057267351385
# 2862, random_selected_drop, DecisionTreeClassifier, 0.8823529411764706, 0.8839883428118722
# 2862, random_selected_stretch, DecisionTreeClassifier, 0.8235294117647058, 0.8308278867102397
# 2862, random_selected_on, SVC, 0.5686274509803921, 0.4521337946943483
# 2862, random_selected_in, SVC, 0.7450980392156863, 0.7304384641845942
# 2862, random_selected_drop, SVC, 0.7450980392156863, 0.7304384641845942
# 2862, random_selected_stretch, SVC, 0.7450980392156863, 0.7304384641845942
# 2862, proportional_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.9037674310441741
# 2862, proportional_selected_in, GradientBoostingClassifier, 0.9019607843137255, 0.9008762548081435
# 2862, proportional_selected_drop, GradientBoostingClassifier, 0.9019607843137255, 0.9010877078103969
# 2862, proportional_selected_stretch, GradientBoostingClassifier, 0.9019607843137255, 0.9024413687043445
# 2862, proportional_selected_on, DecisionTreeClassifier, 0.9019607843137255, 0.9024382480264833
# 2862, proportional_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.8860730062776099
# 2862, proportional_selected_drop, DecisionTreeClassifier, 0.8431372549019608, 0.8508714596949891
# 2862, proportional_selected_stretch, DecisionTreeClassifier, 0.8431372549019608, 0.8472712102249023
# 2862, proportional_selected_on, SVC, 0.5490196078431373, 0.43137254901960786
# 2862, proportional_selected_in, SVC, 0.7254901960784313, 0.7048887939930963
# 2862, proportional_selected_drop, SVC, 0.7254901960784313, 0.7048887939930963
# 2862, proportional_selected_stretch, SVC, 0.7450980392156863, 0.7304384641845942
# 2862, fewest_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.9010877078103969
# 2862, fewest_selected_in, GradientBoostingClassifier, 0.8823529411764706, 0.8807088366822478
# 2862, fewest_selected_drop, GradientBoostingClassifier, 0.8823529411764706, 0.8807088366822478
# 2862, fewest_selected_stretch, GradientBoostingClassifier, 0.8627450980392157, 0.8631786047752434
# 2862, fewest_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.8482296711469047
# 2862, fewest_selected_in, DecisionTreeClassifier, 0.9019607843137255, 0.9008762548081435
# 2862, fewest_selected_drop, DecisionTreeClassifier, 0.8235294117647058, 0.8341672007882679
# 2862, fewest_selected_stretch, DecisionTreeClassifier, 0.8235294117647058, 0.8310160427807488
# 2862, fewest_selected_on, SVC, 0.49019607843137253, 0.35348583877995643
# 2862, fewest_selected_in, SVC, 0.803921568627451, 0.7983410245925581
# 2862, fewest_selected_drop, SVC, 0.7843137254901961, 0.7759918916817248
# 2862, fewest_selected_stretch, SVC, 0.7254901960784313, 0.7172459450513075
# 2862, representative_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.9008762548081435
# 2862, representative_selected_in, GradientBoostingClassifier, 0.8823529411764706, 0.8805882352941177
# 2862, representative_selected_drop, GradientBoostingClassifier, 0.8823529411764706, 0.8805882352941177
# 2862, representative_selected_stretch, GradientBoostingClassifier, 0.8627450980392157, 0.8664618652103007
# 2862, representative_selected_on, DecisionTreeClassifier, 0.8235294117647058, 0.831179372766683
# 2862, representative_selected_in, DecisionTreeClassifier, 0.8627450980392157, 0.8656248270059012
# 2862, representative_selected_drop, DecisionTreeClassifier, 0.8823529411764706, 0.8839883428118722
# 2862, representative_selected_stretch, DecisionTreeClassifier, 0.8823529411764706, 0.8818527410964387
# 2862, representative_selected_on, SVC, 0.5686274509803921, 0.4521337946943483
# 2862, representative_selected_in, SVC, 0.7254901960784313, 0.7048887939930963
# 2862, representative_selected_drop, SVC, 0.7254901960784313, 0.7048887939930963
# 2862, representative_selected_stretch, SVC, 0.7254901960784313, 0.7048887939930963
# 2862, balanced_on, GradientBoostingClassifier, 0.8823529411764706, 0.8807088366822478
# 2862, balanced_on, DecisionTreeClassifier, 0.8823529411764706, 0.8839883428118722
# 2862, balanced_on, SVC, 0.7254901960784313, 0.7048887939930963
# 2862, balanced_in, GradientBoostingClassifier, 0.8823529411764706, 0.8807088366822478
# 2862, balanced_in, DecisionTreeClassifier, 0.8823529411764706, 0.8839883428118722
# 2862, balanced_in, SVC, 0.7254901960784313, 0.7048887939930963
# 899, base, GradientBoostingClassifier, 0.9019607843137255, 0.9083488599059533
# 899, base, DecisionTreeClassifier, 0.8627450980392157, 0.8673317280128425
# 899, base, SVC, 0.6666666666666666, 0.6367231638418079
# 899, random_selected_on, GradientBoostingClassifier, 0.9411764705882353, 0.9428981348637017
# 899, random_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9254901960784314
# 899, random_selected_drop, GradientBoostingClassifier, 0.9019607843137255, 0.9052260838869098
# 899, random_selected_stretch, GradientBoostingClassifier, 0.9215686274509803, 0.925577873425793
# 899, random_selected_on, DecisionTreeClassifier, 0.8823529411764706, 0.8869302053713651
# 899, random_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.8869395711500975
# 899, random_selected_drop, DecisionTreeClassifier, 0.8627450980392157, 0.8673317280128425
# 899, random_selected_stretch, DecisionTreeClassifier, 0.9215686274509803, 0.9251249519415611
# 899, random_selected_on, SVC, 0.5686274509803921, 0.4568872112124707
# 899, random_selected_in, SVC, 0.6862745098039216, 0.6635564570655849
# 899, random_selected_drop, SVC, 0.6862745098039216, 0.6635564570655849
# 899, random_selected_stretch, SVC, 0.6470588235294118, 0.6300887494957415
# 899, proportional_selected_on, GradientBoostingClassifier, 0.9215686274509803, 0.9254901960784314
# 899, proportional_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9254901960784314
# 899, proportional_selected_drop, GradientBoostingClassifier, 0.9215686274509803, 0.9254901960784314
# 899, proportional_selected_stretch, GradientBoostingClassifier, 0.9019607843137255, 0.9058823529411765
# 899, proportional_selected_on, DecisionTreeClassifier, 0.9019607843137255, 0.9048886522934967
# 899, proportional_selected_in, DecisionTreeClassifier, 0.8431372549019608, 0.8503841302602912
# 899, proportional_selected_drop, DecisionTreeClassifier, 0.8235294117647058, 0.8324733402132782
# 899, proportional_selected_stretch, DecisionTreeClassifier, 0.8627450980392157, 0.8681372549019609
# 899, proportional_selected_on, SVC, 0.5490196078431373, 0.41503267973856206
# 899, proportional_selected_in, SVC, 0.6862745098039216, 0.6635564570655849
# 899, proportional_selected_drop, SVC, 0.6862745098039216, 0.6635564570655849
# 899, proportional_selected_stretch, SVC, 0.6862745098039216, 0.6635564570655849
# 899, fewest_selected_on, GradientBoostingClassifier, 0.9411764705882353, 0.9428981348637017
# 899, fewest_selected_in, GradientBoostingClassifier, 0.9411764705882353, 0.9423654568210263
# 899, fewest_selected_drop, GradientBoostingClassifier, 0.9019607843137255, 0.9083488599059533
# 899, fewest_selected_stretch, GradientBoostingClassifier, 0.9607843137254902, 0.9607843137254902
# 899, fewest_selected_on, DecisionTreeClassifier, 0.8627450980392157, 0.8707087546096834
# 899, fewest_selected_in, DecisionTreeClassifier, 0.9019607843137255, 0.911706972078489
# 899, fewest_selected_drop, DecisionTreeClassifier, 0.8627450980392157, 0.8676721970839617
# 899, fewest_selected_stretch, DecisionTreeClassifier, 0.8431372549019608, 0.8522698501599674
# 899, fewest_selected_on, SVC, 0.5490196078431373, 0.41503267973856206
# 899, fewest_selected_in, SVC, 0.6862745098039216, 0.6635564570655849
# 899, fewest_selected_drop, SVC, 0.6862745098039216, 0.6635564570655849
# 899, fewest_selected_stretch, SVC, 0.6666666666666666, 0.6659134241932066
# 899, representative_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.9089773164167628
# 899, representative_selected_in, GradientBoostingClassifier, 0.9019607843137255, 0.9083488599059533
# 899, representative_selected_drop, GradientBoostingClassifier, 0.9215686274509803, 0.9254901960784314
# 899, representative_selected_stretch, GradientBoostingClassifier, 0.8627450980392157, 0.87640458876329
# 899, representative_selected_on, DecisionTreeClassifier, 0.8627450980392157, 0.8747097407836123
# 899, representative_selected_in, DecisionTreeClassifier, 0.8627450980392157, 0.8704277032450408
# 899, representative_selected_drop, DecisionTreeClassifier, 0.8431372549019608, 0.8584651322789418
# 899, representative_selected_stretch, DecisionTreeClassifier, 0.8627450980392157, 0.874481658692185
# 899, representative_selected_on, SVC, 0.5686274509803921, 0.4557338086749852
# 899, representative_selected_in, SVC, 0.6666666666666666, 0.6367231638418079
# 899, representative_selected_drop, SVC, 0.6666666666666666, 0.6367231638418079
# 899, representative_selected_stretch, SVC, 0.6274509803921569, 0.6034217608612072
# 899, balanced_on, GradientBoostingClassifier, 0.9019607843137255, 0.9083488599059533
# 899, balanced_on, DecisionTreeClassifier, 0.8627450980392157, 0.8673317280128425
# 899, balanced_on, SVC, 0.6666666666666666, 0.6367231638418079
# 899, balanced_in, GradientBoostingClassifier, 0.9019607843137255, 0.9083488599059533
# 899, balanced_in, DecisionTreeClassifier, 0.8627450980392157, 0.8673317280128425
# 899, balanced_in, SVC, 0.6666666666666666, 0.6367231638418079

# %%
TestUtils.write_csv_file('./starkey_results.csv', final_results)
# Out:
# File successfully written to: ./starkey_results.csv
