# %%
import random

import pandas as pd
from ptrail.core.Datasets import Datasets
from ptrail.features.kinematic_features import KinematicFeatures
from ptrail.preprocessing.statistics import Statistics
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import f1_score, accuracy_score

from src.augmentation.augment import Augmentation
from src.selection.select import Selection
from src.utils.general_utils import Utilities

# %%
BASE = 'base'
TRAINING = 'training'
TEST_X = 'test_x'
TEST_Y = 'test_y'
RANDOM_SELECTED = 'random_selected'
PROPORTIONAL_SELECTED = 'proportional_selected'
FEWEST_SELECTED = 'fewest_selected'
REPRESENTATIVE_SELECTED = 'representative_selected'
BALANCED_ON = 'balanced_on'
BALANCED_IN = 'balanced_in'

# %%
def augment_trajectories(dataset, ids_to_augment, circle, class_col):
    dataset = Augmentation.augment_trajectories_with_randomly_generated_points(dataset,
                                                                               ids_to_augment=ids_to_augment,
                                                                               circle=circle)

    for i in range(1, 3):
        dataset = Augmentation.augment_trajectories_with_randomly_generated_points(dataset,
                                                                                   ids_to_augment=ids_to_augment,
                                                                                   circle=circle)

    pivoted = Statistics.pivot_stats_df(dataframe=Statistics.generate_kinematic_stats(dataset, class_col), target_col_name=class_col)

    return pivoted.drop(columns=[class_col]), pivoted[class_col]

# %%
starkey_data = Datasets.load_starkey()
ready_dataset = KinematicFeatures.create_distance_column(starkey_data).reset_index()
# Out:
# ------------------------ Dataset Facts ------------------------------
#
# Number of unique Trajectories in the data: 253
# Number of points in the data: 287136
# Dataset time range: 1196 days 22:51:45
# Datatype of the DataFrame: <class 'ptrail.core.TrajectoryDF.PTRAILDataFrame'>
# Dataset Bounding Box: (45.18896978643169, -118.61020848239596, 45.314545642992, -118.50455596234036)
#
# ---------------------------------------------------------------------

# %%
def get_test_train_data(seed_val, k=0.8):
    """
        Given the seed value and a proportion, split the
        data into training and testing set and return it.

        Parameters
        ----------
        seed_val: int
            The seed value to use to control the randomness
            while selecting the train-test split.
        k: float
            The percent of data to be used as training data.

        Returns
        -------
            tuple:
                training, testing_x and testing_y
    """
    # Get all the Trajectory Ids and set the random state.
    traj_ids = list(ready_dataset['traj_id'].unique())
    random.seed(seed_val)

    # Select the ids to be used as training set and the calculate subsequent testing ids.
    train_size = int(len(traj_ids) * k)
    train_traj_ids = random.sample(traj_ids, train_size)
    test_traj_ids = [id_ for id_ in traj_ids if id_ not in train_traj_ids]

    # Split the data into training and testing sets.
    training = ready_dataset.loc[ready_dataset.traj_id.isin(train_traj_ids)]
    testing = ready_dataset.loc[ready_dataset.traj_id.isin(test_traj_ids)]

    pivoted_test = Statistics.pivot_stats_df(Statistics.generate_kinematic_stats(testing, 'Species', False), 'Species')

    return training, pivoted_test.drop(columns=['Species']), pivoted_test['Species']

# %%
def get_iterable_map(seed_val: int):
    """
        Given the seed value, generate the dataset based on it,
        and return a dictionary that contains the following values:
            | 1. Training dataset
            | 2. Testing X data.
            | 3. Testing Y data.
            | 4. Randomly selected trajectories to augment.
            | 5. Proportionally selected trajectories to augment.
            | 6. Fewest selected trajectories to augment.
            | 7. Representative selected trajectories to augment.
            | 8. Balanced using ON strategy Dataset.
            | 9. Balanced using IN strategy Dataset.

        Parameters
        ----------
            seed_val: int
                The seed value to use to control the randomness
                while selecting the train-test split.

        Returns
        -------
            dict:
                Dictionary with the aforementioned values.
    """
    training, test_x, test_y = get_test_train_data(seed_val)

    # -------------------------- The trajectory selection strategies --------------------------------- #
    # Random selection.
    random_selected_ids = Selection.select_randomly(training, seed=seed_val, k=0.2)

    # Proportional selection.
    proportional_selected = Selection.select_trajectories_proportionally(training, classification_col='Species', seed=seed_val, k=0.2)

    # Fewest selection.
    fewest_selected = Selection.select_with_fewest_points(training, k=0.2)

    # Representative Selection
    rep_selected = Selection.select_representative_trajectories(training, 'Species', closeness_cutoff=0.7, tolerance=10)

    # Balance the dataset.
    balanced_on = Augmentation.balance_dataset_with_augmentation(training, 'Species', 'on')
    balanced_in = Augmentation.balance_dataset_with_augmentation(training, 'Species', 'in')

    # ------------------------ Create the iterable map to be returned ---------------------------------- #
    return {
        TRAINING: training,
        TEST_X: test_x,
        TEST_Y: test_y,
        RANDOM_SELECTED: random_selected_ids,
        PROPORTIONAL_SELECTED: proportional_selected,
        FEWEST_SELECTED: fewest_selected,
        REPRESENTATIVE_SELECTED: rep_selected,
        BALANCED_ON: balanced_on,
        BALANCED_IN: balanced_in,
    }

# %%
def select_correct_test_train_split(iter_map, strat, circle_strat):
    x_train, y_train = None, None
    if strategy != BASE:
        if not "balanced" in strat:
            x_train, y_train = augment_trajectories(dataset=iter_map[TRAINING], ids_to_augment=iter_map[strat],
                                                    circle=circle_strat, class_col='Species')
        if "balanced" in strat and circle_strat == "on":
            training = Statistics.pivot_stats_df(Statistics.generate_kinematic_stats(iter_map[BALANCED_ON], 'Species'), 'Species')
            x_train, y_train = training.drop(columns=['Species']), training['Species']
        if "balanced" in strategy and circle_strat == "in":
            training = Statistics.pivot_stats_df(Statistics.generate_kinematic_stats(iter_map[BALANCED_IN], 'Species'), 'Species')
            x_train, y_train = training.drop(columns=['Species']), training['Species']
    else:
        training = Statistics.pivot_stats_df(Statistics.generate_kinematic_stats(iter_map[TRAINING], "Species"), "Species")
        x_train = training.drop(columns=["Species"])
        y_train = training['Species']

    return x_train, y_train

# %%
# Get the 20 seed values that we are going to use.
seed_generator = Utilities.generate_pi_seed(20)
seed_vals = [next(seed_generator) for i in range(20)]
final_results = ["seed, strategy, model, accuracy, f1_score"]

# All our selection strategies.
select_strategies = [BASE, RANDOM_SELECTED, PROPORTIONAL_SELECTED, FEWEST_SELECTED, REPRESENTATIVE_SELECTED, BALANCED_ON, BALANCED_IN]
models = [GradientBoostingClassifier(), DecisionTreeClassifier(), SVC()]

for seed in seed_vals:
    # Get the iterable map for the seed.
    iter_map = get_iterable_map(seed)
    for strategy in select_strategies:
        for model in models:
            for circle_strategy in ['on', 'in']:
                train_x, train_y = select_correct_test_train_split(iter_map, strategy, circle_strategy)
                if (train_x is not None) and (train_y is not None):
                    # Fit the model and predict.
                    model.random_state = seed
                    model.fit(X=train_x, y=train_y)
                    pred_vals = model.predict(X=iter_map[TEST_X])

                    # Calculate the accuracy and f1 score.
                    acc = accuracy_score(y_true=iter_map[TEST_Y], y_pred=pred_vals)
                    score = f1_score(y_true=iter_map[TEST_Y], y_pred=pred_vals, average='weighted')
                    print(f"{seed}, {strategy}_{circle_strategy}, {model.__class__.__name__}, {acc}, {score}")
                    final_results.append(f"{seed}, {strategy}_{circle_strategy}, {model.__class__.__name__}, {acc}, {score}")
# Out:
# 1415, base_on, GradientBoostingClassifier, 0.9607843137254902, 0.9607843137254902
# 1415, base_in, GradientBoostingClassifier, 0.9607843137254902, 0.9607843137254902
# 1415, base_on, DecisionTreeClassifier, 0.9019607843137255, 0.9004022121669181
# 1415, base_in, DecisionTreeClassifier, 0.9019607843137255, 0.9004022121669181
# 1415, base_on, SVC, 0.7450980392156863, 0.7228962463259572
# 1415, base_in, SVC, 0.7450980392156863, 0.7228962463259572
# 1415, random_selected_on, GradientBoostingClassifier, 0.9803921568627451, 0.980125383486728
# 1415, random_selected_in, GradientBoostingClassifier, 0.9803921568627451, 0.980125383486728
# 1415, random_selected_on, DecisionTreeClassifier, 0.9019607843137255, 0.9016122578063483
# 1415, random_selected_in, DecisionTreeClassifier, 0.9215686274509803, 0.9218300653594772
# 1415, random_selected_on, SVC, 0.47058823529411764, 0.30117647058823527
# 1415, random_selected_in, SVC, 0.8235294117647058, 0.8197841374311963
# 1415, proportional_selected_on, GradientBoostingClassifier, 0.9411764705882353, 0.94213898743228
# 1415, proportional_selected_in, GradientBoostingClassifier, 0.9607843137254902, 0.9607843137254902
# 1415, proportional_selected_on, DecisionTreeClassifier, 0.9019607843137255, 0.9016122578063483
# 1415, proportional_selected_in, DecisionTreeClassifier, 0.9215686274509803, 0.9213172448466567
# 1415, proportional_selected_on, SVC, 0.47058823529411764, 0.30117647058823527
# 1415, proportional_selected_in, SVC, 0.7450980392156863, 0.7228962463259572
# 1415, fewest_selected_on, GradientBoostingClassifier, 0.9803921568627451, 0.980125383486728
# 1415, fewest_selected_in, GradientBoostingClassifier, 0.9803921568627451, 0.980125383486728
# 1415, fewest_selected_on, DecisionTreeClassifier, 0.8235294117647058, 0.8206245461147421
# 1415, fewest_selected_in, DecisionTreeClassifier, 0.9215686274509803, 0.921852612012547
# 1415, fewest_selected_on, SVC, 0.5098039215686274, 0.3791446563404662
# 1415, fewest_selected_in, SVC, 0.8823529411764706, 0.8824346714813247
# 1415, representative_selected_on, GradientBoostingClassifier, 0.9607843137254902, 0.95932069797616
# 1415, representative_selected_in, GradientBoostingClassifier, 0.9803921568627451, 0.980125383486728
# 1415, representative_selected_on, DecisionTreeClassifier, 0.8823529411764706, 0.8823529411764706
# 1415, representative_selected_in, DecisionTreeClassifier, 0.9215686274509803, 0.9213172448466567
# 1415, representative_selected_on, SVC, 0.47058823529411764, 0.30117647058823527
# 1415, representative_selected_in, SVC, 0.7450980392156863, 0.7228962463259572
# 1415, balanced_on_on, GradientBoostingClassifier, 0.9607843137254902, 0.9607843137254902
# 1415, balanced_on_in, GradientBoostingClassifier, 0.9607843137254902, 0.9607843137254902
# 1415, balanced_on_on, DecisionTreeClassifier, 0.9019607843137255, 0.899675948810897
# 1415, balanced_on_in, DecisionTreeClassifier, 0.9215686274509803, 0.9215686274509803
# 1415, balanced_on_on, SVC, 0.49019607843137253, 0.34215530409302036
# 1415, balanced_on_in, SVC, 0.7843137254901961, 0.7830733757698917
# 1415, balanced_in_on, GradientBoostingClassifier, 0.9607843137254902, 0.9607843137254902
# 1415, balanced_in_in, GradientBoostingClassifier, 0.9607843137254902, 0.9607843137254902
# 1415, balanced_in_on, DecisionTreeClassifier, 0.9019607843137255, 0.899675948810897
# 1415, balanced_in_in, DecisionTreeClassifier, 0.9215686274509803, 0.9215686274509803
# 1415, balanced_in_on, SVC, 0.49019607843137253, 0.34215530409302036
# 1415, balanced_in_in, SVC, 0.7843137254901961, 0.7830733757698917
# 9265, base_on, GradientBoostingClassifier, 0.9411764705882353, 0.9412469164989099
# 9265, base_in, GradientBoostingClassifier, 0.9411764705882353, 0.9412469164989099
# 9265, base_on, DecisionTreeClassifier, 0.8431372549019608, 0.8485714285714286
# 9265, base_in, DecisionTreeClassifier, 0.8431372549019608, 0.8485714285714286
# 9265, base_on, SVC, 0.6470588235294118, 0.6293082450371452
# 9265, base_in, SVC, 0.6470588235294118, 0.6293082450371452
# 9265, random_selected_on, GradientBoostingClassifier, 0.9215686274509803, 0.9234360410830998
# 9265, random_selected_in, GradientBoostingClassifier, 0.9411764705882353, 0.9412469164989099
# 9265, random_selected_on, DecisionTreeClassifier, 0.9019607843137255, 0.9015089906930515
# 9265, random_selected_in, DecisionTreeClassifier, 0.9215686274509803, 0.920922215039862
# 9265, random_selected_on, SVC, 0.49019607843137253, 0.3224974200206398
# 9265, random_selected_in, SVC, 0.7450980392156863, 0.7441261244480742
# 9265, proportional_selected_on, GradientBoostingClassifier, 0.9411764705882353, 0.9421171767057648
# 9265, proportional_selected_in, GradientBoostingClassifier, 0.9411764705882353, 0.9405300581771169
# 9265, proportional_selected_on, DecisionTreeClassifier, 0.9019607843137255, 0.9019607843137255
# 9265, proportional_selected_in, DecisionTreeClassifier, 0.8627450980392157, 0.8653402537485584
# 9265, proportional_selected_on, SVC, 0.49019607843137253, 0.3224974200206398
# 9265, proportional_selected_in, SVC, 0.6862745098039216, 0.6784566322503235
# 9265, fewest_selected_on, GradientBoostingClassifier, 0.9607843137254902, 0.9606384812207507
# 9265, fewest_selected_in, GradientBoostingClassifier, 0.9607843137254902, 0.9607335418694446
# 9265, fewest_selected_on, DecisionTreeClassifier, 0.8627450980392157, 0.8636238809249189
# 9265, fewest_selected_in, DecisionTreeClassifier, 0.9019607843137255, 0.9015522875816993
# 9265, fewest_selected_on, SVC, 0.5490196078431373, 0.47511312217194573
# 9265, fewest_selected_in, SVC, 0.7058823529411765, 0.7058823529411765
# 9265, representative_selected_on, GradientBoostingClassifier, 0.9411764705882353, 0.9412469164989099
# 9265, representative_selected_in, GradientBoostingClassifier, 0.9607843137254902, 0.9606384812207507
# 9265, representative_selected_on, DecisionTreeClassifier, 0.9019607843137255, 0.9019607843137255
# 9265, representative_selected_in, DecisionTreeClassifier, 0.9019607843137255, 0.9025838868339764
# 9265, representative_selected_on, SVC, 0.5098039215686274, 0.3627450980392156
# 9265, representative_selected_in, SVC, 0.6470588235294118, 0.6293082450371452
# 9265, balanced_on_on, GradientBoostingClassifier, 0.9215686274509803, 0.9215686274509803
# 9265, balanced_on_in, GradientBoostingClassifier, 0.8823529411764706, 0.887935737532216
# 9265, balanced_on_on, DecisionTreeClassifier, 0.9019607843137255, 0.9025374855824683
# 9265, balanced_on_in, DecisionTreeClassifier, 0.9215686274509803, 0.9213382965918463
# 9265, balanced_on_on, SVC, 0.5490196078431373, 0.46685340802987857
# 9265, balanced_on_in, SVC, 0.7254901960784313, 0.7237076648841354
# 9265, balanced_in_on, GradientBoostingClassifier, 0.9215686274509803, 0.9215686274509803
# 9265, balanced_in_in, GradientBoostingClassifier, 0.8823529411764706, 0.887935737532216
# 9265, balanced_in_on, DecisionTreeClassifier, 0.9019607843137255, 0.9025374855824683
# 9265, balanced_in_in, DecisionTreeClassifier, 0.9215686274509803, 0.9213382965918463
# 9265, balanced_in_on, SVC, 0.5490196078431373, 0.46685340802987857
# 9265, balanced_in_in, SVC, 0.7254901960784313, 0.7237076648841354
# 3589, base_on, GradientBoostingClassifier, 0.9411764705882353, 0.9416912017645035
# 3589, base_in, GradientBoostingClassifier, 0.9411764705882353, 0.9416912017645035
# 3589, base_on, DecisionTreeClassifier, 0.8431372549019608, 0.8472912569283033
# 3589, base_in, DecisionTreeClassifier, 0.8431372549019608, 0.8472912569283033
# 3589, base_on, SVC, 0.7254901960784313, 0.7184830044870613
# 3589, base_in, SVC, 0.7254901960784313, 0.7184830044870613
# 3589, random_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.9022820170379813
# 3589, random_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9212540631225753
# 3589, random_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.8389161220043574
# 3589, random_selected_in, DecisionTreeClassifier, 0.7450980392156863, 0.7551619132501486
# 3589, random_selected_on, SVC, 0.5098039215686274, 0.36209150326797385
# 3589, random_selected_in, SVC, 0.7254901960784313, 0.7131827389825327
# 3589, proportional_selected_on, GradientBoostingClassifier, 0.9215686274509803, 0.9228361300244322
# 3589, proportional_selected_in, GradientBoostingClassifier, 0.9411764705882353, 0.9416912017645035
# 3589, proportional_selected_on, DecisionTreeClassifier, 0.8627450980392157, 0.8627931278436566
# 3589, proportional_selected_in, DecisionTreeClassifier, 0.7450980392156863, 0.7566841229245322
# 3589, proportional_selected_on, SVC, 0.49019607843137253, 0.3224974200206398
# 3589, proportional_selected_in, SVC, 0.7647058823529411, 0.7592968221771468
# 3589, fewest_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.9036494980767426
# 3589, fewest_selected_in, GradientBoostingClassifier, 0.9411764705882353, 0.9396386005382545
# 3589, fewest_selected_on, DecisionTreeClassifier, 0.9019607843137255, 0.9035403635138266
# 3589, fewest_selected_in, DecisionTreeClassifier, 0.7254901960784313, 0.7366761197232518
# 3589, fewest_selected_on, SVC, 0.5490196078431373, 0.46493656286043833
# 3589, fewest_selected_in, SVC, 0.7254901960784313, 0.7259703881552622
# 3589, representative_selected_on, GradientBoostingClassifier, 0.9215686274509803, 0.9228361300244322
# 3589, representative_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9228361300244322
# 3589, representative_selected_on, DecisionTreeClassifier, 0.8823529411764706, 0.8836836948568167
# 3589, representative_selected_in, DecisionTreeClassifier, 0.8627450980392157, 0.8650916506953658
# 3589, representative_selected_on, SVC, 0.5098039215686274, 0.36209150326797385
# 3589, representative_selected_in, SVC, 0.6274509803921569, 0.6218200100553042
# 3589, balanced_on_on, GradientBoostingClassifier, 0.8823529411764706, 0.8838235294117647
# 3589, balanced_on_in, GradientBoostingClassifier, 0.9215686274509803, 0.924264705882353
# 3589, balanced_on_on, DecisionTreeClassifier, 0.7450980392156863, 0.7463630613535737
# 3589, balanced_on_in, DecisionTreeClassifier, 0.8823529411764706, 0.8821928771508604
# 3589, balanced_on_on, SVC, 0.5490196078431373, 0.46493656286043833
# 3589, balanced_on_in, SVC, 0.6470588235294118, 0.6438243558986594
# 3589, balanced_in_on, GradientBoostingClassifier, 0.8823529411764706, 0.8838235294117647
# 3589, balanced_in_in, GradientBoostingClassifier, 0.9215686274509803, 0.924264705882353
# 3589, balanced_in_on, DecisionTreeClassifier, 0.7450980392156863, 0.7463630613535737
# 3589, balanced_in_in, DecisionTreeClassifier, 0.8823529411764706, 0.8821928771508604
# 3589, balanced_in_on, SVC, 0.5490196078431373, 0.46493656286043833
# 3589, balanced_in_in, SVC, 0.6470588235294118, 0.6438243558986594
# 7932, base_on, GradientBoostingClassifier, 0.9215686274509803, 0.9206853912736266
# 7932, base_in, GradientBoostingClassifier, 0.9215686274509803, 0.9206853912736266
# 7932, base_on, DecisionTreeClassifier, 0.8235294117647058, 0.8156276793292574
# 7932, base_in, DecisionTreeClassifier, 0.8235294117647058, 0.8156276793292574
# 7932, base_on, SVC, 0.6470588235294118, 0.6362817719680465
# 7932, base_in, SVC, 0.6470588235294118, 0.6362817719680465
# 7932, random_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.9020401682940382
# 7932, random_selected_in, GradientBoostingClassifier, 0.9019607843137255, 0.8999550157444893
# 7932, random_selected_on, DecisionTreeClassifier, 0.8627450980392157, 0.8630319421394471
# 7932, random_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.8822806294426521
# 7932, random_selected_on, SVC, 0.3333333333333333, 0.16666666666666666
# 7932, random_selected_in, SVC, 0.6274509803921569, 0.6097536450477626
# 7932, proportional_selected_on, GradientBoostingClassifier, 0.8823529411764706, 0.8817231615993225
# 7932, proportional_selected_in, GradientBoostingClassifier, 0.8627450980392157, 0.8614406261465085
# 7932, proportional_selected_on, DecisionTreeClassifier, 0.9019607843137255, 0.9020725099156472
# 7932, proportional_selected_in, DecisionTreeClassifier, 0.9019607843137255, 0.897885116106063
# 7932, proportional_selected_on, SVC, 0.3333333333333333, 0.16666666666666666
# 7932, proportional_selected_in, SVC, 0.6666666666666666, 0.6613845538215287
# 7932, fewest_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.8999550157444893
# 7932, fewest_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9191606467148262
# 7932, fewest_selected_on, DecisionTreeClassifier, 0.7843137254901961, 0.7878404911222249
# 7932, fewest_selected_in, DecisionTreeClassifier, 0.8431372549019608, 0.8448402954648283
# 7932, fewest_selected_on, SVC, 0.37254901960784315, 0.24301841948900774
# 7932, fewest_selected_in, SVC, 0.7450980392156863, 0.7520506424183901
# 7932, representative_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.8999550157444893
# 7932, representative_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9206853912736266
# 7932, representative_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.8426683601915801
# 7932, representative_selected_in, DecisionTreeClassifier, 0.9019607843137255, 0.9005747829277242
# 7932, representative_selected_on, SVC, 0.3333333333333333, 0.16666666666666666
# 7932, representative_selected_in, SVC, 0.6470588235294118, 0.6443035835023665
# 7932, balanced_on_on, GradientBoostingClassifier, 0.9215686274509803, 0.9206853912736266
# 7932, balanced_on_in, GradientBoostingClassifier, 0.9215686274509803, 0.9206853912736266
# 7932, balanced_on_on, DecisionTreeClassifier, 0.803921568627451, 0.8062575760344521
# 7932, balanced_on_in, DecisionTreeClassifier, 0.9019607843137255, 0.8984631690514044
# 7932, balanced_on_on, SVC, 0.37254901960784315, 0.24301841948900774
# 7932, balanced_on_in, SVC, 0.6862745098039216, 0.6896714158377445
# 7932, balanced_in_on, GradientBoostingClassifier, 0.9215686274509803, 0.9206853912736266
# 7932, balanced_in_in, GradientBoostingClassifier, 0.9215686274509803, 0.9206853912736266
# 7932, balanced_in_on, DecisionTreeClassifier, 0.803921568627451, 0.8062575760344521
# 7932, balanced_in_in, DecisionTreeClassifier, 0.9019607843137255, 0.8984631690514044
# 7932, balanced_in_on, SVC, 0.37254901960784315, 0.24301841948900774
# 7932, balanced_in_in, SVC, 0.6862745098039216, 0.6896714158377445
# 3846, base_on, GradientBoostingClassifier, 0.9019607843137255, 0.8918248226206704
# 3846, base_in, GradientBoostingClassifier, 0.9019607843137255, 0.8918248226206704
# 3846, base_on, DecisionTreeClassifier, 0.8627450980392157, 0.8561242678889738
# 3846, base_in, DecisionTreeClassifier, 0.8627450980392157, 0.8561242678889738
# 3846, base_on, SVC, 0.7647058823529411, 0.7635948024694829
# 3846, base_in, SVC, 0.7647058823529411, 0.7635948024694829
# 3846, random_selected_on, GradientBoostingClassifier, 0.8823529411764706, 0.8650610209208074
# 3846, random_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9164015530797539
# 3846, random_selected_on, DecisionTreeClassifier, 0.8235294117647058, 0.803921568627451
# 3846, random_selected_in, DecisionTreeClassifier, 0.8235294117647058, 0.8251471711679326
# 3846, random_selected_on, SVC, 0.6470588235294118, 0.5398799086030076
# 3846, random_selected_in, SVC, 0.7450980392156863, 0.7437908496732025
# 3846, proportional_selected_on, GradientBoostingClassifier, 0.9215686274509803, 0.9164015530797539
# 3846, proportional_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9164015530797539
# 3846, proportional_selected_on, DecisionTreeClassifier, 0.7450980392156863, 0.738341986918837
# 3846, proportional_selected_in, DecisionTreeClassifier, 0.8431372549019608, 0.8444249076442172
# 3846, proportional_selected_on, SVC, 0.6666666666666666, 0.5493870908470483
# 3846, proportional_selected_in, SVC, 0.7450980392156863, 0.7457978118783746
# 3846, fewest_selected_on, GradientBoostingClassifier, 0.8823529411764706, 0.8650610209208074
# 3846, fewest_selected_in, GradientBoostingClassifier, 0.9019607843137255, 0.8918248226206704
# 3846, fewest_selected_on, DecisionTreeClassifier, 0.803921568627451, 0.7990032133254641
# 3846, fewest_selected_in, DecisionTreeClassifier, 0.803921568627451, 0.7994245524296676
# 3846, fewest_selected_on, SVC, 0.7450980392156863, 0.7047930283224401
# 3846, fewest_selected_in, SVC, 0.7254901960784313, 0.7285677785195626
# 3846, representative_selected_on, GradientBoostingClassifier, 0.8823529411764706, 0.8639851197395956
# 3846, representative_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9164015530797539
# 3846, representative_selected_on, DecisionTreeClassifier, 0.803921568627451, 0.8013071895424838
# 3846, representative_selected_in, DecisionTreeClassifier, 0.8627450980392157, 0.862689393939394
# 3846, representative_selected_on, SVC, 0.6470588235294118, 0.5461147421931736
# 3846, representative_selected_in, SVC, 0.7450980392156863, 0.7457978118783746
# 3846, balanced_on_on, GradientBoostingClassifier, 0.9215686274509803, 0.9164015530797539
# 3846, balanced_on_in, GradientBoostingClassifier, 0.9019607843137255, 0.8918248226206704
# 3846, balanced_on_on, DecisionTreeClassifier, 0.803921568627451, 0.7968020541549953
# 3846, balanced_on_in, DecisionTreeClassifier, 0.7843137254901961, 0.7727869743215012
# 3846, balanced_on_on, SVC, 0.7450980392156863, 0.735989116611954
# 3846, balanced_on_in, SVC, 0.6862745098039216, 0.6993521866951116
# 3846, balanced_in_on, GradientBoostingClassifier, 0.9215686274509803, 0.9164015530797539
# 3846, balanced_in_in, GradientBoostingClassifier, 0.9019607843137255, 0.8918248226206704
# 3846, balanced_in_on, DecisionTreeClassifier, 0.803921568627451, 0.7968020541549953
# 3846, balanced_in_in, DecisionTreeClassifier, 0.7843137254901961, 0.7727869743215012
# 3846, balanced_in_on, SVC, 0.7450980392156863, 0.735989116611954
# 3846, balanced_in_in, SVC, 0.6862745098039216, 0.6993521866951116
# 2643, base_on, GradientBoostingClassifier, 0.9803921568627451, 0.9811652259470097
# 2643, base_in, GradientBoostingClassifier, 0.9803921568627451, 0.9811652259470097
# 2643, base_on, DecisionTreeClassifier, 0.9215686274509803, 0.9239390685280198
# 2643, base_in, DecisionTreeClassifier, 0.9215686274509803, 0.9239390685280198
# 2643, base_on, SVC, 0.7450980392156863, 0.7398864526653574
# 2643, base_in, SVC, 0.7450980392156863, 0.7398864526653574
# 2643, random_selected_on, GradientBoostingClassifier, 0.9607843137254902, 0.9607220666044196
# 2643, random_selected_in, GradientBoostingClassifier, 0.9803921568627451, 0.9802315191309499
# 2643, random_selected_on, DecisionTreeClassifier, 0.9607843137254902, 0.9640522875816993
# 2643, random_selected_in, DecisionTreeClassifier, 0.9019607843137255, 0.9054846279282504
# 2643, random_selected_on, SVC, 0.6078431372549019, 0.45958871353419406
# 2643, random_selected_in, SVC, 0.7647058823529411, 0.7529543804053609
# 2643, proportional_selected_on, GradientBoostingClassifier, 0.9803921568627451, 0.9802315191309499
# 2643, proportional_selected_in, GradientBoostingClassifier, 0.9803921568627451, 0.9811652259470097
# 2643, proportional_selected_on, DecisionTreeClassifier, 0.9411764705882353, 0.9482280106568531
# 2643, proportional_selected_in, DecisionTreeClassifier, 0.9607843137254902, 0.961284121491734
# 2643, proportional_selected_on, SVC, 0.6078431372549019, 0.45958871353419406
# 2643, proportional_selected_in, SVC, 0.7647058823529411, 0.7529543804053609
# 2643, fewest_selected_on, GradientBoostingClassifier, 0.9803921568627451, 0.9805285253694125
# 2643, fewest_selected_in, GradientBoostingClassifier, 1.0, 1.0
# 2643, fewest_selected_on, DecisionTreeClassifier, 0.9411764705882353, 0.941923684284836
# 2643, fewest_selected_in, DecisionTreeClassifier, 0.9411764705882353, 0.9414254590725178
# 2643, fewest_selected_on, SVC, 0.6470588235294118, 0.6006787330316742
# 2643, fewest_selected_in, SVC, 0.7254901960784313, 0.7277777777777776
# 2643, representative_selected_on, GradientBoostingClassifier, 0.9607843137254902, 0.9607220666044196
# 2643, representative_selected_in, GradientBoostingClassifier, 0.9803921568627451, 0.9811652259470097
# 2643, representative_selected_on, DecisionTreeClassifier, 0.9607843137254902, 0.9640522875816993
# 2643, representative_selected_in, DecisionTreeClassifier, 0.9803921568627451, 0.9813207614557663
# 2643, representative_selected_on, SVC, 0.6470588235294118, 0.5233660130718955
# 2643, representative_selected_in, SVC, 0.7647058823529411, 0.7582983193277312
# 2643, balanced_on_on, GradientBoostingClassifier, 0.9803921568627451, 0.9813207614557663
# 2643, balanced_on_in, GradientBoostingClassifier, 1.0, 1.0
# 2643, balanced_on_on, DecisionTreeClassifier, 0.9019607843137255, 0.9036178456056753
# 2643, balanced_on_in, DecisionTreeClassifier, 0.9215686274509803, 0.9280945043656907
# 2643, balanced_on_on, SVC, 0.6078431372549019, 0.5526831179005092
# 2643, balanced_on_in, SVC, 0.7254901960784313, 0.7276535565493254
# 2643, balanced_in_on, GradientBoostingClassifier, 0.9803921568627451, 0.9813207614557663
# 2643, balanced_in_in, GradientBoostingClassifier, 1.0, 1.0
# 2643, balanced_in_on, DecisionTreeClassifier, 0.9019607843137255, 0.9036178456056753
# 2643, balanced_in_in, DecisionTreeClassifier, 0.9215686274509803, 0.9280945043656907
# 2643, balanced_in_on, SVC, 0.6078431372549019, 0.5526831179005092
# 2643, balanced_in_in, SVC, 0.7254901960784313, 0.7276535565493254
# 3832, base_on, GradientBoostingClassifier, 0.9607843137254902, 0.9611804317686671
# 3832, base_in, GradientBoostingClassifier, 0.9607843137254902, 0.9611804317686671
# 3832, base_on, DecisionTreeClassifier, 0.9019607843137255, 0.9011488653432387
# 3832, base_in, DecisionTreeClassifier, 0.9019607843137255, 0.9011488653432387
# 3832, base_on, SVC, 0.7254901960784313, 0.7254901960784313
# 3832, base_in, SVC, 0.7254901960784313, 0.7254901960784313
# 3832, random_selected_on, GradientBoostingClassifier, 0.9803921568627451, 0.9798941798941799
# 3832, random_selected_in, GradientBoostingClassifier, 0.9607843137254902, 0.9611804317686671
# 3832, random_selected_on, DecisionTreeClassifier, 0.9215686274509803, 0.9215686274509803
# 3832, random_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.8839576751416679
# 3832, random_selected_on, SVC, 0.6078431372549019, 0.45958871353419406
# 3832, random_selected_in, SVC, 0.7843137254901961, 0.7804099015171679
# 3832, proportional_selected_on, GradientBoostingClassifier, 0.9803921568627451, 0.9798941798941799
# 3832, proportional_selected_in, GradientBoostingClassifier, 1.0, 1.0
# 3832, proportional_selected_on, DecisionTreeClassifier, 0.8823529411764706, 0.8733271086212264
# 3832, proportional_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.8876590313008073
# 3832, proportional_selected_on, SVC, 0.5882352941176471, 0.4502541757443718
# 3832, proportional_selected_in, SVC, 0.7647058823529411, 0.7646055864801165
# 3832, fewest_selected_on, GradientBoostingClassifier, 0.9607843137254902, 0.9607843137254902
# 3832, fewest_selected_in, GradientBoostingClassifier, 1.0, 1.0
# 3832, fewest_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.8448957210656683
# 3832, fewest_selected_in, DecisionTreeClassifier, 0.9215686274509803, 0.9168253968253968
# 3832, fewest_selected_on, SVC, 0.6470588235294118, 0.5776364599894012
# 3832, fewest_selected_in, SVC, 0.7254901960784313, 0.7317605116913075
# 3832, representative_selected_on, GradientBoostingClassifier, 0.9607843137254902, 0.9585959383753501
# 3832, representative_selected_in, GradientBoostingClassifier, 1.0, 1.0
# 3832, representative_selected_on, DecisionTreeClassifier, 0.9019607843137255, 0.8926237161531279
# 3832, representative_selected_in, DecisionTreeClassifier, 0.9019607843137255, 0.9011488653432387
# 3832, representative_selected_on, SVC, 0.7058823529411765, 0.6597462514417533
# 3832, representative_selected_in, SVC, 0.7450980392156863, 0.7428744522170129
# 3832, balanced_on_on, GradientBoostingClassifier, 0.9607843137254902, 0.9610157505625201
# 3832, balanced_on_in, GradientBoostingClassifier, 0.9607843137254902, 0.9623759854777423
# 3832, balanced_on_on, DecisionTreeClassifier, 0.9019607843137255, 0.8922662141779789
# 3832, balanced_on_in, DecisionTreeClassifier, 0.9019607843137255, 0.9077683552444624
# 3832, balanced_on_on, SVC, 0.6470588235294118, 0.5776364599894012
# 3832, balanced_on_in, SVC, 0.6862745098039216, 0.6917460132017057
# 3832, balanced_in_on, GradientBoostingClassifier, 0.9607843137254902, 0.9610157505625201
# 3832, balanced_in_in, GradientBoostingClassifier, 0.9607843137254902, 0.9623759854777423
# 3832, balanced_in_on, DecisionTreeClassifier, 0.9019607843137255, 0.8922662141779789
# 3832, balanced_in_in, DecisionTreeClassifier, 0.9019607843137255, 0.9077683552444624
# 3832, balanced_in_on, SVC, 0.6470588235294118, 0.5776364599894012
# 3832, balanced_in_in, SVC, 0.6862745098039216, 0.6917460132017057
# 7950, base_on, GradientBoostingClassifier, 0.9215686274509803, 0.9226325793817852
# 7950, base_in, GradientBoostingClassifier, 0.9215686274509803, 0.9226325793817852
# 7950, base_on, DecisionTreeClassifier, 0.8235294117647058, 0.8253679180650589
# 7950, base_in, DecisionTreeClassifier, 0.8235294117647058, 0.8253679180650589
# 7950, base_on, SVC, 0.6862745098039216, 0.6778711484593837
# 7950, base_in, SVC, 0.6862745098039216, 0.6778711484593837
# 7950, random_selected_on, GradientBoostingClassifier, 0.9215686274509803, 0.922167848463664
# 7950, random_selected_in, GradientBoostingClassifier, 0.9607843137254902, 0.9606530378432566
# 7950, random_selected_on, DecisionTreeClassifier, 0.8823529411764706, 0.8823068050749711
# 7950, random_selected_in, DecisionTreeClassifier, 0.8627450980392157, 0.8639455782312925
# 7950, random_selected_on, SVC, 0.5098039215686274, 0.34428316781257956
# 7950, random_selected_in, SVC, 0.6470588235294118, 0.6399297771135072
# 7950, proportional_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.9029320706610818
# 7950, proportional_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9226325793817852
# 7950, proportional_selected_on, DecisionTreeClassifier, 0.8235294117647058, 0.8253679180650589
# 7950, proportional_selected_in, DecisionTreeClassifier, 0.8431372549019608, 0.8461762413943907
# 7950, proportional_selected_on, SVC, 0.5098039215686274, 0.34428316781257956
# 7950, proportional_selected_in, SVC, 0.6862745098039216, 0.6771695531191217
# 7950, fewest_selected_on, GradientBoostingClassifier, 0.9215686274509803, 0.9218831917793855
# 7950, fewest_selected_in, GradientBoostingClassifier, 0.9019607843137255, 0.9032679738562092
# 7950, fewest_selected_on, DecisionTreeClassifier, 0.7647058823529411, 0.7691076430572229
# 7950, fewest_selected_in, DecisionTreeClassifier, 0.7450980392156863, 0.7640522875816993
# 7950, fewest_selected_on, SVC, 0.5686274509803921, 0.4954555940023069
# 7950, fewest_selected_in, SVC, 0.6862745098039216, 0.6884531590413944
# 7950, representative_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.9029320706610818
# 7950, representative_selected_in, GradientBoostingClassifier, 0.9411764705882353, 0.9416022483140889
# 7950, representative_selected_on, DecisionTreeClassifier, 0.8823529411764706, 0.8832616825696411
# 7950, representative_selected_in, DecisionTreeClassifier, 0.8627450980392157, 0.8628637337287856
# 7950, representative_selected_on, SVC, 0.5098039215686274, 0.41585699580728575
# 7950, representative_selected_in, SVC, 0.6666666666666666, 0.6576977202364199
# 7950, balanced_on_on, GradientBoostingClassifier, 0.9215686274509803, 0.9241830065359479
# 7950, balanced_on_in, GradientBoostingClassifier, 0.9019607843137255, 0.9059209890852893
# 7950, balanced_on_on, DecisionTreeClassifier, 0.803921568627451, 0.8054215234480889
# 7950, balanced_on_in, DecisionTreeClassifier, 0.8235294117647058, 0.8292473118279571
# 7950, balanced_on_on, SVC, 0.5098039215686274, 0.4199313528228192
# 7950, balanced_on_in, SVC, 0.6470588235294118, 0.6471758353810406
# 7950, balanced_in_on, GradientBoostingClassifier, 0.9215686274509803, 0.9241830065359479
# 7950, balanced_in_in, GradientBoostingClassifier, 0.9019607843137255, 0.9059209890852893
# 7950, balanced_in_on, DecisionTreeClassifier, 0.803921568627451, 0.8054215234480889
# 7950, balanced_in_in, DecisionTreeClassifier, 0.8235294117647058, 0.8292473118279571
# 7950, balanced_in_on, SVC, 0.5098039215686274, 0.4199313528228192
# 7950, balanced_in_in, SVC, 0.6470588235294118, 0.6471758353810406
# 2884, base_on, GradientBoostingClassifier, 0.9215686274509803, 0.9205617911500263
# 2884, base_in, GradientBoostingClassifier, 0.9215686274509803, 0.9205617911500263
# 2884, base_on, DecisionTreeClassifier, 0.8431372549019608, 0.8431372549019608
# 2884, base_in, DecisionTreeClassifier, 0.8431372549019608, 0.8431372549019608
# 2884, base_on, SVC, 0.7254901960784313, 0.7311229946524065
# 2884, base_in, SVC, 0.7254901960784313, 0.7311229946524065
# 2884, random_selected_on, GradientBoostingClassifier, 0.9411764705882353, 0.9411764705882353
# 2884, random_selected_in, GradientBoostingClassifier, 0.9411764705882353, 0.9400759513291481
# 2884, random_selected_on, DecisionTreeClassifier, 0.803921568627451, 0.8069381598793364
# 2884, random_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.8850441167190674
# 2884, random_selected_on, SVC, 0.5098039215686274, 0.41848739495798315
# 2884, random_selected_in, SVC, 0.7843137254901961, 0.7889116143712487
# 2884, proportional_selected_on, GradientBoostingClassifier, 0.9215686274509803, 0.9208246144307526
# 2884, proportional_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9205617911500263
# 2884, proportional_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.8449574546799852
# 2884, proportional_selected_in, DecisionTreeClassifier, 0.8235294117647058, 0.8245652978172401
# 2884, proportional_selected_on, SVC, 0.5294117647058824, 0.36651583710407243
# 2884, proportional_selected_in, SVC, 0.7843137254901961, 0.7889116143712487
# 2884, fewest_selected_on, GradientBoostingClassifier, 0.9411764705882353, 0.9400759513291481
# 2884, fewest_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9205617911500263
# 2884, fewest_selected_on, DecisionTreeClassifier, 0.8627450980392157, 0.8623575912578471
# 2884, fewest_selected_in, DecisionTreeClassifier, 0.9411764705882353, 0.9419266837169651
# 2884, fewest_selected_on, SVC, 0.5098039215686274, 0.42812205095942124
# 2884, fewest_selected_in, SVC, 0.6666666666666666, 0.6827012025901942
# 2884, representative_selected_on, GradientBoostingClassifier, 0.9411764705882353, 0.9401717208622579
# 2884, representative_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9228026875085698
# 2884, representative_selected_on, DecisionTreeClassifier, 0.803921568627451, 0.8120996650408415
# 2884, representative_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.8794881588999236
# 2884, representative_selected_on, SVC, 0.5098039215686274, 0.42812205095942124
# 2884, representative_selected_in, SVC, 0.7647058823529411, 0.7601904085953083
# 2884, balanced_on_on, GradientBoostingClassifier, 0.9215686274509803, 0.9205617911500263
# 2884, balanced_on_in, GradientBoostingClassifier, 0.9215686274509803, 0.9205617911500263
# 2884, balanced_on_on, DecisionTreeClassifier, 0.8235294117647058, 0.8302559445733696
# 2884, balanced_on_in, DecisionTreeClassifier, 0.7843137254901961, 0.7741102710676747
# 2884, balanced_on_on, SVC, 0.5098039215686274, 0.41848739495798315
# 2884, balanced_on_in, SVC, 0.6470588235294118, 0.6546787820819385
# 2884, balanced_in_on, GradientBoostingClassifier, 0.9215686274509803, 0.9205617911500263
# 2884, balanced_in_in, GradientBoostingClassifier, 0.9215686274509803, 0.9205617911500263
# 2884, balanced_in_on, DecisionTreeClassifier, 0.8235294117647058, 0.8302559445733696
# 2884, balanced_in_in, DecisionTreeClassifier, 0.7843137254901961, 0.7741102710676747
# 2884, balanced_in_on, SVC, 0.5098039215686274, 0.41848739495798315
# 2884, balanced_in_in, SVC, 0.6470588235294118, 0.6546787820819385
# 1971, base_on, GradientBoostingClassifier, 0.8823529411764706, 0.8806329549363606
# 1971, base_in, GradientBoostingClassifier, 0.8823529411764706, 0.8806329549363606
# 1971, base_on, DecisionTreeClassifier, 0.8431372549019608, 0.8440269029571901
# 1971, base_in, DecisionTreeClassifier, 0.8431372549019608, 0.8440269029571901
# 1971, base_on, SVC, 0.6274509803921569, 0.6219951257339095
# 1971, base_in, SVC, 0.6274509803921569, 0.6219951257339095
# 1971, random_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.8945233265720081
# 1971, random_selected_in, GradientBoostingClassifier, 0.9019607843137255, 0.899224705362021
# 1971, random_selected_on, DecisionTreeClassifier, 0.7450980392156863, 0.7689795918367347
# 1971, random_selected_in, DecisionTreeClassifier, 0.8627450980392157, 0.8640907080535564
# 1971, random_selected_on, SVC, 0.5098039215686274, 0.35752482811306335
# 1971, random_selected_in, SVC, 0.6274509803921569, 0.6272819472616634
# 1971, proportional_selected_on, GradientBoostingClassifier, 0.8823529411764706, 0.8763039698638075
# 1971, proportional_selected_in, GradientBoostingClassifier, 0.8823529411764706, 0.8790242887605971
# 1971, proportional_selected_on, DecisionTreeClassifier, 0.7647058823529411, 0.7831808278867102
# 1971, proportional_selected_in, DecisionTreeClassifier, 0.8431372549019608, 0.8437936343131288
# 1971, proportional_selected_on, SVC, 0.5294117647058824, 0.36651583710407243
# 1971, proportional_selected_in, SVC, 0.6666666666666666, 0.6695562435500516
# 1971, fewest_selected_on, GradientBoostingClassifier, 0.9215686274509803, 0.9178765880217787
# 1971, fewest_selected_in, GradientBoostingClassifier, 0.9019607843137255, 0.9036749628080898
# 1971, fewest_selected_on, DecisionTreeClassifier, 0.7450980392156863, 0.7462795221557886
# 1971, fewest_selected_in, DecisionTreeClassifier, 0.803921568627451, 0.8153940877726044
# 1971, fewest_selected_on, SVC, 0.5294117647058824, 0.46761734997029114
# 1971, fewest_selected_in, SVC, 0.6666666666666666, 0.6689063308607901
# 1971, representative_selected_on, GradientBoostingClassifier, 0.8627450980392157, 0.857455056325936
# 1971, representative_selected_in, GradientBoostingClassifier, 0.8627450980392157, 0.8670505964623612
# 1971, representative_selected_on, DecisionTreeClassifier, 0.8235294117647058, 0.832408435072142
# 1971, representative_selected_in, DecisionTreeClassifier, 0.8235294117647058, 0.8255880342567647
# 1971, representative_selected_on, SVC, 0.5490196078431373, 0.4065699006875478
# 1971, representative_selected_in, SVC, 0.6470588235294118, 0.6386877828054299
# 1971, balanced_on_on, GradientBoostingClassifier, 0.8823529411764706, 0.8829061405126314
# 1971, balanced_on_in, GradientBoostingClassifier, 0.9019607843137255, 0.9036749628080898
# 1971, balanced_on_on, DecisionTreeClassifier, 0.7647058823529411, 0.7618035190615836
# 1971, balanced_on_in, DecisionTreeClassifier, 0.8431372549019608, 0.8458243277450007
# 1971, balanced_on_on, SVC, 0.5490196078431373, 0.5185520361990951
# 1971, balanced_on_in, SVC, 0.5882352941176471, 0.5964363348922996
# 1971, balanced_in_on, GradientBoostingClassifier, 0.8823529411764706, 0.8829061405126314
# 1971, balanced_in_in, GradientBoostingClassifier, 0.9019607843137255, 0.9036749628080898
# 1971, balanced_in_on, DecisionTreeClassifier, 0.7647058823529411, 0.7618035190615836
# 1971, balanced_in_in, DecisionTreeClassifier, 0.8431372549019608, 0.8458243277450007
# 1971, balanced_in_on, SVC, 0.5490196078431373, 0.5185520361990951
# 1971, balanced_in_in, SVC, 0.5882352941176471, 0.5964363348922996
# 6939, base_on, GradientBoostingClassifier, 0.9215686274509803, 0.9220272904483431
# 6939, base_in, GradientBoostingClassifier, 0.9215686274509803, 0.9220272904483431
# 6939, base_on, DecisionTreeClassifier, 0.8823529411764706, 0.8852187028657617
# 6939, base_in, DecisionTreeClassifier, 0.8823529411764706, 0.8852187028657617
# 6939, base_on, SVC, 0.7450980392156863, 0.7307911875385923
# 6939, base_in, SVC, 0.7450980392156863, 0.7307911875385923
# 6939, random_selected_on, GradientBoostingClassifier, 0.9411764705882353, 0.939618365406018
# 6939, random_selected_in, GradientBoostingClassifier, 0.9607843137254902, 0.9607843137254902
# 6939, random_selected_on, DecisionTreeClassifier, 0.9215686274509803, 0.920651301456255
# 6939, random_selected_in, DecisionTreeClassifier, 0.9019607843137255, 0.9040060043156019
# 6939, random_selected_on, SVC, 0.5490196078431373, 0.3891784561926036
# 6939, random_selected_in, SVC, 0.803921568627451, 0.803921568627451
# 6939, proportional_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.9034514390551541
# 6939, proportional_selected_in, GradientBoostingClassifier, 0.9019607843137255, 0.9027252226426632
# 6939, proportional_selected_on, DecisionTreeClassifier, 0.9019607843137255, 0.9072987685640295
# 6939, proportional_selected_in, DecisionTreeClassifier, 0.9019607843137255, 0.9057687410628587
# 6939, proportional_selected_on, SVC, 0.6078431372549019, 0.5274333156686097
# 6939, proportional_selected_in, SVC, 0.803921568627451, 0.8004921184159939
# 6939, fewest_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.9034514390551541
# 6939, fewest_selected_in, GradientBoostingClassifier, 0.9607843137254902, 0.9607843137254902
# 6939, fewest_selected_on, DecisionTreeClassifier, 0.8627450980392157, 0.8595681822780713
# 6939, fewest_selected_in, DecisionTreeClassifier, 0.9411764705882353, 0.9425462050849048
# 6939, fewest_selected_on, SVC, 0.6078431372549019, 0.5272331154684097
# 6939, fewest_selected_in, SVC, 0.7254901960784313, 0.7237319879218743
# 6939, representative_selected_on, GradientBoostingClassifier, 0.9215686274509803, 0.91942533154799
# 6939, representative_selected_in, GradientBoostingClassifier, 0.9411764705882353, 0.9425462050849048
# 6939, representative_selected_on, DecisionTreeClassifier, 0.8627450980392157, 0.8704236939531056
# 6939, representative_selected_in, DecisionTreeClassifier, 0.9411764705882353, 0.943691602515132
# 6939, representative_selected_on, SVC, 0.5490196078431373, 0.3891784561926036
# 6939, representative_selected_in, SVC, 0.7254901960784313, 0.7120349606118107
# 6939, balanced_on_on, GradientBoostingClassifier, 0.9215686274509803, 0.9215686274509803
# 6939, balanced_on_in, GradientBoostingClassifier, 0.9215686274509803, 0.9242226183402653
# 6939, balanced_on_on, DecisionTreeClassifier, 0.9215686274509803, 0.9215686274509803
# 6939, balanced_on_in, DecisionTreeClassifier, 0.8823529411764706, 0.8902939868533654
# 6939, balanced_on_on, SVC, 0.6078431372549019, 0.5272331154684097
# 6939, balanced_on_in, SVC, 0.7058823529411765, 0.7089007724301842
# 6939, balanced_in_on, GradientBoostingClassifier, 0.9215686274509803, 0.9215686274509803
# 6939, balanced_in_in, GradientBoostingClassifier, 0.9215686274509803, 0.9242226183402653
# 6939, balanced_in_on, DecisionTreeClassifier, 0.9215686274509803, 0.9215686274509803
# 6939, balanced_in_in, DecisionTreeClassifier, 0.8823529411764706, 0.8902939868533654
# 6939, balanced_in_on, SVC, 0.6078431372549019, 0.5272331154684097
# 6939, balanced_in_in, SVC, 0.7058823529411765, 0.7089007724301842
# 9375, base_on, GradientBoostingClassifier, 0.8823529411764706, 0.8804091333503098
# 9375, base_in, GradientBoostingClassifier, 0.8823529411764706, 0.8804091333503098
# 9375, base_on, DecisionTreeClassifier, 0.8431372549019608, 0.8412659945179043
# 9375, base_in, DecisionTreeClassifier, 0.8431372549019608, 0.8412659945179043
# 9375, base_on, SVC, 0.6666666666666666, 0.6465821759939406
# 9375, base_in, SVC, 0.6666666666666666, 0.6465821759939406
# 9375, random_selected_on, GradientBoostingClassifier, 0.8823529411764706, 0.8784335349800246
# 9375, random_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9191005073358013
# 9375, random_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.8435146311932954
# 9375, random_selected_in, DecisionTreeClassifier, 0.8627450980392157, 0.8563759865797652
# 9375, random_selected_on, SVC, 0.39215686274509803, 0.22093344380005525
# 9375, random_selected_in, SVC, 0.7058823529411765, 0.7071683374204384
# 9375, proportional_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.89760348583878
# 9375, proportional_selected_in, GradientBoostingClassifier, 0.8823529411764706, 0.8784335349800246
# 9375, proportional_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.8435146311932954
# 9375, proportional_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.8784335349800246
# 9375, proportional_selected_on, SVC, 0.39215686274509803, 0.22093344380005525
# 9375, proportional_selected_in, SVC, 0.7254901960784313, 0.7261002178649238
# 9375, fewest_selected_on, GradientBoostingClassifier, 0.8823529411764706, 0.8784335349800246
# 9375, fewest_selected_in, GradientBoostingClassifier, 0.9019607843137255, 0.8997629680741634
# 9375, fewest_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.8407639868740437
# 9375, fewest_selected_in, DecisionTreeClassifier, 0.8627450980392157, 0.8610043410802424
# 9375, fewest_selected_on, SVC, 0.45098039215686275, 0.34530175706646293
# 9375, fewest_selected_in, SVC, 0.6862745098039216, 0.688003050734083
# 9375, representative_selected_on, GradientBoostingClassifier, 0.8823529411764706, 0.8799053983444711
# 9375, representative_selected_in, GradientBoostingClassifier, 0.8627450980392157, 0.8563759865797652
# 9375, representative_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.8435146311932954
# 9375, representative_selected_in, DecisionTreeClassifier, 0.8431372549019608, 0.8401420204930216
# 9375, representative_selected_on, SVC, 0.39215686274509803, 0.22093344380005525
# 9375, representative_selected_in, SVC, 0.6470588235294118, 0.6445315904139434
# 9375, balanced_on_on, GradientBoostingClassifier, 0.9215686274509803, 0.9191005073358013
# 9375, balanced_on_in, GradientBoostingClassifier, 0.9019607843137255, 0.8997629680741634
# 9375, balanced_on_on, DecisionTreeClassifier, 0.8431372549019608, 0.8435182502119621
# 9375, balanced_on_in, DecisionTreeClassifier, 0.8235294117647058, 0.8219492925375277
# 9375, balanced_on_on, SVC, 0.45098039215686275, 0.3569906223358909
# 9375, balanced_on_in, SVC, 0.7254901960784313, 0.7264804911863736
# 9375, balanced_in_on, GradientBoostingClassifier, 0.9215686274509803, 0.9191005073358013
# 9375, balanced_in_in, GradientBoostingClassifier, 0.9019607843137255, 0.8997629680741634
# 9375, balanced_in_on, DecisionTreeClassifier, 0.8431372549019608, 0.8435182502119621
# 9375, balanced_in_in, DecisionTreeClassifier, 0.8235294117647058, 0.8219492925375277
# 9375, balanced_in_on, SVC, 0.45098039215686275, 0.3569906223358909
# 9375, balanced_in_in, SVC, 0.7254901960784313, 0.7264804911863736
# 1058, base_on, GradientBoostingClassifier, 0.9019607843137255, 0.9006125849032424
# 1058, base_in, GradientBoostingClassifier, 0.9019607843137255, 0.9006125849032424
# 1058, base_on, DecisionTreeClassifier, 0.8823529411764706, 0.8825421165846697
# 1058, base_in, DecisionTreeClassifier, 0.8823529411764706, 0.8825421165846697
# 1058, base_on, SVC, 0.7058823529411765, 0.6800280639562792
# 1058, base_in, SVC, 0.7058823529411765, 0.6800280639562792
# 1058, random_selected_on, GradientBoostingClassifier, 0.8823529411764706, 0.8815859677204215
# 1058, random_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.920667957585511
# 1058, random_selected_on, DecisionTreeClassifier, 0.7843137254901961, 0.7873270520329342
# 1058, random_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.8862066038536626
# 1058, random_selected_on, SVC, 0.45098039215686275, 0.28033916269210385
# 1058, random_selected_in, SVC, 0.6862745098039216, 0.6822694599584643
# 1058, proportional_selected_on, GradientBoostingClassifier, 0.8627450980392157, 0.8619870235484222
# 1058, proportional_selected_in, GradientBoostingClassifier, 0.9411764705882353, 0.9416322223507676
# 1058, proportional_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.843570803373498
# 1058, proportional_selected_in, DecisionTreeClassifier, 0.9215686274509803, 0.9233511586452762
# 1058, proportional_selected_on, SVC, 0.45098039215686275, 0.28033916269210385
# 1058, proportional_selected_in, SVC, 0.7647058823529411, 0.766406327236777
# 1058, fewest_selected_on, GradientBoostingClassifier, 0.9215686274509803, 0.9211123843476784
# 1058, fewest_selected_in, GradientBoostingClassifier, 0.9607843137254902, 0.959079229417152
# 1058, fewest_selected_on, DecisionTreeClassifier, 0.803921568627451, 0.7972076711191188
# 1058, fewest_selected_in, DecisionTreeClassifier, 0.8627450980392157, 0.8674390968508615
# 1058, fewest_selected_on, SVC, 0.5098039215686274, 0.4103438476840012
# 1058, fewest_selected_in, SVC, 0.7450980392156863, 0.7462617745866544
# 1058, representative_selected_on, GradientBoostingClassifier, 0.9215686274509803, 0.921374514718168
# 1058, representative_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9215160896894644
# 1058, representative_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.8404940407535564
# 1058, representative_selected_in, DecisionTreeClassifier, 0.8627450980392157, 0.8637233759272783
# 1058, representative_selected_on, SVC, 0.45098039215686275, 0.28033916269210385
# 1058, representative_selected_in, SVC, 0.6862745098039216, 0.6702540665388963
# 1058, balanced_on_on, GradientBoostingClassifier, 0.9019607843137255, 0.9024382480264833
# 1058, balanced_on_in, GradientBoostingClassifier, 0.9215686274509803, 0.9213738305779829
# 1058, balanced_on_on, DecisionTreeClassifier, 0.8627450980392157, 0.8636788048552755
# 1058, balanced_on_in, DecisionTreeClassifier, 0.9019607843137255, 0.9038225391166567
# 1058, balanced_on_on, SVC, 0.47058823529411764, 0.3707664884135472
# 1058, balanced_on_in, SVC, 0.6666666666666666, 0.66484268125855
# 1058, balanced_in_on, GradientBoostingClassifier, 0.9019607843137255, 0.9024382480264833
# 1058, balanced_in_in, GradientBoostingClassifier, 0.9215686274509803, 0.9213738305779829
# 1058, balanced_in_on, DecisionTreeClassifier, 0.8627450980392157, 0.8636788048552755
# 1058, balanced_in_in, DecisionTreeClassifier, 0.9019607843137255, 0.9038225391166567
# 1058, balanced_in_on, SVC, 0.47058823529411764, 0.3707664884135472
# 1058, balanced_in_in, SVC, 0.6666666666666666, 0.66484268125855
# 2097, base_on, GradientBoostingClassifier, 0.9411764705882353, 0.9447019651367762
# 2097, base_in, GradientBoostingClassifier, 0.9411764705882353, 0.9447019651367762
# 2097, base_on, DecisionTreeClassifier, 0.9215686274509803, 0.9240394361501627
# 2097, base_in, DecisionTreeClassifier, 0.9215686274509803, 0.9240394361501627
# 2097, base_on, SVC, 0.6862745098039216, 0.6781823840647371
# 2097, base_in, SVC, 0.6862745098039216, 0.6781823840647371
# 2097, random_selected_on, GradientBoostingClassifier, 0.9411764705882353, 0.9447019651367762
# 2097, random_selected_in, GradientBoostingClassifier, 0.9607843137254902, 0.9625090777051563
# 2097, random_selected_on, DecisionTreeClassifier, 0.9607843137254902, 0.9625090777051563
# 2097, random_selected_in, DecisionTreeClassifier, 0.9411764705882353, 0.9447019651367762
# 2097, random_selected_on, SVC, 0.6078431372549019, 0.5178472590237296
# 2097, random_selected_in, SVC, 0.6862745098039216, 0.6732718479924462
# 2097, proportional_selected_on, GradientBoostingClassifier, 0.9411764705882353, 0.9447019651367762
# 2097, proportional_selected_in, GradientBoostingClassifier, 0.9803921568627451, 0.9808674985145573
# 2097, proportional_selected_on, DecisionTreeClassifier, 0.9411764705882353, 0.9447019651367762
# 2097, proportional_selected_in, DecisionTreeClassifier, 0.9607843137254902, 0.9625090777051563
# 2097, proportional_selected_on, SVC, 0.5686274509803921, 0.42848164906988434
# 2097, proportional_selected_in, SVC, 0.7450980392156863, 0.7423675565663397
# 2097, fewest_selected_on, GradientBoostingClassifier, 0.9607843137254902, 0.9625090777051563
# 2097, fewest_selected_in, GradientBoostingClassifier, 0.9607843137254902, 0.9625090777051563
# 2097, fewest_selected_on, DecisionTreeClassifier, 0.8823529411764706, 0.895676219205631
# 2097, fewest_selected_in, DecisionTreeClassifier, 0.9411764705882353, 0.9447019651367762
# 2097, fewest_selected_on, SVC, 0.6078431372549019, 0.5427450980392157
# 2097, fewest_selected_in, SVC, 0.7647058823529411, 0.7625272331154683
# 2097, representative_selected_on, GradientBoostingClassifier, 0.9803921568627451, 0.9808674985145573
# 2097, representative_selected_in, GradientBoostingClassifier, 0.9607843137254902, 0.9625090777051563
# 2097, representative_selected_on, DecisionTreeClassifier, 0.9019607843137255, 0.9088426149854137
# 2097, representative_selected_in, DecisionTreeClassifier, 0.9411764705882353, 0.9422597226426307
# 2097, representative_selected_on, SVC, 0.6078431372549019, 0.4868937048503612
# 2097, representative_selected_in, SVC, 0.6862745098039216, 0.6781823840647371
# 2097, balanced_on_on, GradientBoostingClassifier, 0.9803921568627451, 0.9807294960995151
# ...
# 5923, fewest_selected_on, GradientBoostingClassifier, 0.9411764705882353, 0.9383833305401933
# 5923, fewest_selected_in, GradientBoostingClassifier, 0.9411764705882353, 0.9383833305401933
# 5923, fewest_selected_on, DecisionTreeClassifier, 0.803921568627451, 0.8313330631669732
# 5923, fewest_selected_in, DecisionTreeClassifier, 0.8431372549019608, 0.8590102707749767
# 5923, fewest_selected_on, SVC, 0.6078431372549019, 0.5315904139433552
# 5923, fewest_selected_in, SVC, 0.7843137254901961, 0.7826066161524184
# 5923, representative_selected_on, GradientBoostingClassifier, 0.9215686274509803, 0.9212628521194053
# 5923, representative_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9212628521194053
# 5923, representative_selected_on, DecisionTreeClassifier, 0.8823529411764706, 0.8965590446704998
# 5923, representative_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.8858769643083368
# 5923, representative_selected_on, SVC, 0.5294117647058824, 0.3814929480564156
# 5923, representative_selected_in, SVC, 0.6274509803921569, 0.6103755406230494
# 5923, balanced_on_on, GradientBoostingClassifier, 0.9411764705882353, 0.9383833305401933
# 5923, balanced_on_in, GradientBoostingClassifier, 0.9215686274509803, 0.9218721838033713
# 5923, balanced_on_on, DecisionTreeClassifier, 0.803921568627451, 0.8144950611823677
# 5923, balanced_on_in, DecisionTreeClassifier, 0.9215686274509803, 0.9270725834193326
# 5923, balanced_on_on, SVC, 0.5098039215686274, 0.34428316781257956
# 5923, balanced_on_in, SVC, 0.7058823529411765, 0.7128587283970191
# 5923, balanced_in_on, GradientBoostingClassifier, 0.9411764705882353, 0.9383833305401933
# 5923, balanced_in_in, GradientBoostingClassifier, 0.9215686274509803, 0.9218721838033713
# 5923, balanced_in_on, DecisionTreeClassifier, 0.803921568627451, 0.8144950611823677
# 5923, balanced_in_in, DecisionTreeClassifier, 0.9215686274509803, 0.9270725834193326
# 5923, balanced_in_on, SVC, 0.5098039215686274, 0.34428316781257956
# 5923, balanced_in_in, SVC, 0.7058823529411765, 0.7128587283970191
# 781, base_on, GradientBoostingClassifier, 0.9215686274509803, 0.9182024161015757
# 781, base_in, GradientBoostingClassifier, 0.9215686274509803, 0.9182024161015757
# 781, base_on, DecisionTreeClassifier, 0.8823529411764706, 0.8751355861493534
# 781, base_in, DecisionTreeClassifier, 0.8823529411764706, 0.8751355861493534
# 781, base_on, SVC, 0.6078431372549019, 0.6025723052817131
# 781, base_in, SVC, 0.6078431372549019, 0.6025723052817131
# 781, random_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.8997886736393903
# 781, random_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9124162485507022
# 781, random_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.8217040662418814
# 781, random_selected_in, DecisionTreeClassifier, 0.9019607843137255, 0.8940422322775262
# 781, random_selected_on, SVC, 0.45098039215686275, 0.28033916269210385
# 781, random_selected_in, SVC, 0.5686274509803921, 0.5576266870384518
# 781, proportional_selected_on, GradientBoostingClassifier, 0.9411764705882353, 0.937094837935174
# 781, proportional_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9124162485507022
# 781, proportional_selected_on, DecisionTreeClassifier, 0.9411764705882353, 0.939998389392853
# 781, proportional_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.8672607504540277
# 781, proportional_selected_on, SVC, 0.45098039215686275, 0.28033916269210385
# 781, proportional_selected_in, SVC, 0.6274509803921569, 0.6205585264408795
# 781, fewest_selected_on, GradientBoostingClassifier, 0.9215686274509803, 0.9124162485507022
# 781, fewest_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9124162485507022
# 781, fewest_selected_on, DecisionTreeClassifier, 0.803921568627451, 0.7917541070482247
# 781, fewest_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.8766339869281045
# 781, fewest_selected_on, SVC, 0.5294117647058824, 0.46721311475409827
# 781, fewest_selected_in, SVC, 0.6078431372549019, 0.6048780487804879
# 781, representative_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.8997886736393903
# 781, representative_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9182024161015757
# 781, representative_selected_on, DecisionTreeClassifier, 0.8823529411764706, 0.877736229626986
# 781, representative_selected_in, DecisionTreeClassifier, 0.8431372549019608, 0.8318523153942428
# 781, representative_selected_on, SVC, 0.47058823529411764, 0.31947354284179424
# 781, representative_selected_in, SVC, 0.6078431372549019, 0.6025723052817131
# 781, balanced_on_on, GradientBoostingClassifier, 0.9215686274509803, 0.9182024161015757
# 781, balanced_on_in, GradientBoostingClassifier, 0.9411764705882353, 0.937094837935174
# 781, balanced_on_on, DecisionTreeClassifier, 0.7647058823529411, 0.7522065465752698
# 781, balanced_on_in, DecisionTreeClassifier, 0.8235294117647058, 0.8191616515887401
# 781, balanced_on_on, SVC, 0.49019607843137253, 0.4352041913475261
# 781, balanced_on_in, SVC, 0.6078431372549019, 0.6030897207367796
# 781, balanced_in_on, GradientBoostingClassifier, 0.9215686274509803, 0.9182024161015757
# 781, balanced_in_in, GradientBoostingClassifier, 0.9411764705882353, 0.937094837935174
# 781, balanced_in_on, DecisionTreeClassifier, 0.7647058823529411, 0.7522065465752698
# 781, balanced_in_in, DecisionTreeClassifier, 0.8235294117647058, 0.8191616515887401
# 781, balanced_in_on, SVC, 0.49019607843137253, 0.4352041913475261
# 781, balanced_in_in, SVC, 0.6078431372549019, 0.6030897207367796
# 6406, base_on, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, base_in, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, base_on, DecisionTreeClassifier, 0.8235294117647058, 0.8236128493950773
# 6406, base_in, DecisionTreeClassifier, 0.8235294117647058, 0.8236128493950773
# 6406, base_on, SVC, 0.7058823529411765, 0.7042081936643536
# 6406, base_in, SVC, 0.7058823529411765, 0.7042081936643536
# 6406, random_selected_on, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, random_selected_in, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, random_selected_on, DecisionTreeClassifier, 0.803921568627451, 0.8019559730050378
# 6406, random_selected_in, DecisionTreeClassifier, 0.9411764705882353, 0.940497938305757
# 6406, random_selected_on, SVC, 0.47058823529411764, 0.30117647058823527
# 6406, random_selected_in, SVC, 0.7058823529411765, 0.7025503011662181
# 6406, proportional_selected_on, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, proportional_selected_in, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, proportional_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.8431372549019608
# 6406, proportional_selected_in, DecisionTreeClassifier, 0.8235294117647058, 0.8237998647734956
# 6406, proportional_selected_on, SVC, 0.47058823529411764, 0.30117647058823527
# 6406, proportional_selected_in, SVC, 0.7254901960784313, 0.7227869222754132
# 6406, fewest_selected_on, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, fewest_selected_in, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, fewest_selected_on, DecisionTreeClassifier, 0.8823529411764706, 0.8834056595990428
# 6406, fewest_selected_in, DecisionTreeClassifier, 0.8627450980392157, 0.8615293624781291
# 6406, fewest_selected_on, SVC, 0.5294117647058824, 0.4524886877828055
# 6406, fewest_selected_in, SVC, 0.7647058823529411, 0.7665563194974959
# 6406, representative_selected_on, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, representative_selected_in, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, representative_selected_on, DecisionTreeClassifier, 0.803921568627451, 0.8023959583833534
# 6406, representative_selected_in, DecisionTreeClassifier, 0.8235294117647058, 0.8242830419745113
# 6406, representative_selected_on, SVC, 0.49019607843137253, 0.34201112877583467
# 6406, representative_selected_in, SVC, 0.7058823529411765, 0.7072454650309322
# 6406, balanced_on_on, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, balanced_on_in, GradientBoostingClassifier, 0.9411764705882353, 0.9402139537441906
# 6406, balanced_on_on, DecisionTreeClassifier, 0.9607843137254902, 0.9606743118004565
# 6406, balanced_on_in, DecisionTreeClassifier, 0.8431372549019608, 0.8436378806841887
# 6406, balanced_on_on, SVC, 0.5294117647058824, 0.43818810946838627
# 6406, balanced_on_in, SVC, 0.6470588235294118, 0.6413357087675595
# 6406, balanced_in_on, GradientBoostingClassifier, 0.9607843137254902, 0.9597860962566845
# 6406, balanced_in_in, GradientBoostingClassifier, 0.9411764705882353, 0.9402139537441906
# 6406, balanced_in_on, DecisionTreeClassifier, 0.9607843137254902, 0.9606743118004565
# 6406, balanced_in_in, DecisionTreeClassifier, 0.8431372549019608, 0.8436378806841887
# 6406, balanced_in_on, SVC, 0.5294117647058824, 0.43818810946838627
# 6406, balanced_in_in, SVC, 0.6470588235294118, 0.6413357087675595
# 2862, base_on, GradientBoostingClassifier, 0.8823529411764706, 0.8805882352941177
# 2862, base_in, GradientBoostingClassifier, 0.8823529411764706, 0.8805882352941177
# 2862, base_on, DecisionTreeClassifier, 0.8431372549019608, 0.8482296711469047
# 2862, base_in, DecisionTreeClassifier, 0.8431372549019608, 0.8482296711469047
# 2862, base_on, SVC, 0.7450980392156863, 0.7304384641845942
# 2862, base_in, SVC, 0.7450980392156863, 0.7304384641845942
# 2862, random_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.9024382480264833
# 2862, random_selected_in, GradientBoostingClassifier, 0.8823529411764706, 0.8815859677204215
# 2862, random_selected_on, DecisionTreeClassifier, 0.8823529411764706, 0.8856525201956991
# 2862, random_selected_in, DecisionTreeClassifier, 0.9019607843137255, 0.9014408793820559
# 2862, random_selected_on, SVC, 0.45098039215686275, 0.28033916269210385
# 2862, random_selected_in, SVC, 0.8235294117647058, 0.8218704363572639
# 2862, proportional_selected_on, GradientBoostingClassifier, 0.8823529411764706, 0.8836473983532807
# 2862, proportional_selected_in, GradientBoostingClassifier, 0.8823529411764706, 0.8836473983532807
# 2862, proportional_selected_on, DecisionTreeClassifier, 0.8235294117647058, 0.8316993464052287
# 2862, proportional_selected_in, DecisionTreeClassifier, 0.8235294117647058, 0.8301247771836007
# 2862, proportional_selected_on, SVC, 0.45098039215686275, 0.28033916269210385
# 2862, proportional_selected_in, SVC, 0.7647058823529411, 0.7527937490785789
# 2862, fewest_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.9010877078103969
# 2862, fewest_selected_in, GradientBoostingClassifier, 0.8823529411764706, 0.8805882352941177
# 2862, fewest_selected_on, DecisionTreeClassifier, 0.8627450980392157, 0.865172735760971
# 2862, fewest_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.8844706245125248
# 2862, fewest_selected_on, SVC, 0.45098039215686275, 0.28033916269210385
# 2862, fewest_selected_in, SVC, 0.7647058823529411, 0.7614758493696757
# 2862, representative_selected_on, GradientBoostingClassifier, 0.8627450980392157, 0.8631786047752434
# 2862, representative_selected_in, GradientBoostingClassifier, 0.8823529411764706, 0.8815859677204215
# 2862, representative_selected_on, DecisionTreeClassifier, 0.8627450980392157, 0.8690227078973882
# 2862, representative_selected_in, DecisionTreeClassifier, 0.8431372549019608, 0.8508714596949891
# 2862, representative_selected_on, SVC, 0.45098039215686275, 0.28033916269210385
# 2862, representative_selected_in, SVC, 0.7450980392156863, 0.7304384641845942
# 2862, balanced_on_on, GradientBoostingClassifier, 0.9019607843137255, 0.9010877078103969
# 2862, balanced_on_in, GradientBoostingClassifier, 0.8823529411764706, 0.8815859677204215
# 2862, balanced_on_on, DecisionTreeClassifier, 0.7843137254901961, 0.7849260500356628
# 2862, balanced_on_in, DecisionTreeClassifier, 0.8235294117647058, 0.8249019607843138
# 2862, balanced_on_on, SVC, 0.45098039215686275, 0.28033916269210385
# 2862, balanced_on_in, SVC, 0.8627450980392157, 0.8629806276865102
# 2862, balanced_in_on, GradientBoostingClassifier, 0.9019607843137255, 0.9010877078103969
# 2862, balanced_in_in, GradientBoostingClassifier, 0.8823529411764706, 0.8815859677204215
# 2862, balanced_in_on, DecisionTreeClassifier, 0.7843137254901961, 0.7849260500356628
# 2862, balanced_in_in, DecisionTreeClassifier, 0.8235294117647058, 0.8249019607843138
# 2862, balanced_in_on, SVC, 0.45098039215686275, 0.28033916269210385
# 2862, balanced_in_in, SVC, 0.8627450980392157, 0.8629806276865102
# 899, base_on, GradientBoostingClassifier, 0.9019607843137255, 0.9083488599059533
# 899, base_in, GradientBoostingClassifier, 0.9019607843137255, 0.9083488599059533
# 899, base_on, DecisionTreeClassifier, 0.8823529411764706, 0.8869395711500975
# 899, base_in, DecisionTreeClassifier, 0.8823529411764706, 0.8869395711500975
# 899, base_on, SVC, 0.6274509803921569, 0.5920239282153539
# 899, base_in, SVC, 0.6274509803921569, 0.5920239282153539
# 899, random_selected_on, GradientBoostingClassifier, 0.9411764705882353, 0.9423654568210263
# 899, random_selected_in, GradientBoostingClassifier, 0.9411764705882353, 0.9423654568210263
# 899, random_selected_on, DecisionTreeClassifier, 0.8235294117647058, 0.8450764921353155
# 899, random_selected_in, DecisionTreeClassifier, 0.8823529411764706, 0.8877157700687113
# 899, random_selected_on, SVC, 0.49019607843137253, 0.34912854030501084
# 899, random_selected_in, SVC, 0.7058823529411765, 0.6891640866873066
# 899, proportional_selected_on, GradientBoostingClassifier, 0.9215686274509803, 0.9244167388723082
# 899, proportional_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9254901960784314
# 899, proportional_selected_on, DecisionTreeClassifier, 0.8823529411764706, 0.8877157700687113
# 899, proportional_selected_in, DecisionTreeClassifier, 0.9019607843137255, 0.9032931121166413
# 899, proportional_selected_on, SVC, 0.47058823529411764, 0.3184931506849315
# 899, proportional_selected_in, SVC, 0.6862745098039216, 0.6767148610285865
# 899, fewest_selected_on, GradientBoostingClassifier, 0.9411764705882353, 0.9423654568210263
# 899, fewest_selected_in, GradientBoostingClassifier, 0.9411764705882353, 0.9423654568210263
# 899, fewest_selected_on, DecisionTreeClassifier, 0.8627450980392157, 0.8682913544821723
# 899, fewest_selected_in, DecisionTreeClassifier, 0.8431372549019608, 0.8558163534691723
# 899, fewest_selected_on, SVC, 0.5098039215686274, 0.3906198131550245
# 899, fewest_selected_in, SVC, 0.7450980392156863, 0.7448685857321652
# 899, representative_selected_on, GradientBoostingClassifier, 0.9019607843137255, 0.9083488599059533
# 899, representative_selected_in, GradientBoostingClassifier, 0.9215686274509803, 0.9244167388723082
# 899, representative_selected_on, DecisionTreeClassifier, 0.8431372549019608, 0.8572146807440925
# 899, representative_selected_in, DecisionTreeClassifier, 0.8235294117647058, 0.8374893000855994
# 899, representative_selected_on, SVC, 0.49019607843137253, 0.34912854030501084
# 899, representative_selected_in, SVC, 0.6470588235294118, 0.6366285919807518
# 899, balanced_on_on, GradientBoostingClassifier, 0.9411764705882353, 0.9423654568210263
# 899, balanced_on_in, GradientBoostingClassifier, 0.9411764705882353, 0.9428981348637017
# 899, balanced_on_on, DecisionTreeClassifier, 0.8431372549019608, 0.8495926158464858
# 899, balanced_on_in, DecisionTreeClassifier, 0.9411764705882353, 0.9452363963715132
# 899, balanced_on_on, SVC, 0.45098039215686275, 0.2841794251947355
# 899, balanced_on_in, SVC, 0.7647058823529411, 0.7663349675333809
# 899, balanced_in_on, GradientBoostingClassifier, 0.9411764705882353, 0.9423654568210263
# 899, balanced_in_in, GradientBoostingClassifier, 0.9411764705882353, 0.9428981348637017
# 899, balanced_in_on, DecisionTreeClassifier, 0.8431372549019608, 0.8495926158464858
# 899, balanced_in_in, DecisionTreeClassifier, 0.9411764705882353, 0.9452363963715132
# 899, balanced_in_on, SVC, 0.45098039215686275, 0.2841794251947355
# 899, balanced_in_in, SVC, 0.7647058823529411, 0.7663349675333809

# %%
import csv

# Specify the file path to save the CSV file
file_path = "starkey_results.csv"

# Write the list to a CSV file
with open(file_path, mode="w", newline="") as file:
    writer = csv.writer(file)
    for item in final_results:
        writer.writerow(item.split(", "))
