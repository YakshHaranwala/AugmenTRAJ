# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from TestUtils.test_utils import TestUtils

# %%
TestUtils.summarize_results(pd.read_csv('results/geolife_results.csv'), 'Geolife Result Summary')
# Out:
# Geolife Result Summary
#     seed                       model  base_accuracy  max_accuracy  \
# 0    781      DecisionTreeClassifier          0.500         0.625
# 1    781  GradientBoostingClassifier          0.500         0.750
# 2    781      RandomForestClassifier          0.500         0.750
# 3    899      DecisionTreeClassifier          0.500         0.875
# 4    899  GradientBoostingClassifier          0.500         0.750
# 5    899      RandomForestClassifier          0.750         0.875
# 6   1058      DecisionTreeClassifier          0.875         1.000
# 7   1058  GradientBoostingClassifier          0.625         1.000
# 8   1058      RandomForestClassifier          0.875         0.875
# 9   1415      DecisionTreeClassifier          0.750         1.000
# 10  1415  GradientBoostingClassifier          0.875         0.875
# 11  1415      RandomForestClassifier          0.750         0.875
# 12  1971      DecisionTreeClassifier          0.750         0.750
# ...

# %%
TestUtils.summarize_results(pd.read_csv('results/starkey_results.csv'), 'Starkey Result Summary')
# Out:
# Starkey Result Summary
#     seed                       model  base_accuracy  max_accuracy  \
# 0    781      DecisionTreeClassifier         0.9020        0.9216
# 1    781  GradientBoostingClassifier         0.9216        0.9412
# 2    781                         SVC         0.5882        0.6471
# 3    899      DecisionTreeClassifier         0.8627        0.9216
# 4    899  GradientBoostingClassifier         0.9020        0.9608
# 5    899                         SVC         0.6667        0.7255
# 6   1058      DecisionTreeClassifier         0.8235        0.9216
# 7   1058  GradientBoostingClassifier         0.9020        0.9412
# 8   1058                         SVC         0.6667        0.7451
# 9   1415      DecisionTreeClassifier         0.9216        0.9804
# 10  1415  GradientBoostingClassifier         0.9412        0.9608
# 11  1415                         SVC         0.7451        0.8235
# 12  1971      DecisionTreeClassifier         0.8627        0.8824
# ...

# %%
TestUtils.summarize_results(pd.read_csv('results/traffic_results.csv'), 'Traffic Result Summary')
# Out:
# Traffic Result Summary
#     seed                       model  base_accuracy  max_accuracy  \
# 0    781      DecisionTreeClassifier         0.7500        0.9167
# 1    781  GradientBoostingClassifier         0.8750        0.8750
# 2    781                         SVC         0.8750        0.8750
# 3    899      DecisionTreeClassifier         0.8800        0.9200
# 4    899  GradientBoostingClassifier         0.8800        0.9200
# 5    899                         SVC         0.8800        0.8800
# 6   1058      DecisionTreeClassifier         0.8800        0.9200
# 7   1058  GradientBoostingClassifier         0.8800        0.9600
# 8   1058                         SVC         0.9600        0.9600
# 9   1415      DecisionTreeClassifier         0.8750        0.9583
# 10  1415  GradientBoostingClassifier         0.8750        0.9583
# 11  1415                         SVC         0.9583        0.9583
# 12  1971      DecisionTreeClassifier         0.7600        0.9200
# ...
