# %%
import pandas as pd

from TestUtils.test_utils import TestUtils

# %%
geolife = TestUtils.summarize_results(pd.read_csv('results/geolife_results.csv'), 'Geolife Result Summary')
TestUtils.plot_comparison_results(geolife, 'Geolife')
# Out:
# Geolife Result Summary

# %%
starkey = TestUtils.summarize_results(pd.read_csv('results/starkey_results.csv'), 'Starkey Result Summary')
TestUtils.plot_comparison_results(starkey, 'Starkey')
# Out:
# Starkey Result Summary

# %%
traffic = TestUtils.summarize_results(pd.read_csv('results/traffic_results.csv'), 'Traffic Result Summary')
TestUtils.plot_comparison_results(traffic, 'Traffic')
# Out:
# Traffic Result Summary
