# %%
import pandas as pd
from ptrail.features.kinematic_features import KinematicFeatures
from ptrail.core.TrajectoryDF import PTRAILDataFrame

from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.metrics import f1_score, accuracy_score
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

from src.utils.general_utils import Utilities
from TestUtils.test_utils import TestUtils
from TestUtils.Keys import *

# %%
gl_dataset = PTRAILDataFrame(data_set=pd.read_csv('./TestUtils/geolife.csv'),
                             traj_id='traj_id',
                             datetime='DateTime',
                             latitude='lat',
                             longitude='lon')
ready_dataset = KinematicFeatures.create_distance_column(gl_dataset)
ready_dataset
# Out:
#                                    lat         lon  mode_of_transport  \
# traj_id DateTime
# 10      2008-03-31 16:00:08  41.741415   86.186028                  1
#         2008-03-31 16:01:07  41.737063   86.179470                  1
#         2008-03-31 16:02:07  41.734105   86.172823                  1
#         2008-03-31 16:03:06  41.739110   86.166563                  1
#         2008-03-31 16:04:05  41.744368   86.159987                  1
# ...                                ...         ...                ...
# 98      2007-06-02 12:07:19  39.935300  116.468267                  1
#         2007-06-02 12:07:58  39.935450  116.468333                  1
#         2007-06-02 12:08:20  39.935400  116.468517                  1
#         2007-06-02 12:09:40  39.934633  116.468983                  1
#         2007-06-02 12:09:50  39.934717  116.468900                  1
#
#                                Distance
# traj_id DateTime
# 10      2008-03-31 16:00:08         NaN
#         2008-03-31 16:01:07  728.185829
#         2008-03-31 16:02:07  642.172796
#         2008-03-31 16:03:06  761.267192
#         2008-03-31 16:04:05  799.694199
# ...                                 ...
# 98      2007-06-02 12:07:19   14.666196
#         2007-06-02 12:07:58   17.621166
#         2007-06-02 12:08:20   16.590457
#         2007-06-02 12:09:40   94.077625
#         2007-06-02 12:09:50   11.676742
#
# [355181 rows x 4 columns]

# %%
# Get the 20 seed values that we are going to use.
seed_generator = Utilities.generate_pi_seed(20)
seed_vals = [next(seed_generator) for i in range(20)]
final_results = ["seed, strategy, model, accuracy, f1_score"]

# All our selection strategies.
select_strategies = [BASE, RANDOM_SELECTED, FEWEST_SELECTED, BALANCED_ON, BALANCED_IN]
augment_strategies = [ON, IN, DROP, STRETCH]
models = [GradientBoostingClassifier(), DecisionTreeClassifier(), RandomForestClassifier()]

for seed in seed_vals:
    iter_map = TestUtils.get_iterable_map(ready_dataset, seed, 'mode_of_transport')
    for select_strategy in select_strategies:
        for model in models:
            if select_strategy != BASE and 'balanced' not in select_strategy:
                for augment_strategy in augment_strategies:
                    train_x, train_y = TestUtils.select_correct_test_train_split(iter_map,
                                                                                 select_strategy,
                                                                                 augment_strategy,
                                                                                 'mode_of_transport', 3)
                    if (train_x is not None) and (train_y is not None):
                        # Fit the model and predict.
                        model.random_state = seed
                        model.fit(X=train_x, y=train_y)
                        pred_vals = model.predict(X=iter_map[TEST_X])

                        # Calculate the accuracy and f1 score.
                        acc = accuracy_score(y_true=iter_map[TEST_Y], y_pred=pred_vals)
                        score = f1_score(y_true=iter_map[TEST_Y], y_pred=pred_vals, average='weighted')
                        final_results.append(f"{seed}, {select_strategy}_{augment_strategy},
                                             {model.__class__.__name__}, {acc}, {score}")
            else:
                train_x, train_y = TestUtils.select_correct_test_train_split(iter_map, select_strategy,
                                                                             BASE, 'mode_of_transport', 3)
                if (train_x is not None) and (train_y is not None):
                    # Fit the model and predict.
                    model.random_state = seed
                    model.fit(X=train_x, y=train_y)
                    pred_vals = model.predict(X=iter_map[TEST_X])

                    # Calculate the accuracy and f1 score.
                    acc = accuracy_score(y_true=iter_map[TEST_Y], y_pred=pred_vals)
                    score = f1_score(y_true=iter_map[TEST_Y], y_pred=pred_vals, average='weighted')
                    if 'balanced' not in select_strategy:
                        final_results.append(f"{seed}, base,"f" {model.__class__.__name__}, {acc}, {score}")
                    else:
                        final_results.append(f"{seed}, {select_strategy},"f" {model.__class__.__name__},
                                             {acc}, {score}")
# Out:
# 1415, base, GradientBoostingClassifier, 0.875, 0.8818181818181818
# 1415, base, DecisionTreeClassifier, 0.75, 0.7666666666666667
# 1415, base, RandomForestClassifier, 0.75, 0.7666666666666667
# 1415, random_selected_on, GradientBoostingClassifier, 0.875, 0.8818181818181818
# 1415, random_selected_in, GradientBoostingClassifier, 0.875, 0.8818181818181818
# 1415, random_selected_drop, GradientBoostingClassifier, 0.875, 0.8818181818181818
# 1415, random_selected_stretch, GradientBoostingClassifier, 0.875, 0.8818181818181818
# 1415, random_selected_on, DecisionTreeClassifier, 1.0, 1.0
# 1415, random_selected_in, DecisionTreeClassifier, 0.75, 0.7666666666666667
# 1415, random_selected_drop, DecisionTreeClassifier, 0.75, 0.7666666666666667
# 1415, random_selected_stretch, DecisionTreeClassifier, 0.875, 0.8589743589743589
# 1415, random_selected_on, RandomForestClassifier, 0.875, 0.8818181818181818
# 1415, random_selected_in, RandomForestClassifier, 0.875, 0.8818181818181818
# 1415, random_selected_drop, RandomForestClassifier, 0.875, 0.8818181818181818
# 1415, random_selected_stretch, RandomForestClassifier, 0.875, 0.8818181818181818
# 1415, fewest_selected_on, GradientBoostingClassifier, 0.75, 0.7666666666666667
# 1415, fewest_selected_in, GradientBoostingClassifier, 0.875, 0.8818181818181818
# 1415, fewest_selected_drop, GradientBoostingClassifier, 0.875, 0.8818181818181818
# 1415, fewest_selected_stretch, GradientBoostingClassifier, 0.5, 0.5
# 1415, fewest_selected_on, DecisionTreeClassifier, 0.625, 0.6428571428571429
# 1415, fewest_selected_in, DecisionTreeClassifier, 0.875, 0.8589743589743589
# 1415, fewest_selected_drop, DecisionTreeClassifier, 0.875, 0.8589743589743589
# 1415, fewest_selected_stretch, DecisionTreeClassifier, 0.75, 0.7666666666666667
# 1415, fewest_selected_on, RandomForestClassifier, 0.875, 0.8818181818181818
# 1415, fewest_selected_in, RandomForestClassifier, 0.875, 0.8818181818181818
# 1415, fewest_selected_drop, RandomForestClassifier, 0.875, 0.8818181818181818
# 1415, fewest_selected_stretch, RandomForestClassifier, 0.875, 0.8818181818181818
# 1415, balanced_on, GradientBoostingClassifier, 0.875, 0.8818181818181818
# 1415, balanced_on, DecisionTreeClassifier, 0.75, 0.7666666666666667
# 1415, balanced_on, RandomForestClassifier, 0.75, 0.7666666666666667
# 1415, balanced_in, GradientBoostingClassifier, 0.875, 0.8818181818181818
# 1415, balanced_in, DecisionTreeClassifier, 0.75, 0.7666666666666667
# 1415, balanced_in, RandomForestClassifier, 0.75, 0.7666666666666667
# 9265, base, GradientBoostingClassifier, 0.5, 0.5666666666666667
# 9265, base, DecisionTreeClassifier, 0.625, 0.6863636363636364
# 9265, base, RandomForestClassifier, 0.625, 0.6863636363636364
# 9265, random_selected_on, GradientBoostingClassifier, 0.5, 0.5666666666666667
# 9265, random_selected_in, GradientBoostingClassifier, 0.375, 0.4246031746031746
# 9265, random_selected_drop, GradientBoostingClassifier, 0.5, 0.5666666666666667
# 9265, random_selected_stretch, GradientBoostingClassifier, 0.5, 0.5666666666666667
# 9265, random_selected_on, DecisionTreeClassifier, 0.5, 0.5666666666666667
# 9265, random_selected_in, DecisionTreeClassifier, 0.625, 0.6863636363636364
# 9265, random_selected_drop, DecisionTreeClassifier, 0.625, 0.6863636363636364
# 9265, random_selected_stretch, DecisionTreeClassifier, 0.5, 0.5666666666666667
# 9265, random_selected_on, RandomForestClassifier, 0.625, 0.6863636363636364
# 9265, random_selected_in, RandomForestClassifier, 0.625, 0.6863636363636364
# 9265, random_selected_drop, RandomForestClassifier, 0.625, 0.6863636363636364
# 9265, random_selected_stretch, RandomForestClassifier, 0.625, 0.6863636363636364
# 9265, fewest_selected_on, GradientBoostingClassifier, 0.75, 0.7916666666666666
# 9265, fewest_selected_in, GradientBoostingClassifier, 0.375, 0.4246031746031746
# 9265, fewest_selected_drop, GradientBoostingClassifier, 0.375, 0.4246031746031746
# 9265, fewest_selected_stretch, GradientBoostingClassifier, 0.75, 0.7916666666666666
# 9265, fewest_selected_on, DecisionTreeClassifier, 0.625, 0.6863636363636364
# 9265, fewest_selected_in, DecisionTreeClassifier, 0.625, 0.6863636363636364
# 9265, fewest_selected_drop, DecisionTreeClassifier, 0.625, 0.6863636363636364
# 9265, fewest_selected_stretch, DecisionTreeClassifier, 0.5, 0.5666666666666667
# 9265, fewest_selected_on, RandomForestClassifier, 0.75, 0.7916666666666666
# 9265, fewest_selected_in, RandomForestClassifier, 0.625, 0.6863636363636364
# 9265, fewest_selected_drop, RandomForestClassifier, 0.625, 0.6863636363636364
# 9265, fewest_selected_stretch, RandomForestClassifier, 0.75, 0.7916666666666666
# 9265, balanced_on, GradientBoostingClassifier, 0.5, 0.5666666666666667
# 9265, balanced_on, DecisionTreeClassifier, 0.625, 0.6863636363636364
# 9265, balanced_on, RandomForestClassifier, 0.625, 0.6863636363636364
# 9265, balanced_in, GradientBoostingClassifier, 0.5, 0.5666666666666667
# 9265, balanced_in, DecisionTreeClassifier, 0.625, 0.6863636363636364
# 9265, balanced_in, RandomForestClassifier, 0.625, 0.6863636363636364
# 3589, base, GradientBoostingClassifier, 0.375, 0.38492063492063494
# 3589, base, DecisionTreeClassifier, 0.625, 0.6071428571428572
# 3589, base, RandomForestClassifier, 0.5, 0.5
# 3589, random_selected_on, GradientBoostingClassifier, 0.375, 0.3409090909090909
# 3589, random_selected_in, GradientBoostingClassifier, 0.375, 0.38492063492063494
# 3589, random_selected_drop, GradientBoostingClassifier, 0.375, 0.38492063492063494
# 3589, random_selected_stretch, GradientBoostingClassifier, 0.375, 0.38492063492063494
# 3589, random_selected_on, DecisionTreeClassifier, 0.5, 0.5
# 3589, random_selected_in, DecisionTreeClassifier, 0.75, 0.7499999999999999
# 3589, random_selected_drop, DecisionTreeClassifier, 0.625, 0.6071428571428572
# 3589, random_selected_stretch, DecisionTreeClassifier, 0.625, 0.6309523809523809
# 3589, random_selected_on, RandomForestClassifier, 0.625, 0.6309523809523809
# 3589, random_selected_in, RandomForestClassifier, 0.625, 0.6309523809523809
# 3589, random_selected_drop, RandomForestClassifier, 0.75, 0.7499999999999999
# 3589, random_selected_stretch, RandomForestClassifier, 0.625, 0.6309523809523809
# 3589, fewest_selected_on, GradientBoostingClassifier, 0.375, 0.38492063492063494
# 3589, fewest_selected_in, GradientBoostingClassifier, 0.375, 0.38492063492063494
# 3589, fewest_selected_drop, GradientBoostingClassifier, 0.375, 0.38492063492063494
# 3589, fewest_selected_stretch, GradientBoostingClassifier, 0.375, 0.38492063492063494
# 3589, fewest_selected_on, DecisionTreeClassifier, 0.75, 0.7499999999999999
# 3589, fewest_selected_in, DecisionTreeClassifier, 0.625, 0.6071428571428572
# 3589, fewest_selected_drop, DecisionTreeClassifier, 0.625, 0.6071428571428572
# 3589, fewest_selected_stretch, DecisionTreeClassifier, 0.75, 0.7499999999999999
# 3589, fewest_selected_on, RandomForestClassifier, 0.625, 0.6309523809523809
# 3589, fewest_selected_in, RandomForestClassifier, 0.625, 0.6309523809523809
# 3589, fewest_selected_drop, RandomForestClassifier, 0.5, 0.5
# 3589, fewest_selected_stretch, RandomForestClassifier, 0.625, 0.6309523809523809
# 3589, balanced_on, GradientBoostingClassifier, 0.375, 0.38492063492063494
# 3589, balanced_on, DecisionTreeClassifier, 0.625, 0.6071428571428572
# 3589, balanced_on, RandomForestClassifier, 0.5, 0.5
# 3589, balanced_in, GradientBoostingClassifier, 0.375, 0.38492063492063494
# 3589, balanced_in, DecisionTreeClassifier, 0.625, 0.6071428571428572
# 3589, balanced_in, RandomForestClassifier, 0.5, 0.5
# 7932, base, GradientBoostingClassifier, 0.75, 0.7666666666666667
# 7932, base, DecisionTreeClassifier, 0.875, 0.8818181818181818
# 7932, base, RandomForestClassifier, 0.875, 0.8818181818181818
# 7932, random_selected_on, GradientBoostingClassifier, 0.75, 0.7666666666666667
# 7932, random_selected_in, GradientBoostingClassifier, 0.75, 0.7666666666666667
# 7932, random_selected_drop, GradientBoostingClassifier, 0.625, 0.6428571428571429
# 7932, random_selected_stretch, GradientBoostingClassifier, 0.75, 0.75
# 7932, random_selected_on, DecisionTreeClassifier, 0.875, 0.8818181818181818
# 7932, random_selected_in, DecisionTreeClassifier, 0.625, 0.6428571428571429
# 7932, random_selected_drop, DecisionTreeClassifier, 0.625, 0.6428571428571429
# 7932, random_selected_stretch, DecisionTreeClassifier, 0.625, 0.6454545454545454
# 7932, random_selected_on, RandomForestClassifier, 0.625, 0.6454545454545454
# 7932, random_selected_in, RandomForestClassifier, 0.625, 0.6454545454545454
# 7932, random_selected_drop, RandomForestClassifier, 0.75, 0.7666666666666667
# 7932, random_selected_stretch, RandomForestClassifier, 0.625, 0.6454545454545454
# 7932, fewest_selected_on, GradientBoostingClassifier, 0.75, 0.7666666666666667
# 7932, fewest_selected_in, GradientBoostingClassifier, 0.75, 0.7666666666666667
# 7932, fewest_selected_drop, GradientBoostingClassifier, 0.75, 0.7666666666666667
# 7932, fewest_selected_stretch, GradientBoostingClassifier, 0.5, 0.5333333333333333
# 7932, fewest_selected_on, DecisionTreeClassifier, 0.875, 0.8818181818181818
# 7932, fewest_selected_in, DecisionTreeClassifier, 0.75, 0.7666666666666667
# 7932, fewest_selected_drop, DecisionTreeClassifier, 0.75, 0.7666666666666667
# 7932, fewest_selected_stretch, DecisionTreeClassifier, 0.75, 0.75
# 7932, fewest_selected_on, RandomForestClassifier, 0.625, 0.6454545454545454
# 7932, fewest_selected_in, RandomForestClassifier, 0.875, 0.8818181818181818
# 7932, fewest_selected_drop, RandomForestClassifier, 0.75, 0.75
# 7932, fewest_selected_stretch, RandomForestClassifier, 0.75, 0.7666666666666667
# 7932, balanced_on, GradientBoostingClassifier, 0.75, 0.7666666666666667
# 7932, balanced_on, DecisionTreeClassifier, 0.875, 0.8818181818181818
# 7932, balanced_on, RandomForestClassifier, 0.875, 0.8818181818181818
# 7932, balanced_in, GradientBoostingClassifier, 0.75, 0.7666666666666667
# 7932, balanced_in, DecisionTreeClassifier, 0.875, 0.8818181818181818
# 7932, balanced_in, RandomForestClassifier, 0.875, 0.8818181818181818
# 3846, base, GradientBoostingClassifier, 0.625, 0.6045454545454545
# 3846, base, DecisionTreeClassifier, 0.625, 0.6045454545454545
# 3846, base, RandomForestClassifier, 0.625, 0.6045454545454545
# 3846, random_selected_on, GradientBoostingClassifier, 0.625, 0.6045454545454545
# 3846, random_selected_in, GradientBoostingClassifier, 0.625, 0.6045454545454545
# 3846, random_selected_drop, GradientBoostingClassifier, 0.625, 0.6045454545454545
# 3846, random_selected_stretch, GradientBoostingClassifier, 0.625, 0.6045454545454545
# 3846, random_selected_on, DecisionTreeClassifier, 0.625, 0.6045454545454545
# 3846, random_selected_in, DecisionTreeClassifier, 0.625, 0.6045454545454545
# 3846, random_selected_drop, DecisionTreeClassifier, 0.625, 0.6045454545454545
# 3846, random_selected_stretch, DecisionTreeClassifier, 0.625, 0.6045454545454545
# 3846, random_selected_on, RandomForestClassifier, 0.625, 0.6045454545454545
# 3846, random_selected_in, RandomForestClassifier, 0.625, 0.6045454545454545
# 3846, random_selected_drop, RandomForestClassifier, 0.625, 0.6045454545454545
# 3846, random_selected_stretch, RandomForestClassifier, 0.625, 0.6045454545454545
# 3846, fewest_selected_on, GradientBoostingClassifier, 0.625, 0.6045454545454545
# 3846, fewest_selected_in, GradientBoostingClassifier, 0.625, 0.6045454545454545
# 3846, fewest_selected_drop, GradientBoostingClassifier, 0.625, 0.6045454545454545
# 3846, fewest_selected_stretch, GradientBoostingClassifier, 0.625, 0.6045454545454545
# 3846, fewest_selected_on, DecisionTreeClassifier, 0.625, 0.6045454545454545
# 3846, fewest_selected_in, DecisionTreeClassifier, 0.625, 0.6045454545454545
# 3846, fewest_selected_drop, DecisionTreeClassifier, 0.625, 0.6045454545454545
# 3846, fewest_selected_stretch, DecisionTreeClassifier, 0.625, 0.6045454545454545
# 3846, fewest_selected_on, RandomForestClassifier, 0.5, 0.41666666666666663
# 3846, fewest_selected_in, RandomForestClassifier, 0.5, 0.41666666666666663
# 3846, fewest_selected_drop, RandomForestClassifier, 0.625, 0.6045454545454545
# 3846, fewest_selected_stretch, RandomForestClassifier, 0.5, 0.41666666666666663
# 3846, balanced_on, GradientBoostingClassifier, 0.625, 0.6045454545454545
# 3846, balanced_on, DecisionTreeClassifier, 0.625, 0.6045454545454545
# 3846, balanced_on, RandomForestClassifier, 0.625, 0.6045454545454545
# 3846, balanced_in, GradientBoostingClassifier, 0.625, 0.6045454545454545
# 3846, balanced_in, DecisionTreeClassifier, 0.625, 0.6045454545454545
# 3846, balanced_in, RandomForestClassifier, 0.625, 0.6045454545454545
# 2643, base, GradientBoostingClassifier, 0.625, 0.5636363636363637
# 2643, base, DecisionTreeClassifier, 0.625, 0.5636363636363637
# 2643, base, RandomForestClassifier, 0.625, 0.5636363636363637
# 2643, random_selected_on, GradientBoostingClassifier, 0.625, 0.6190476190476191
# 2643, random_selected_in, GradientBoostingClassifier, 0.625, 0.6190476190476191
# 2643, random_selected_drop, GradientBoostingClassifier, 0.625, 0.6190476190476191
# 2643, random_selected_stretch, GradientBoostingClassifier, 0.625, 0.6190476190476191
# 2643, random_selected_on, DecisionTreeClassifier, 0.625, 0.6190476190476191
# 2643, random_selected_in, DecisionTreeClassifier, 0.625, 0.6190476190476191
# 2643, random_selected_drop, DecisionTreeClassifier, 0.625, 0.6190476190476191
# 2643, random_selected_stretch, DecisionTreeClassifier, 0.5, 0.4666666666666667
# 2643, random_selected_on, RandomForestClassifier, 0.625, 0.5636363636363637
# 2643, random_selected_in, RandomForestClassifier, 0.5, 0.3333333333333333
# 2643, random_selected_drop, RandomForestClassifier, 0.5, 0.3333333333333333
# 2643, random_selected_stretch, RandomForestClassifier, 0.625, 0.5636363636363637
# 2643, fewest_selected_on, GradientBoostingClassifier, 0.625, 0.6190476190476191
# 2643, fewest_selected_in, GradientBoostingClassifier, 0.75, 0.7333333333333334
# 2643, fewest_selected_drop, GradientBoostingClassifier, 0.75, 0.7333333333333334
# 2643, fewest_selected_stretch, GradientBoostingClassifier, 0.875, 0.873015873015873
# 2643, fewest_selected_on, DecisionTreeClassifier, 1.0, 1.0
# 2643, fewest_selected_in, DecisionTreeClassifier, 0.875, 0.873015873015873
# 2643, fewest_selected_drop, DecisionTreeClassifier, 0.875, 0.873015873015873
# 2643, fewest_selected_stretch, DecisionTreeClassifier, 0.25, 0.25
# 2643, fewest_selected_on, RandomForestClassifier, 0.625, 0.5636363636363637
# 2643, fewest_selected_in, RandomForestClassifier, 0.75, 0.7333333333333334
# 2643, fewest_selected_drop, RandomForestClassifier, 0.75, 0.7333333333333334
# 2643, fewest_selected_stretch, RandomForestClassifier, 0.625, 0.5636363636363637
# 2643, balanced_on, GradientBoostingClassifier, 0.625, 0.5636363636363637
# 2643, balanced_on, DecisionTreeClassifier, 0.625, 0.5636363636363637
# 2643, balanced_on, RandomForestClassifier, 0.625, 0.5636363636363637
# 2643, balanced_in, GradientBoostingClassifier, 0.625, 0.5636363636363637
# 2643, balanced_in, DecisionTreeClassifier, 0.625, 0.5636363636363637
# 2643, balanced_in, RandomForestClassifier, 0.625, 0.5636363636363637
# 3832, base, GradientBoostingClassifier, 0.5, 0.5333333333333333
# 3832, base, DecisionTreeClassifier, 0.5, 0.5333333333333333
# 3832, base, RandomForestClassifier, 0.75, 0.7666666666666667
# 3832, random_selected_on, GradientBoostingClassifier, 0.625, 0.6428571428571429
# 3832, random_selected_in, GradientBoostingClassifier, 0.875, 0.8818181818181818
# 3832, random_selected_drop, GradientBoostingClassifier, 0.875, 0.8818181818181818
# 3832, random_selected_stretch, GradientBoostingClassifier, 0.625, 0.6454545454545454
# 3832, random_selected_on, DecisionTreeClassifier, 0.625, 0.6428571428571429
# 3832, random_selected_in, DecisionTreeClassifier, 0.875, 0.8818181818181818
# 3832, random_selected_drop, DecisionTreeClassifier, 0.875, 0.8818181818181818
# 3832, random_selected_stretch, DecisionTreeClassifier, 0.5, 0.5333333333333333
# 3832, random_selected_on, RandomForestClassifier, 0.75, 0.7666666666666667
# 3832, random_selected_in, RandomForestClassifier, 0.625, 0.6428571428571429
# 3832, random_selected_drop, RandomForestClassifier, 0.625, 0.6428571428571429
# 3832, random_selected_stretch, RandomForestClassifier, 0.625, 0.6428571428571429
# 3832, fewest_selected_on, GradientBoostingClassifier, 0.5, 0.5333333333333333
# 3832, fewest_selected_in, GradientBoostingClassifier, 0.875, 0.8818181818181818
# 3832, fewest_selected_drop, GradientBoostingClassifier, 0.875, 0.8818181818181818
# 3832, fewest_selected_stretch, GradientBoostingClassifier, 0.625, 0.6428571428571429
# 3832, fewest_selected_on, DecisionTreeClassifier, 0.5, 0.5333333333333333
# 3832, fewest_selected_in, DecisionTreeClassifier, 0.875, 0.8818181818181818
# 3832, fewest_selected_drop, DecisionTreeClassifier, 0.875, 0.8818181818181818
# 3832, fewest_selected_stretch, DecisionTreeClassifier, 0.5, 0.5333333333333333
# 3832, fewest_selected_on, RandomForestClassifier, 0.625, 0.6454545454545454
# 3832, fewest_selected_in, RandomForestClassifier, 0.875, 0.8818181818181818
# 3832, fewest_selected_drop, RandomForestClassifier, 0.75, 0.7666666666666667
# 3832, fewest_selected_stretch, RandomForestClassifier, 0.625, 0.6428571428571429
# 3832, balanced_on, GradientBoostingClassifier, 0.5, 0.5333333333333333
# 3832, balanced_on, DecisionTreeClassifier, 0.5, 0.5333333333333333
# 3832, balanced_on, RandomForestClassifier, 0.75, 0.7666666666666667
# 3832, balanced_in, GradientBoostingClassifier, 0.5, 0.5333333333333333
# 3832, balanced_in, DecisionTreeClassifier, 0.5, 0.5333333333333333
# 3832, balanced_in, RandomForestClassifier, 0.75, 0.7666666666666667
# 7950, base, GradientBoostingClassifier, 0.5, 0.5
# 7950, base, DecisionTreeClassifier, 0.75, 0.7499999999999999
# 7950, base, RandomForestClassifier, 0.375, 0.20454545454545453
# 7950, random_selected_on, GradientBoostingClassifier, 0.75, 0.7499999999999999
# 7950, random_selected_in, GradientBoostingClassifier, 0.375, 0.20454545454545453
# 7950, random_selected_drop, GradientBoostingClassifier, 0.5, 0.43333333333333335
# 7950, random_selected_stretch, GradientBoostingClassifier, 0.625, 0.6071428571428572
# 7950, random_selected_on, DecisionTreeClassifier, 0.25, 0.15000000000000002
# 7950, random_selected_in, DecisionTreeClassifier, 0.375, 0.20454545454545453
# 7950, random_selected_drop, DecisionTreeClassifier, 0.5, 0.43333333333333335
# 7950, random_selected_stretch, DecisionTreeClassifier, 0.5, 0.5
# 7950, random_selected_on, RandomForestClassifier, 0.375, 0.20454545454545453
# 7950, random_selected_in, RandomForestClassifier, 0.5, 0.43333333333333335
# 7950, random_selected_drop, RandomForestClassifier, 0.5, 0.43333333333333335
# 7950, random_selected_stretch, RandomForestClassifier, 0.375, 0.20454545454545453
# 7950, fewest_selected_on, GradientBoostingClassifier, 0.375, 0.20454545454545453
# 7950, fewest_selected_in, GradientBoostingClassifier, 0.125, 0.08333333333333333
# 7950, fewest_selected_drop, GradientBoostingClassifier, 0.125, 0.08333333333333333
# 7950, fewest_selected_stretch, GradientBoostingClassifier, 0.25, 0.15000000000000002
# 7950, fewest_selected_on, DecisionTreeClassifier, 0.25, 0.15000000000000002
# 7950, fewest_selected_in, DecisionTreeClassifier, 0.375, 0.20454545454545453
# 7950, fewest_selected_drop, DecisionTreeClassifier, 0.375, 0.20454545454545453
# 7950, fewest_selected_stretch, DecisionTreeClassifier, 0.5, 0.43333333333333335
# 7950, fewest_selected_on, RandomForestClassifier, 0.375, 0.20454545454545453
# 7950, fewest_selected_in, RandomForestClassifier, 0.5, 0.43333333333333335
# 7950, fewest_selected_drop, RandomForestClassifier, 0.5, 0.43333333333333335
# 7950, fewest_selected_stretch, RandomForestClassifier, 0.375, 0.20454545454545453
# 7950, balanced_on, GradientBoostingClassifier, 0.5, 0.5
# 7950, balanced_on, DecisionTreeClassifier, 0.75, 0.7499999999999999
# 7950, balanced_on, RandomForestClassifier, 0.375, 0.20454545454545453
# 7950, balanced_in, GradientBoostingClassifier, 0.5, 0.5
# 7950, balanced_in, DecisionTreeClassifier, 0.75, 0.7499999999999999
# 7950, balanced_in, RandomForestClassifier, 0.375, 0.20454545454545453
# 2884, base, GradientBoostingClassifier, 0.75, 0.75
# 2884, base, DecisionTreeClassifier, 0.75, 0.75
# 2884, base, RandomForestClassifier, 0.875, 0.873015873015873
# 2884, random_selected_on, GradientBoostingClassifier, 0.5, 0.5
# 2884, random_selected_in, GradientBoostingClassifier, 0.5, 0.5
# 2884, random_selected_drop, GradientBoostingClassifier, 0.5, 0.5
# 2884, random_selected_stretch, GradientBoostingClassifier, 0.5, 0.5
# 2884, random_selected_on, DecisionTreeClassifier, 0.5, 0.5
# 2884, random_selected_in, DecisionTreeClassifier, 0.5, 0.5
# 2884, random_selected_drop, DecisionTreeClassifier, 0.5, 0.5
# 2884, random_selected_stretch, DecisionTreeClassifier, 0.5, 0.5
# 2884, random_selected_on, RandomForestClassifier, 0.875, 0.873015873015873
# 2884, random_selected_in, RandomForestClassifier, 0.875, 0.873015873015873
# 2884, random_selected_drop, RandomForestClassifier, 0.875, 0.873015873015873
# 2884, random_selected_stretch, RandomForestClassifier, 0.625, 0.6190476190476191
# 2884, fewest_selected_on, GradientBoostingClassifier, 0.75, 0.75
# 2884, fewest_selected_in, GradientBoostingClassifier, 0.75, 0.75
# 2884, fewest_selected_drop, GradientBoostingClassifier, 0.75, 0.75
# 2884, fewest_selected_stretch, GradientBoostingClassifier, 0.625, 0.6190476190476191
# 2884, fewest_selected_on, DecisionTreeClassifier, 0.75, 0.75
# 2884, fewest_selected_in, DecisionTreeClassifier, 0.75, 0.75
# 2884, fewest_selected_drop, DecisionTreeClassifier, 0.75, 0.75
# 2884, fewest_selected_stretch, DecisionTreeClassifier, 0.5, 0.5
# 2884, fewest_selected_on, RandomForestClassifier, 0.75, 0.75
# 2884, fewest_selected_in, RandomForestClassifier, 0.875, 0.873015873015873
# 2884, fewest_selected_drop, RandomForestClassifier, 0.875, 0.873015873015873
# 2884, fewest_selected_stretch, RandomForestClassifier, 0.5, 0.4666666666666667
# 2884, balanced_on, GradientBoostingClassifier, 0.75, 0.75
# 2884, balanced_on, DecisionTreeClassifier, 0.75, 0.75
# 2884, balanced_on, RandomForestClassifier, 0.875, 0.873015873015873
# 2884, balanced_in, GradientBoostingClassifier, 0.75, 0.75
# 2884, balanced_in, DecisionTreeClassifier, 0.75, 0.75
# 2884, balanced_in, RandomForestClassifier, 0.875, 0.873015873015873
# 1971, base, GradientBoostingClassifier, 0.75, 0.7500000000000001
# 1971, base, DecisionTreeClassifier, 0.75, 0.7500000000000001
# 1971, base, RandomForestClassifier, 0.5, 0.5
# 1971, random_selected_on, GradientBoostingClassifier, 0.625, 0.6045454545454545
# 1971, random_selected_in, GradientBoostingClassifier, 0.375, 0.3409090909090909
# 1971, random_selected_drop, GradientBoostingClassifier, 0.625, 0.6045454545454545
# 1971, random_selected_stretch, GradientBoostingClassifier, 0.625, 0.6045454545454545
# 1971, random_selected_on, DecisionTreeClassifier, 0.5, 0.5
# 1971, random_selected_in, DecisionTreeClassifier, 0.625, 0.6309523809523809
# 1971, random_selected_drop, DecisionTreeClassifier, 0.625, 0.6045454545454545
# 1971, random_selected_stretch, DecisionTreeClassifier, 0.5, 0.5
# 1971, random_selected_on, RandomForestClassifier, 0.625, 0.6045454545454545
# 1971, random_selected_in, RandomForestClassifier, 0.75, 0.7083333333333333
# 1971, random_selected_drop, RandomForestClassifier, 0.5, 0.5
# 1971, random_selected_stretch, RandomForestClassifier, 0.625, 0.6045454545454545
# 1971, fewest_selected_on, GradientBoostingClassifier, 0.625, 0.6045454545454545
# 1971, fewest_selected_in, GradientBoostingClassifier, 0.75, 0.7500000000000001
# 1971, fewest_selected_drop, GradientBoostingClassifier, 0.75, 0.7500000000000001
# 1971, fewest_selected_stretch, GradientBoostingClassifier, 0.625, 0.6045454545454545
# 1971, fewest_selected_on, DecisionTreeClassifier, 0.625, 0.6045454545454545
# 1971, fewest_selected_in, DecisionTreeClassifier, 0.75, 0.7500000000000001
# 1971, fewest_selected_drop, DecisionTreeClassifier, 0.75, 0.7500000000000001
# 1971, fewest_selected_stretch, DecisionTreeClassifier, 0.625, 0.6309523809523809
# 1971, fewest_selected_on, RandomForestClassifier, 0.5, 0.5
# 1971, fewest_selected_in, RandomForestClassifier, 0.625, 0.6309523809523809
# 1971, fewest_selected_drop, RandomForestClassifier, 0.5, 0.5
# 1971, fewest_selected_stretch, RandomForestClassifier, 0.5, 0.5
# 1971, balanced_on, GradientBoostingClassifier, 0.75, 0.7500000000000001
# 1971, balanced_on, DecisionTreeClassifier, 0.75, 0.7500000000000001
# 1971, balanced_on, RandomForestClassifier, 0.5, 0.5
# 1971, balanced_in, GradientBoostingClassifier, 0.75, 0.7500000000000001
# 1971, balanced_in, DecisionTreeClassifier, 0.75, 0.7500000000000001
# 1971, balanced_in, RandomForestClassifier, 0.5, 0.5
# 6939, base, GradientBoostingClassifier, 0.75, 0.7500000000000001
# 6939, base, DecisionTreeClassifier, 0.75, 0.7499999999999999
# 6939, base, RandomForestClassifier, 0.875, 0.8681818181818182
# 6939, random_selected_on, GradientBoostingClassifier, 0.5, 0.5
# 6939, random_selected_in, GradientBoostingClassifier, 0.75, 0.7499999999999999
# 6939, random_selected_drop, GradientBoostingClassifier, 0.75, 0.7500000000000001
# 6939, random_selected_stretch, GradientBoostingClassifier, 0.75, 0.7083333333333333
# 6939, random_selected_on, DecisionTreeClassifier, 0.5, 0.5
# 6939, random_selected_in, DecisionTreeClassifier, 0.75, 0.7499999999999999
# 6939, random_selected_drop, DecisionTreeClassifier, 0.75, 0.7499999999999999
# 6939, random_selected_stretch, DecisionTreeClassifier, 0.75, 0.7083333333333333
# 6939, random_selected_on, RandomForestClassifier, 0.875, 0.8681818181818182
# 6939, random_selected_in, RandomForestClassifier, 0.875, 0.8681818181818182
# 6939, random_selected_drop, RandomForestClassifier, 0.875, 0.8681818181818182
# 6939, random_selected_stretch, RandomForestClassifier, 0.875, 0.8681818181818182
# 6939, fewest_selected_on, GradientBoostingClassifier, 0.625, 0.6309523809523809
# 6939, fewest_selected_in, GradientBoostingClassifier, 0.875, 0.8681818181818182
# 6939, fewest_selected_drop, GradientBoostingClassifier, 0.75, 0.7500000000000001
# 6939, fewest_selected_stretch, GradientBoostingClassifier, 0.625, 0.4807692307692308
# 6939, fewest_selected_on, DecisionTreeClassifier, 0.75, 0.7083333333333333
# 6939, fewest_selected_in, DecisionTreeClassifier, 0.75, 0.7499999999999999
# 6939, fewest_selected_drop, DecisionTreeClassifier, 0.75, 0.7499999999999999
# 6939, fewest_selected_stretch, DecisionTreeClassifier, 0.875, 0.8681818181818182
# 6939, fewest_selected_on, RandomForestClassifier, 0.875, 0.8681818181818182
# 6939, fewest_selected_in, RandomForestClassifier, 0.875, 0.8681818181818182
# 6939, fewest_selected_drop, RandomForestClassifier, 0.875, 0.8681818181818182
# 6939, fewest_selected_stretch, RandomForestClassifier, 0.875, 0.8681818181818182
# 6939, balanced_on, GradientBoostingClassifier, 0.75, 0.7500000000000001
# 6939, balanced_on, DecisionTreeClassifier, 0.75, 0.7499999999999999
# 6939, balanced_on, RandomForestClassifier, 0.875, 0.8681818181818182
# 6939, balanced_in, GradientBoostingClassifier, 0.75, 0.7500000000000001
# 6939, balanced_in, DecisionTreeClassifier, 0.75, 0.7499999999999999
# 6939, balanced_in, RandomForestClassifier, 0.875, 0.8681818181818182
# 9375, base, GradientBoostingClassifier, 0.5, 0.5666666666666667
# 9375, base, DecisionTreeClassifier, 0.75, 0.7916666666666666
# 9375, base, RandomForestClassifier, 0.875, 0.891025641025641
# 9375, random_selected_on, GradientBoostingClassifier, 1.0, 1.0
# 9375, random_selected_in, GradientBoostingClassifier, 0.625, 0.6863636363636364
# 9375, random_selected_drop, GradientBoostingClassifier, 0.875, 0.891025641025641
# 9375, random_selected_stretch, GradientBoostingClassifier, 0.875, 0.891025641025641
# 9375, random_selected_on, DecisionTreeClassifier, 0.875, 0.891025641025641
# 9375, random_selected_in, DecisionTreeClassifier, 0.625, 0.6863636363636364
# 9375, random_selected_drop, DecisionTreeClassifier, 0.375, 0.4246031746031746
# 9375, random_selected_stretch, DecisionTreeClassifier, 0.625, 0.6863636363636364
# 9375, random_selected_on, RandomForestClassifier, 1.0, 1.0
# 9375, random_selected_in, RandomForestClassifier, 1.0, 1.0
# 9375, random_selected_drop, RandomForestClassifier, 0.75, 0.7916666666666666
# 9375, random_selected_stretch, RandomForestClassifier, 1.0, 1.0
# 9375, fewest_selected_on, GradientBoostingClassifier, 0.625, 0.6863636363636364
# 9375, fewest_selected_in, GradientBoostingClassifier, 0.625, 0.6863636363636364
# 9375, fewest_selected_drop, GradientBoostingClassifier, 0.5, 0.5666666666666667
# 9375, fewest_selected_stretch, GradientBoostingClassifier, 0.75, 0.7916666666666666
# 9375, fewest_selected_on, DecisionTreeClassifier, 0.5, 0.5833333333333333
# 9375, fewest_selected_in, DecisionTreeClassifier, 0.5, 0.5666666666666667
# 9375, fewest_selected_drop, DecisionTreeClassifier, 0.5, 0.5666666666666667
# 9375, fewest_selected_stretch, DecisionTreeClassifier, 0.625, 0.6863636363636364
# 9375, fewest_selected_on, RandomForestClassifier, 0.625, 0.6863636363636364
# 9375, fewest_selected_in, RandomForestClassifier, 1.0, 1.0
# 9375, fewest_selected_drop, RandomForestClassifier, 0.75, 0.7916666666666666
# 9375, fewest_selected_stretch, RandomForestClassifier, 0.875, 0.891025641025641
# 9375, balanced_on, GradientBoostingClassifier, 0.5, 0.5666666666666667
# 9375, balanced_on, DecisionTreeClassifier, 0.75, 0.7916666666666666
# 9375, balanced_on, RandomForestClassifier, 0.875, 0.891025641025641
# 9375, balanced_in, GradientBoostingClassifier, 0.5, 0.5666666666666667
# 9375, balanced_in, DecisionTreeClassifier, 0.75, 0.7916666666666666
# 9375, balanced_in, RandomForestClassifier, 0.875, 0.891025641025641
# 1058, base, GradientBoostingClassifier, 0.625, 0.4807692307692308
# 1058, base, DecisionTreeClassifier, 0.875, 0.8681818181818182
# 1058, base, RandomForestClassifier, 0.875, 0.8681818181818182
# 1058, random_selected_on, GradientBoostingClassifier, 0.875, 0.8681818181818182
# 1058, random_selected_in, GradientBoostingClassifier, 0.625, 0.4807692307692308
# 1058, random_selected_drop, GradientBoostingClassifier, 0.625, 0.4807692307692308
# 1058, random_selected_stretch, GradientBoostingClassifier, 0.625, 0.4807692307692308
# 1058, random_selected_on, DecisionTreeClassifier, 0.875, 0.8681818181818182
# 1058, random_selected_in, DecisionTreeClassifier, 0.875, 0.8681818181818182
# 1058, random_selected_drop, DecisionTreeClassifier, 0.625, 0.4807692307692308
# 1058, random_selected_stretch, DecisionTreeClassifier, 0.625, 0.4807692307692308
# 1058, random_selected_on, RandomForestClassifier, 0.875, 0.8681818181818182
# 1058, random_selected_in, RandomForestClassifier, 0.875, 0.8681818181818182
# 1058, random_selected_drop, RandomForestClassifier, 0.875, 0.8681818181818182
# 1058, random_selected_stretch, RandomForestClassifier, 0.75, 0.7083333333333333
# 1058, fewest_selected_on, GradientBoostingClassifier, 0.625, 0.4807692307692308
# 1058, fewest_selected_in, GradientBoostingClassifier, 0.625, 0.4807692307692308
# 1058, fewest_selected_drop, GradientBoostingClassifier, 0.625, 0.4807692307692308
# 1058, fewest_selected_stretch, GradientBoostingClassifier, 0.625, 0.4807692307692308
# 1058, fewest_selected_on, DecisionTreeClassifier, 0.875, 0.8681818181818182
# 1058, fewest_selected_in, DecisionTreeClassifier, 0.875, 0.8681818181818182
# 1058, fewest_selected_drop, DecisionTreeClassifier, 0.875, 0.8681818181818182
# 1058, fewest_selected_stretch, DecisionTreeClassifier, 1.0, 1.0
# 1058, fewest_selected_on, RandomForestClassifier, 0.875, 0.8681818181818182
# 1058, fewest_selected_in, RandomForestClassifier, 0.875, 0.8681818181818182
# 1058, fewest_selected_drop, RandomForestClassifier, 0.875, 0.8681818181818182
# 1058, fewest_selected_stretch, RandomForestClassifier, 0.75, 0.7083333333333333
# 1058, balanced_on, GradientBoostingClassifier, 0.625, 0.4807692307692308
# 1058, balanced_on, DecisionTreeClassifier, 0.875, 0.8681818181818182
# 1058, balanced_on, RandomForestClassifier, 0.875, 0.8681818181818182
# 1058, balanced_in, GradientBoostingClassifier, 0.625, 0.4807692307692308
# 1058, balanced_in, DecisionTreeClassifier, 0.875, 0.8681818181818182
# 1058, balanced_in, RandomForestClassifier, 0.875, 0.8681818181818182
# 2097, base, GradientBoostingClassifier, 0.75, 0.7500000000000001
# 2097, base, DecisionTreeClassifier, 0.625, 0.6045454545454545
# 2097, base, RandomForestClassifier, 0.375, 0.38492063492063494
# 2097, random_selected_on, GradientBoostingClassifier, 0.375, 0.38492063492063494
# 2097, random_selected_in, GradientBoostingClassifier, 0.375, 0.38492063492063494
# 2097, random_selected_drop, GradientBoostingClassifier, 0.375, 0.38492063492063494
# 2097, random_selected_stretch, GradientBoostingClassifier, 0.125, 0.08333333333333333
# 2097, random_selected_on, DecisionTreeClassifier, 0.375, 0.38492063492063494
# 2097, random_selected_in, DecisionTreeClassifier, 0.375, 0.38492063492063494
# 2097, random_selected_drop, DecisionTreeClassifier, 0.375, 0.38492063492063494
# 2097, random_selected_stretch, DecisionTreeClassifier, 0.75, 0.7499999999999999
# 2097, random_selected_on, RandomForestClassifier, 0.5, 0.5
# 2097, random_selected_in, RandomForestClassifier, 0.625, 0.6045454545454545
# 2097, random_selected_drop, RandomForestClassifier, 0.375, 0.38492063492063494
# 2097, random_selected_stretch, RandomForestClassifier, 0.5, 0.5
# 2097, fewest_selected_on, GradientBoostingClassifier, 0.5, 0.5
# 2097, fewest_selected_in, GradientBoostingClassifier, 0.5, 0.5
# 2097, fewest_selected_drop, GradientBoostingClassifier, 0.5, 0.5
# 2097, fewest_selected_stretch, GradientBoostingClassifier, 0.375, 0.34523809523809523
# 2097, fewest_selected_on, DecisionTreeClassifier, 0.5, 0.5
# 2097, fewest_selected_in, DecisionTreeClassifier, 0.5, 0.5
# 2097, fewest_selected_drop, DecisionTreeClassifier, 0.5, 0.5
# 2097, fewest_selected_stretch, DecisionTreeClassifier, 0.375, 0.34523809523809523
# 2097, fewest_selected_on, RandomForestClassifier, 0.625, 0.6045454545454545
# 2097, fewest_selected_in, RandomForestClassifier, 0.25, 0.25
# 2097, fewest_selected_drop, RandomForestClassifier, 0.375, 0.38492063492063494
# 2097, fewest_selected_stretch, RandomForestClassifier, 0.375, 0.38492063492063494
# 2097, balanced_on, GradientBoostingClassifier, 0.75, 0.7500000000000001
# 2097, balanced_on, DecisionTreeClassifier, 0.625, 0.6045454545454545
# 2097, balanced_on, RandomForestClassifier, 0.375, 0.38492063492063494
# 2097, balanced_in, GradientBoostingClassifier, 0.75, 0.7500000000000001
# 2097, balanced_in, DecisionTreeClassifier, 0.625, 0.6045454545454545
# 2097, balanced_in, RandomForestClassifier, 0.375, 0.38492063492063494
# 4944, base, GradientBoostingClassifier, 0.625, 0.5636363636363637
# 4944, base, DecisionTreeClassifier, 0.625, 0.5636363636363637
# 4944, base, RandomForestClassifier, 0.75, 0.7333333333333334
# 4944, random_selected_on, GradientBoostingClassifier, 0.5, 0.3333333333333333
# 4944, random_selected_in, GradientBoostingClassifier, 0.75, 0.7333333333333334
# 4944, random_selected_drop, GradientBoostingClassifier, 0.75, 0.7333333333333334
# 4944, random_selected_stretch, GradientBoostingClassifier, 0.75, 0.7333333333333334
# 4944, random_selected_on, DecisionTreeClassifier, 0.625, 0.5636363636363637
# 4944, random_selected_in, DecisionTreeClassifier, 1.0, 1.0
# 4944, random_selected_drop, DecisionTreeClassifier, 1.0, 1.0
# 4944, random_selected_stretch, DecisionTreeClassifier, 0.875, 0.873015873015873
# 4944, random_selected_on, RandomForestClassifier, 0.75, 0.7333333333333334
# 4944, random_selected_in, RandomForestClassifier, 0.75, 0.7333333333333334
# 4944, random_selected_drop, RandomForestClassifier, 0.875, 0.873015873015873
# 4944, random_selected_stretch, RandomForestClassifier, 0.5, 0.3333333333333333
# 4944, fewest_selected_on, GradientBoostingClassifier, 0.625, 0.5636363636363637
# 4944, fewest_selected_in, GradientBoostingClassifier, 0.875, 0.873015873015873
# 4944, fewest_selected_drop, GradientBoostingClassifier, 0.75, 0.7333333333333334
# 4944, fewest_selected_stretch, GradientBoostingClassifier, 0.375, 0.3650793650793651
# 4944, fewest_selected_on, DecisionTreeClassifier, 0.625, 0.5636363636363637
# 4944, fewest_selected_in, DecisionTreeClassifier, 0.875, 0.873015873015873
# 4944, fewest_selected_drop, DecisionTreeClassifier, 1.0, 1.0
# 4944, fewest_selected_stretch, DecisionTreeClassifier, 0.625, 0.6190476190476191
# 4944, fewest_selected_on, RandomForestClassifier, 0.75, 0.7333333333333334
# 4944, fewest_selected_in, RandomForestClassifier, 0.625, 0.5636363636363637
# 4944, fewest_selected_drop, RandomForestClassifier, 0.625, 0.5636363636363637
# 4944, fewest_selected_stretch, RandomForestClassifier, 0.5, 0.3333333333333333
# 4944, balanced_on, GradientBoostingClassifier, 0.625, 0.5636363636363637
# 4944, balanced_on, DecisionTreeClassifier, 0.625, 0.5636363636363637
# 4944, balanced_on, RandomForestClassifier, 0.75, 0.7333333333333334
# 4944, balanced_in, GradientBoostingClassifier, 0.625, 0.5636363636363637
# 4944, balanced_in, DecisionTreeClassifier, 0.625, 0.5636363636363637
# 4944, balanced_in, RandomForestClassifier, 0.75, 0.7333333333333334
# 5923, base, GradientBoostingClassifier, 0.625, 0.5636363636363637
# 5923, base, DecisionTreeClassifier, 0.75, 0.7333333333333334
# 5923, base, RandomForestClassifier, 0.625, 0.5636363636363637
# 5923, random_selected_on, GradientBoostingClassifier, 0.625, 0.6190476190476191
# 5923, random_selected_in, GradientBoostingClassifier, 0.625, 0.6190476190476191
# 5923, random_selected_drop, GradientBoostingClassifier, 0.75, 0.75
# 5923, random_selected_stretch, GradientBoostingClassifier, 0.5, 0.3333333333333333
# 5923, random_selected_on, DecisionTreeClassifier, 0.5, 0.5
# 5923, random_selected_in, DecisionTreeClassifier, 0.5, 0.5
# 5923, random_selected_drop, DecisionTreeClassifier, 0.5, 0.5
# 5923, random_selected_stretch, DecisionTreeClassifier, 0.375, 0.2727272727272727
# 5923, random_selected_on, RandomForestClassifier, 0.625, 0.5636363636363637
# 5923, random_selected_in, RandomForestClassifier, 0.5, 0.3333333333333333
# 5923, random_selected_drop, RandomForestClassifier, 0.5, 0.3333333333333333
# 5923, random_selected_stretch, RandomForestClassifier, 0.5, 0.3333333333333333
# 5923, fewest_selected_on, GradientBoostingClassifier, 0.375, 0.2727272727272727
# 5923, fewest_selected_in, GradientBoostingClassifier, 0.625, 0.5636363636363637
# 5923, fewest_selected_drop, GradientBoostingClassifier, 0.625, 0.5636363636363637
# 5923, fewest_selected_stretch, GradientBoostingClassifier, 0.5, 0.4666666666666667
# 5923, fewest_selected_on, DecisionTreeClassifier, 0.5, 0.4666666666666667
# 5923, fewest_selected_in, DecisionTreeClassifier, 0.75, 0.7333333333333334
# 5923, fewest_selected_drop, DecisionTreeClassifier, 0.75, 0.7333333333333334
# 5923, fewest_selected_stretch, DecisionTreeClassifier, 0.375, 0.2727272727272727
# 5923, fewest_selected_on, RandomForestClassifier, 0.5, 0.3333333333333333
# 5923, fewest_selected_in, RandomForestClassifier, 0.625, 0.5636363636363637
# 5923, fewest_selected_drop, RandomForestClassifier, 0.625, 0.5636363636363637
# 5923, fewest_selected_stretch, RandomForestClassifier, 0.625, 0.5636363636363637
# 5923, balanced_on, GradientBoostingClassifier, 0.625, 0.5636363636363637
# 5923, balanced_on, DecisionTreeClassifier, 0.75, 0.7333333333333334
# 5923, balanced_on, RandomForestClassifier, 0.625, 0.5636363636363637
# 5923, balanced_in, GradientBoostingClassifier, 0.625, 0.5636363636363637
# 5923, balanced_in, DecisionTreeClassifier, 0.75, 0.7333333333333334
# 5923, balanced_in, RandomForestClassifier, 0.625, 0.5636363636363637
# 781, base, GradientBoostingClassifier, 0.5, 0.43333333333333335
# 781, base, DecisionTreeClassifier, 0.5, 0.43333333333333335
# 781, base, RandomForestClassifier, 0.5, 0.43333333333333335
# 781, random_selected_on, GradientBoostingClassifier, 0.625, 0.6071428571428572
# 781, random_selected_in, GradientBoostingClassifier, 0.5, 0.43333333333333335
# 781, random_selected_drop, GradientBoostingClassifier, 0.5, 0.43333333333333335
# 781, random_selected_stretch, GradientBoostingClassifier, 0.5, 0.43333333333333335
# 781, random_selected_on, DecisionTreeClassifier, 0.625, 0.6071428571428572
# 781, random_selected_in, DecisionTreeClassifier, 0.5, 0.43333333333333335
# 781, random_selected_drop, DecisionTreeClassifier, 0.5, 0.43333333333333335
# 781, random_selected_stretch, DecisionTreeClassifier, 0.5, 0.43333333333333335
# 781, random_selected_on, RandomForestClassifier, 0.625, 0.6071428571428572
# 781, random_selected_in, RandomForestClassifier, 0.75, 0.7499999999999999
# 781, random_selected_drop, RandomForestClassifier, 0.625, 0.6071428571428572
# 781, random_selected_stretch, RandomForestClassifier, 0.75, 0.7499999999999999
# 781, fewest_selected_on, GradientBoostingClassifier, 0.5, 0.43333333333333335
# 781, fewest_selected_in, GradientBoostingClassifier, 0.5, 0.43333333333333335
# 781, fewest_selected_drop, GradientBoostingClassifier, 0.5, 0.43333333333333335
# 781, fewest_selected_stretch, GradientBoostingClassifier, 0.5, 0.43333333333333335
# 781, fewest_selected_on, DecisionTreeClassifier, 0.5, 0.43333333333333335
# 781, fewest_selected_in, DecisionTreeClassifier, 0.5, 0.43333333333333335
# 781, fewest_selected_drop, DecisionTreeClassifier, 0.5, 0.43333333333333335
# 781, fewest_selected_stretch, DecisionTreeClassifier, 0.5, 0.43333333333333335
# 781, fewest_selected_on, RandomForestClassifier, 0.625, 0.6071428571428572
# 781, fewest_selected_in, RandomForestClassifier, 0.5, 0.43333333333333335
# 781, fewest_selected_drop, RandomForestClassifier, 0.5, 0.43333333333333335
# 781, fewest_selected_stretch, RandomForestClassifier, 0.625, 0.6071428571428572
# 781, balanced_on, GradientBoostingClassifier, 0.5, 0.43333333333333335
# 781, balanced_on, DecisionTreeClassifier, 0.5, 0.43333333333333335
# 781, balanced_on, RandomForestClassifier, 0.5, 0.43333333333333335
# 781, balanced_in, GradientBoostingClassifier, 0.5, 0.43333333333333335
# 781, balanced_in, DecisionTreeClassifier, 0.5, 0.43333333333333335
# 781, balanced_in, RandomForestClassifier, 0.5, 0.43333333333333335
# 6406, base, GradientBoostingClassifier, 0.625, 0.5769230769230769
# 6406, base, DecisionTreeClassifier, 0.75, 0.7666666666666667
# 6406, base, RandomForestClassifier, 0.875, 0.8589743589743589
# 6406, random_selected_on, GradientBoostingClassifier, 0.625, 0.5769230769230769
# 6406, random_selected_in, GradientBoostingClassifier, 0.875, 0.8589743589743589
# 6406, random_selected_drop, GradientBoostingClassifier, 0.875, 0.8818181818181818
# 6406, random_selected_stretch, GradientBoostingClassifier, 0.625, 0.5769230769230769
# 6406, random_selected_on, DecisionTreeClassifier, 0.75, 0.75
# 6406, random_selected_in, DecisionTreeClassifier, 1.0, 1.0
# 6406, random_selected_drop, DecisionTreeClassifier, 0.875, 0.8818181818181818
# 6406, random_selected_stretch, DecisionTreeClassifier, 0.75, 0.75
# 6406, random_selected_on, RandomForestClassifier, 0.875, 0.8589743589743589
# 6406, random_selected_in, RandomForestClassifier, 0.875, 0.8589743589743589
# 6406, random_selected_drop, RandomForestClassifier, 0.875, 0.8589743589743589
# 6406, random_selected_stretch, RandomForestClassifier, 0.75, 0.6428571428571428
# 6406, fewest_selected_on, GradientBoostingClassifier, 0.625, 0.5769230769230769
# 6406, fewest_selected_in, GradientBoostingClassifier, 0.625, 0.5769230769230769
# 6406, fewest_selected_drop, GradientBoostingClassifier, 0.625, 0.5769230769230769
# 6406, fewest_selected_stretch, GradientBoostingClassifier, 0.625, 0.5769230769230769
# 6406, fewest_selected_on, DecisionTreeClassifier, 0.75, 0.75
# 6406, fewest_selected_in, DecisionTreeClassifier, 0.75, 0.7666666666666667
# 6406, fewest_selected_drop, DecisionTreeClassifier, 0.75, 0.7666666666666667
# 6406, fewest_selected_stretch, DecisionTreeClassifier, 0.75, 0.75
# 6406, fewest_selected_on, RandomForestClassifier, 0.875, 0.8589743589743589
# 6406, fewest_selected_in, RandomForestClassifier, 0.875, 0.8589743589743589
# 6406, fewest_selected_drop, RandomForestClassifier, 0.875, 0.8589743589743589
# 6406, fewest_selected_stretch, RandomForestClassifier, 0.875, 0.8589743589743589
# 6406, balanced_on, GradientBoostingClassifier, 0.625, 0.5769230769230769
# 6406, balanced_on, DecisionTreeClassifier, 0.75, 0.7666666666666667
# 6406, balanced_on, RandomForestClassifier, 0.875, 0.8589743589743589
# 6406, balanced_in, GradientBoostingClassifier, 0.625, 0.5769230769230769
# 6406, balanced_in, DecisionTreeClassifier, 0.75, 0.7666666666666667
# 6406, balanced_in, RandomForestClassifier, 0.875, 0.8589743589743589
# 2862, base, GradientBoostingClassifier, 1.0, 1.0
# 2862, base, DecisionTreeClassifier, 1.0, 1.0
# 2862, base, RandomForestClassifier, 0.75, 0.7916666666666666
# 2862, random_selected_on, GradientBoostingClassifier, 0.625, 0.6863636363636364
# 2862, random_selected_in, GradientBoostingClassifier, 0.75, 0.7916666666666666
# 2862, random_selected_drop, GradientBoostingClassifier, 0.75, 0.7916666666666666
# 2862, random_selected_stretch, GradientBoostingClassifier, 0.75, 0.7916666666666666
# 2862, random_selected_on, DecisionTreeClassifier, 0.75, 0.7916666666666666
# 2862, random_selected_in, DecisionTreeClassifier, 0.75, 0.7916666666666666
# 2862, random_selected_drop, DecisionTreeClassifier, 0.75, 0.7916666666666666
# 2862, random_selected_stretch, DecisionTreeClassifier, 0.875, 0.891025641025641
# 2862, random_selected_on, RandomForestClassifier, 1.0, 1.0
# 2862, random_selected_in, RandomForestClassifier, 0.75, 0.7916666666666666
# 2862, random_selected_drop, RandomForestClassifier, 0.75, 0.7916666666666666
# 2862, random_selected_stretch, RandomForestClassifier, 0.75, 0.7916666666666666
# 2862, fewest_selected_on, GradientBoostingClassifier, 1.0, 1.0
# 2862, fewest_selected_in, GradientBoostingClassifier, 0.875, 0.891025641025641
# 2862, fewest_selected_drop, GradientBoostingClassifier, 0.75, 0.7916666666666666
# 2862, fewest_selected_stretch, GradientBoostingClassifier, 0.75, 0.7916666666666666
# 2862, fewest_selected_on, DecisionTreeClassifier, 0.75, 0.7916666666666666
# 2862, fewest_selected_in, DecisionTreeClassifier, 0.875, 0.891025641025641
# 2862, fewest_selected_drop, DecisionTreeClassifier, 0.875, 0.891025641025641
# 2862, fewest_selected_stretch, DecisionTreeClassifier, 0.625, 0.6863636363636364
# 2862, fewest_selected_on, RandomForestClassifier, 0.875, 0.891025641025641
# 2862, fewest_selected_in, RandomForestClassifier, 0.875, 0.891025641025641
# 2862, fewest_selected_drop, RandomForestClassifier, 1.0, 1.0
# 2862, fewest_selected_stretch, RandomForestClassifier, 0.75, 0.7916666666666666
# 2862, balanced_on, GradientBoostingClassifier, 1.0, 1.0
# 2862, balanced_on, DecisionTreeClassifier, 1.0, 1.0
# 2862, balanced_on, RandomForestClassifier, 0.75, 0.7916666666666666
# 2862, balanced_in, GradientBoostingClassifier, 1.0, 1.0
# 2862, balanced_in, DecisionTreeClassifier, 1.0, 1.0
# 2862, balanced_in, RandomForestClassifier, 0.75, 0.7916666666666666
# 899, base, GradientBoostingClassifier, 0.5, 0.5
# 899, base, DecisionTreeClassifier, 0.5, 0.5
# 899, base, RandomForestClassifier, 0.75, 0.75
# 899, random_selected_on, GradientBoostingClassifier, 0.5, 0.5
# 899, random_selected_in, GradientBoostingClassifier, 0.75, 0.75
# 899, random_selected_drop, GradientBoostingClassifier, 0.375, 0.40909090909090906
# 899, random_selected_stretch, GradientBoostingClassifier, 0.75, 0.75
# 899, random_selected_on, DecisionTreeClassifier, 0.5, 0.5
# 899, random_selected_in, DecisionTreeClassifier, 0.625, 0.6454545454545454
# 899, random_selected_drop, DecisionTreeClassifier, 0.625, 0.5769230769230769
# 899, random_selected_stretch, DecisionTreeClassifier, 0.75, 0.75
# 899, random_selected_on, RandomForestClassifier, 0.75, 0.6428571428571428
# 899, random_selected_in, RandomForestClassifier, 0.625, 0.5769230769230769
# 899, random_selected_drop, RandomForestClassifier, 0.875, 0.8589743589743589
# 899, random_selected_stretch, RandomForestClassifier, 0.875, 0.8589743589743589
# 899, fewest_selected_on, GradientBoostingClassifier, 0.5, 0.5
# 899, fewest_selected_in, GradientBoostingClassifier, 0.5, 0.5
# 899, fewest_selected_drop, GradientBoostingClassifier, 0.5, 0.5
# 899, fewest_selected_stretch, GradientBoostingClassifier, 0.5, 0.5
# 899, fewest_selected_on, DecisionTreeClassifier, 0.5, 0.5
# 899, fewest_selected_in, DecisionTreeClassifier, 0.5, 0.5
# 899, fewest_selected_drop, DecisionTreeClassifier, 0.5, 0.5
# 899, fewest_selected_stretch, DecisionTreeClassifier, 0.5, 0.5
# 899, fewest_selected_on, RandomForestClassifier, 0.625, 0.5769230769230769
# 899, fewest_selected_in, RandomForestClassifier, 0.625, 0.5769230769230769
# 899, fewest_selected_drop, RandomForestClassifier, 0.625, 0.5769230769230769
# 899, fewest_selected_stretch, RandomForestClassifier, 0.625, 0.5769230769230769
# 899, balanced_on, GradientBoostingClassifier, 0.5, 0.5
# 899, balanced_on, DecisionTreeClassifier, 0.5, 0.5
# 899, balanced_on, RandomForestClassifier, 0.75, 0.75
# 899, balanced_in, GradientBoostingClassifier, 0.5, 0.5
# 899, balanced_in, DecisionTreeClassifier, 0.5, 0.5
# 899, balanced_in, RandomForestClassifier, 0.75, 0.75

# %%
TestUtils.write_csv_file('./geolife_results.csv', final_results)
# Out:
# File successfully written to: ./geolife_results.csv
